# %%
# !pip install transformers
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: transformers in /usr/local/lib/python3.8/dist-packages (4.25.1)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.8/dist-packages (from transformers) (21.3)
# Requirement already satisfied: huggingface-hub<1.0,>=0.10.0 in /usr/local/lib/python3.8/dist-packages (from transformers) (0.11.1)
# Requirement already satisfied: filelock in /usr/local/lib/python3.8/dist-packages (from transformers) (3.8.2)
# Requirement already satisfied: tqdm>=4.27 in /usr/local/lib/python3.8/dist-packages (from transformers) (4.64.1)
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.8/dist-packages (from transformers) (2022.6.2)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.8/dist-packages (from transformers) (6.0)
# Requirement already satisfied: requests in /usr/local/lib/python3.8/dist-packages (from transformers) (2.23.0)
# Requirement already satisfied: numpy>=1.17 in /usr/local/lib/python3.8/dist-packages (from transformers) (1.21.6)
# Requirement already satisfied: tokenizers!=0.11.3,<0.14,>=0.11.1 in /usr/local/lib/python3.8/dist-packages (from transformers) (0.13.2)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /usr/local/lib/python3.8/dist-packages (from huggingface-hub<1.0,>=0.10.0->transformers) (4.4.0)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in /usr/local/lib/python3.8/dist-packages (from packaging>=20.0->transformers) (3.0.9)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /usr/local/lib/python3.8/dist-packages (from requests->transformers) (1.24.3)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.8/dist-packages (from requests->transformers) (2022.12.7)
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/lib/python3.8/dist-packages (from requests->transformers) (3.0.4)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.8/dist-packages (from requests->transformers) (2.10)

# %%
import pandas as pd
import numpy as np
import urllib.request
import os
from tqdm import tqdm
import tensorflow as tf
from transformers import BertTokenizer, TFBertModel
from sklearn.model_selection import train_test_split

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# 데이터 불러오기
data = pd.read_csv('/content/drive/MyDrive/공장/review_data_f.csv')
data = data.drop('Unnamed: 0', axis=1)
data
# Out:
#                                                  review  y
# 0     3대째 이어오고 있는 춘천시 소양로 2가에 위치한 막국수 전문점. 숨은 맛 집답게 ...  1
# 1     공간이 많이 좁았지만 햇살이 잘 들어와서 너무 이뻤던 카페입니다 레몬 빵이 시큼하고...  1
# 2                                             비싸고 맛없어요!  0
# 3     아기자기하고 이쁜 곳! 맛도 좋다!! 배도 부르다! 일요일 점심 무더위에도 웨이팅을...  1
# 4     막걸리 비싸고 주인장의 고압적인 응대에 위축되고 테이블은 다닥다닥 붙어있고 술 마시...  0
# ...                                                 ... ..
# 2062                    웬만하면 리뷰 안다는데 개만 없고 개비 싸고 개불 친절함  0
# 2063  양념이 좀 많이 달아요.  육수는 조미료 맛 많이 나서 별로예요. 직접 면을 뽑는 ...  0
# 2064  근처 맛 집 검색해서 찾아가 봤어요 음식이 전체적으로 다 맛있네요 깔끔한 내부도 마...  1
# 2065  최악 여길 왜가는지 모르겠음. 마늘 손질하던 아줌마가 카드 계산하고 다시 가서 마늘...  0
# 2066  가격이 저렴한데 비해 메뉴 퀄리티가 좋다. 디저트 종류도 다양하고 카페 메뉴도 다양...  1
#
# [2067 rows x 2 columns]

# %%
train_data, test_data = train_test_split(data, test_size=.2)

print('훈련용 리뷰 개수 :', len(train_data))
print('테스트용 리뷰 개수 :', len(test_data))
# Out:
# 훈련용 리뷰 개수 : 1653
# 테스트용 리뷰 개수 : 414

# %% [markdown]
# ---

# %%
# # GPU 환경 설정
# # assert tf.test.is_gpu_available() == True, 'GPU 설정을 확인하세요.'
# print(tf.config.list_physical_devices('GPU'))
# print(tf.config.list_logical_devices('GPU'))

# %%
tokenizer = BertTokenizer.from_pretrained("bert-base-multilingual-cased")
# Out:
# Downloading:   0%|          | 0.00/996k [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/29.0 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/625 [00:00<?, ?B/s]

# %%
def create_examples(df):
    example = []
    label = []
    for (i, row) in enumerate(df.values):
        example.append(row[0])
        label.append(row[1:])
    
    return example, label

# %%
train_example, train_label = create_examples(train_data)
test_example, test_label = create_examples(test_data)

# %%
def convert_examples_to_features(examples, labels, max_seq_len, tokenizer):
    
    input_ids, attention_masks, token_type_ids, data_labels = [], [], [], []
    
    for example, label in tqdm(zip(examples, labels), total=len(examples)):
        input_id = tokenizer.encode(example, max_length=max_seq_len, pad_to_max_length=True)
        padding_count = input_id.count(tokenizer.pad_token_id)
        attention_mask = [1] * (max_seq_len - padding_count) + [0] * padding_count
        token_type_id = [0] * max_seq_len

        assert len(input_id) == max_seq_len, "Error with input length {} vs {}".format(len(input_id), max_seq_len)
        assert len(attention_mask) == max_seq_len, "Error with attention mask length {} vs {}".format(len(attention_mask), max_seq_len)
        assert len(token_type_id) == max_seq_len, "Error with token type length {} vs {}".format(len(token_type_id), max_seq_len)

        input_ids.append(input_id)
        attention_masks.append(attention_mask)
        token_type_ids.append(token_type_id)
        data_labels.append(label)

    input_ids = np.array(input_ids, dtype=int)
    attention_masks = np.array(attention_masks, dtype=int)
    token_type_ids = np.array(token_type_ids, dtype=int)

    data_labels = np.asarray(data_labels, dtype=np.int32)

    return (input_ids, attention_masks, token_type_ids), data_labels

# %%
max_seq_len = 256

# %%
train_X, train_y = convert_examples_to_features(train_example, train_label, max_seq_len=max_seq_len, tokenizer=tokenizer)
# Out:
#   0%|          | 0/1653 [00:00<?, ?it/s]Truncation was not explicitly activated but `max_length` is provided a specific value, please use `truncation=True` to explicitly truncate examples to max length. Defaulting to 'longest_first' truncation strategy. If you encode pairs of sequences (GLUE-style) with the tokenizer you can select this strategy more precisely by providing a specific strategy to `truncation`.
# /usr/local/lib/python3.8/dist-packages/transformers/tokenization_utils_base.py:2336: FutureWarning: The `pad_to_max_length` argument is deprecated and will be removed in a future version, use `padding=True` or `padding='longest'` to pad to the longest sequence in the batch, or use `padding='max_length'` to pad to a max length. In this case, you can give a specific length with `max_length` (e.g. `max_length=45`) or leave max_length to None to pad to the maximal input size of the model (e.g. 512 for Bert).
#   warnings.warn(
# 100%|██████████| 1653/1653 [00:02<00:00, 572.52it/s]

# %%
test_X, test_y = convert_examples_to_features(test_example, test_label, max_seq_len=max_seq_len, tokenizer=tokenizer)
# Out:
# 100%|██████████| 414/414 [00:00<00:00, 687.32it/s]

# %%
model = TFBertModel.from_pretrained("bert-base-multilingual-cased", from_pt=True)
# Out:
# Downloading:   0%|          | 0.00/714M [00:00<?, ?B/s]
# Some weights of the PyTorch model were not used when initializing the TF 2.0 model TFBertModel: ['cls.seq_relationship.weight', 'cls.predictions.transform.LayerNorm.weight', 'cls.predictions.transform.dense.weight', 'cls.seq_relationship.bias', 'cls.predictions.transform.dense.bias', 'cls.predictions.bias', 'cls.predictions.transform.LayerNorm.bias', 'cls.predictions.decoder.weight']
# - This IS expected if you are initializing TFBertModel from a PyTorch model trained on another task or with another architecture (e.g. initializing a TFBertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing TFBertModel from a PyTorch model that you expect to be exactly identical (e.g. initializing a TFBertForSequenceClassification model from a BertForSequenceClassification model).
# All the weights of TFBertModel were initialized from the PyTorch model.
# If your task is similar to the task the model of the checkpoint was trained on, you can already use TFBertModel for predictions without further training.

# %%
input_ids_layer = tf.keras.layers.Input(shape=(max_seq_len,), dtype=tf.int32)
attention_masks_layer = tf.keras.layers.Input(shape=(max_seq_len,), dtype=tf.int32)
token_type_ids_layer = tf.keras.layers.Input(shape=(max_seq_len,), dtype=tf.int32)

outputs = model([input_ids_layer, attention_masks_layer, token_type_ids_layer])

# %%
class TFBertForSequenceClassification(tf.keras.Model):
    def __init__(self, model_name):
        super(TFBertForSequenceClassification, self).__init__()
        self.bert = TFBertModel.from_pretrained(model_name, from_pt=True)
        self.classifier = tf.keras.layers.Dense(1,
                                                kernel_initializer=tf.keras.initializers.TruncatedNormal(0.02),
                                                activation='sigmoid',
                                                name='classifier')

    def call(self, inputs):
        input_ids, attention_mask, token_type_ids = inputs
        outputs = self.bert(input_ids=input_ids, attention_mask=attention_mask, token_type_ids=token_type_ids)
        cls_token = outputs[1]
        prediction = self.classifier(cls_token)

        return prediction

# %%
model = TFBertForSequenceClassification("bert-base-multilingual-cased")
optimizer = tf.keras.optimizers.Adam(learning_rate=5e-5)
loss = tf.keras.losses.BinaryCrossentropy()
model.compile(optimizer=optimizer, loss=loss, metrics = ['accuracy'])
# Out:
# Some weights of the PyTorch model were not used when initializing the TF 2.0 model TFBertModel: ['cls.seq_relationship.weight', 'cls.predictions.transform.LayerNorm.weight', 'cls.predictions.transform.dense.weight', 'cls.seq_relationship.bias', 'cls.predictions.transform.dense.bias', 'cls.predictions.bias', 'cls.predictions.transform.LayerNorm.bias', 'cls.predictions.decoder.weight']
# - This IS expected if you are initializing TFBertModel from a PyTorch model trained on another task or with another architecture (e.g. initializing a TFBertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing TFBertModel from a PyTorch model that you expect to be exactly identical (e.g. initializing a TFBertForSequenceClassification model from a BertForSequenceClassification model).
# All the weights of TFBertModel were initialized from the PyTorch model.
# If your task is similar to the task the model of the checkpoint was trained on, you can already use TFBertModel for predictions without further training.

# %%
model.fit(train_X, train_y, epochs=2, batch_size=16, validation_split=0.2)
# Out:
# Epoch 1/2
# 83/83 [==============================] - 100s 1s/step - loss: 0.6223 - accuracy: 0.6430 - val_loss: 0.4415 - val_accuracy: 0.7764
# Epoch 2/2
# 83/83 [==============================] - 80s 969ms/step - loss: 0.4387 - accuracy: 0.8207 - val_loss: 0.3879 - val_accuracy: 0.8580

# %%
results = model.evaluate(test_X, test_y, batch_size=8)
print("test loss, test acc: ", results)
# Out:
# 52/52 [==============================] - 8s 161ms/step - loss: 0.3952 - accuracy: 0.8551
# test loss, test acc:  [0.3951782286167145, 0.8550724387168884]

# %%
model.predict(test_X)
# Out:
# 13/13 [==============================] - 11s 604ms/step
# array([[0.16288337],
#        [0.44585213],
#        [0.17821367],
#        [0.35550883],
#        [0.1694465 ],
#        [0.30632037],
#        [0.7358334 ],
#        [0.74116963],
#        [0.3596613 ],
#        [0.14470717],
#        [0.9220794 ],
#        [0.7518225 ],
#        [0.9257964 ],
#        [0.16095056],
#        [0.18653691],
#        [0.6277997 ],
#        [0.1561538 ],
#        [0.16824354],
#        [0.5189366 ],
#        [0.26733488],
#        [0.22684239],
#        [0.81952596],
#        [0.2456496 ],
#        [0.25609198],
#        [0.74400204],
#        [0.14239325],
#        [0.55602235],
#        [0.76397645],
#        [0.41133386],
#        [0.2723984 ],
#        [0.8473135 ],
#        [0.51643234],
#        [0.54700756],
#        [0.31236407],
#        [0.45479637],
#        [0.47686064],
#        [0.7300312 ],
#        [0.8250188 ],
#        [0.23485823],
#        [0.15882139],
#        [0.41404524],
#        [0.2860511 ],
#        [0.46493283],
#        [0.38194266],
#        [0.9251263 ],
#        [0.20356207],
#        [0.9113754 ],
#        [0.2125175 ],
#        [0.8692593 ],
#        [0.30122253],
#        [0.8727745 ],
#        [0.2520923 ],
#        [0.8462924 ],
#        [0.5458741 ],
#        [0.5268604 ],
#        [0.1496052 ],
#        [0.51721334],
#        [0.9167574 ],
#        [0.37607914],
#        [0.38144937],
#        [0.9340958 ],
#        [0.52024454],
#        [0.6677335 ],
#        [0.22749826],
#        [0.5922632 ],
#        [0.49247295],
#        [0.16596493],
#        [0.9336892 ],
#        [0.45317557],
#        [0.18370874],
#        [0.6156264 ],
#        [0.36972708],
#        [0.15716276],
#        [0.81867176],
#        [0.43624347],
#        [0.14652096],
#        [0.92975557],
#        [0.92140263],
#        [0.5145592 ],
#        [0.8859914 ],
#        [0.157794  ],
#        [0.26243743],
#        [0.84195036],
#        [0.31548798],
#        [0.34243953],
#        [0.24180898],
#        [0.8128015 ],
#        [0.93186533],
#        [0.1505441 ],
#        [0.23995303],
#        [0.11898591],
#        [0.3745172 ],
#        [0.91588527],
#        [0.32807326],
#        [0.8662922 ],
#        [0.5292004 ],
#        [0.4579531 ],
#        [0.7519273 ],
#        [0.8842667 ],
#        [0.17924382],
#        [0.26297417],
#        [0.21161179],
#        [0.4225743 ],
#        [0.30494574],
#        [0.3053245 ],
#        [0.8423036 ],
#        [0.14182092],
#        [0.19174394],
#        [0.35587245],
#        [0.81794244],
#        [0.8075677 ],
#        [0.16471705],
#        [0.22844897],
#        [0.9294217 ],
#        [0.37477973],
#        [0.87146616],
#        [0.9086528 ],
#        [0.5046927 ],
#        [0.2161584 ],
#        [0.48744252],
#        [0.11067986],
#        [0.2893653 ],
#        [0.9356457 ],
#        [0.1589162 ],
#        [0.7037401 ],
#        [0.16288964],
#        [0.40897703],
#        [0.51817983],
#        [0.9241108 ],
#        [0.1796837 ],
#        [0.5175378 ],
#        [0.24182335],
#        [0.6369548 ],
#        [0.39840895],
#        [0.8160859 ],
#        [0.90279794],
#        [0.92409784],
#        [0.30070353],
#        [0.93488324],
#        [0.8681669 ],
#        [0.360088  ],
#        [0.77691215],
#        [0.43836477],
#        [0.16232966],
#        [0.87412065],
#        [0.13748759],
#        [0.22850488],
#        [0.2897792 ],
#        [0.8721469 ],
#        [0.26182777],
#        [0.8717449 ],
#        [0.27503338],
#        [0.86893237],
#        [0.6898591 ],
#        [0.3892318 ],
#        [0.3738948 ],
#        [0.85910106],
#        [0.13523129],
#        [0.2889403 ],
#        [0.13626929],
#        [0.7371705 ],
#        [0.42146337],
#        [0.5453228 ],
#        [0.21339437],
#        [0.3689974 ],
#        [0.9252805 ],
#        [0.9250446 ],
#        [0.20078677],
#        [0.56756926],
#        [0.2492129 ],
#        [0.6474657 ],
#        [0.88287604],
#        [0.2346467 ],
#        [0.6913613 ],
#        [0.7960368 ],
#        [0.6691704 ],
#        [0.3319986 ],
#        [0.2086892 ],
#        [0.26449728],
#        [0.25313416],
#        [0.20086186],
#        [0.90614176],
#        [0.15211822],
#        [0.7680358 ],
#        [0.854782  ],
#        [0.2599396 ],
#        [0.26858515],
#        [0.84493375],
#        [0.16566844],
#        [0.9053572 ],
#        [0.9356952 ],
#        [0.13549587],
#        [0.8097359 ],
#        [0.89344966],
#        [0.17744857],
#        [0.9316078 ],
#        [0.22579686],
#        [0.57949895],
#        [0.93323827],
#        [0.33609933],
#        [0.40655464],
#        [0.1296859 ],
#        [0.1917146 ],
#        [0.60055137],
#        [0.22524367],
#        [0.22673279],
#        [0.25450388],
#        [0.191544  ],
#        [0.6118237 ],
#        [0.91684455],
#        [0.33989975],
#        [0.50582767],
#        [0.5221017 ],
#        [0.29637673],
#        [0.4699674 ],
#        [0.8843297 ],
#        [0.20321599],
#        [0.67132914],
#        [0.13557377],
#        [0.66594857],
#        [0.7558699 ],
#        [0.9274954 ],
#        [0.2168568 ],
#        [0.23785912],
#        [0.72471637],
#        [0.7907427 ],
#        [0.68033695],
#        [0.8947171 ],
#        [0.8474733 ],
#        [0.36702535],
#        [0.87216777],
#        [0.26817155],
#        [0.2646467 ],
#        [0.25199103],
#        [0.8450242 ],
#        [0.9157789 ],
#        [0.59160084],
#        [0.7805532 ],
#        [0.15152977],
#        [0.52007794],
#        [0.7194166 ],
#        [0.57733524],
#        [0.7191099 ],
#        [0.198407  ],
#        [0.8269237 ],
#        [0.18310559],
#        [0.7879688 ],
#        [0.3054198 ],
#        [0.9415575 ],
#        [0.30322447],
#        [0.7303711 ],
#        [0.42450565],
#        [0.7781839 ],
#        [0.1724701 ],
#        [0.8791699 ],
#        [0.45891288],
#        [0.28245372],
#        [0.16517411],
#        [0.57244337],
#        [0.1749432 ],
#        [0.7836899 ],
#        [0.20784009],
#        [0.6524884 ],
#        [0.87321347],
#        [0.7196081 ],
#        [0.37480757],
#        [0.8012132 ],
#        [0.20332827],
#        [0.5342942 ],
#        [0.17323512],
#        [0.1578082 ],
#        [0.26504195],
#        [0.89914525],
#        [0.22263081],
#        [0.24803722],
#        [0.9145812 ],
#        [0.19126272],
#        [0.20293655],
#        [0.19096936],
#        [0.18627061],
#        [0.20844387],
#        [0.5967136 ],
#        [0.91800225],
#        [0.5808567 ],
#        [0.19313882],
#        [0.28114405],
#        [0.27066132],
#        [0.85106725],
#        [0.13910985],
#        [0.38188672],
#        [0.37429062],
#        [0.8942959 ],
#        [0.5323889 ],
#        [0.87149614],
#        [0.8312446 ],
#        [0.41916156],
#        [0.832259  ],
#        [0.13246799],
#        [0.2676951 ],
#        [0.852689  ],
#        [0.12184321],
#        [0.69145226],
#        [0.19438715],
#        [0.14266068],
#        [0.23887338],
#        [0.24382535],
#        [0.5383705 ],
#        [0.3248685 ],
#        [0.5217709 ],
#        [0.89162946],
#        [0.70591253],
#        [0.70869493],
#        [0.19685064],
#        [0.44606712],
#        [0.5214779 ],
#        [0.22670372],
#        [0.24373148],
#        [0.11757869],
#        [0.5537992 ],
#        [0.2136393 ],
#        [0.3552547 ],
#        [0.16651604],
#        [0.14989977],
#        [0.50668705],
#        [0.24568334],
#        [0.25153148],
#        [0.7743237 ],
#        [0.15527022],
#        [0.8976155 ],
#        [0.22230573],
#        [0.85867566],
#        [0.22973283],
#        [0.90973556],
#        [0.9046139 ],
#        [0.16414596],
#        [0.20484366],
#        [0.18937184],
#        [0.18194704],
#        [0.81841964],
#        [0.2375599 ],
#        [0.15414593],
#        [0.2194178 ],
#        [0.30390826],
#        [0.24910426],
#        [0.89524424],
#        [0.41100103],
#        [0.6717822 ],
#        [0.9229197 ],
#        [0.9195125 ],
#        [0.21092583],
#        [0.40878057],
#        [0.75491923],
#        [0.49593   ],
#        [0.21315202],
#        [0.7545074 ],
#        [0.8886317 ],
#        [0.87965035],
#        [0.7510726 ],
#        [0.30386198],
#        [0.16288792],
#        [0.5731505 ],
#        [0.8497769 ],
#        [0.41570905],
#        [0.73479813],
#        [0.33130142],
#        [0.9233873 ],
#        [0.18454246],
#        [0.48280102],
#        [0.64275074],
#        [0.79571044],
#        [0.5613527 ],
#        [0.25008753],
#        [0.13461359],
#        [0.1582541 ],
#        [0.77452445],
#        [0.20677376],
#        [0.8334263 ],
#        [0.31006032],
#        [0.6773005 ],
#        [0.17476876],
#        [0.8397759 ],
#        [0.8744364 ],
#        [0.6929429 ],
#        [0.38627037],
#        [0.92430586],
#        [0.92160773],
#        [0.39003342],
#        [0.8620973 ],
#        [0.6520491 ],
#        [0.37197065],
#        [0.21005078],
#        [0.6955878 ],
#        [0.3206321 ],
#        [0.2524054 ],
#        [0.62082726],
#        [0.7812135 ],
#        [0.4686658 ],
#        [0.3041531 ],
#        [0.17562649],
#        [0.15439448],
#        [0.81410784],
#        [0.8217922 ],
#        [0.7482445 ],
#        [0.8899865 ],
#        [0.10475177],
#        [0.186904  ],
#        [0.34366938],
#        [0.9158236 ],
#        [0.24539919],
#        [0.63366735],
#        [0.4743357 ],
#        [0.88230914],
#        [0.19889554],
#        [0.8614902 ]], dtype=float32)

# %%
test_set = pd.read_csv('/content/drive/MyDrive/공장/train_x_total.csv')
test_set = test_set[['reviews']]
test_set['y'] = 0
test_set = test_set.dropna()
test_set.head()
# Out:
#                          reviews  y
# 0                  만족도 최상의 커피 맛집  0
# 1                        찐 커피 맛집  0
# 2                로마노 진짜 달달하고 맛있고  0
# 3  아이스크림 라떼도 꼬소하고 달달하고 진짜 맛있어요!!  0
# 4                  마리토쪼도 크림 부드럽고  0

# %%
test_example, test_label = create_examples(test_set)
test_X, _ = convert_examples_to_features(test_example, test_label, max_seq_len=max_seq_len, tokenizer=tokenizer)
# Out:
#   0%|          | 0/10292 [00:00<?, ?it/s]/usr/local/lib/python3.8/dist-packages/transformers/tokenization_utils_base.py:2336: FutureWarning: The `pad_to_max_length` argument is deprecated and will be removed in a future version, use `padding=True` or `padding='longest'` to pad to the longest sequence in the batch, or use `padding='max_length'` to pad to a max length. In this case, you can give a specific length with `max_length` (e.g. `max_length=45`) or leave max_length to None to pad to the maximal input size of the model (e.g. 512 for Bert).
#   warnings.warn(
# 100%|██████████| 10292/10292 [00:03<00:00, 2594.59it/s]

# %%
pred = model.predict(test_X)
# Out:
# 322/322 [==============================] - 191s 591ms/step

# %%
pred
# Out:
# array([[0.5736812 ],
#        [0.81933594],
#        [0.6300249 ],
#        ...,
#        [0.76487994],
#        [0.27208036],
#        [0.6189232 ]], dtype=float32)

# %%
pred = np.where(pred>0.5, 1, 0).reshape(-1)

# %%
test_set['pred'] = pred

# %%
pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows', None)

# %%
test_set.loc[test_set['pred']==1]
# Out:
#                                                  reviews  y  pred
# 0                                          만족도 최상의 커피 맛집  0     1
# 1                                                찐 커피 맛집  0     1
# 2                                        로마노 진짜 달달하고 맛있고  0     1
# 3                          아이스크림 라떼도 꼬소하고 달달하고 진짜 맛있어요!!  0     1
# 4                                          마리토쪼도 크림 부드럽고  0     1
# 6                                          커조남 커피는 힐링입니다  0     1
# 7                                             소금 빵도 맛있어요  0     1
# 8                                             시나몬 롤 맛있어용  0     1
# 10                                           드립커피하면 커조남!  0     1
# 11                                 오늘 드립커피는 좀 애매한 맛이긴했지만  0     1
# 12                                        리필 커피가 맛있어서 괜춘  0     1
# 13                                    바로 앞 공영 주차장에 주차 가능  0     1
# 14                                             최애 커피집입니다  0     1
# 16                                   크리스마스 페어에서도 로마노 한 잔  0     1
# 17                               더웠는 데 시원하게 상큼하게 잘 마셨습니다  0     1
# 18                                                 커피 맛집  0     1
# 19                   커피 맛을 조금 아는 남자가 반갑게 맞아 주는 찐 커피 맛집!!  0     1
# 20                          리모델링하고는 처음 가 봤는데 인테리어도 더 이쁘고  0     1
# 21                                  디저트도 많아진 거 같아서 좋아요!!  0     1
# 22                                       커피는 여전히 너무 맛있네요  0     1
# 23                              로마노는 처음 마셔 봤는데 완전 신세계!!!  0     1
# 25                              디카페인 라떼도 생각보다 맛있어서 충격적..  0     1
# 28                                          리필도 되니 늠 좋네요  0     1
# 29                                          커피가 너무 맛있어요.  0     1
# 30                         디카페인 커피 원두 시음해 보고 맛있어서 구매했습니다  0     1
# 33                                       카페오레 온도가 참 좋아요.  0     1
# 34                                    소금 빵과 잘 어울리는 맛입니다.  0     1
# 35                                        평일에도 항상 사람들 많고  0     1
# 36                                        직원 분들 모두 친절하시고  0     1
# 37                                    무엇보다 커피 맛 정말 최고에요!  0     1
# 40                                           카페오레 맛있습니다.  0     1
# 42                                          커피 너무 맛있어요!!  0     1
# 44                                            굿 커피 맛 좋아요  0     1
# 45                                       빵이랑 음료 다 맛있었어요!  0     1
# 46                            주문한 메뉴를 자리까지 가져다 주셔서 좋았어요!  0     1
# 48                                          커피가 정말 맛있어요.  0     1
# 49                                                 친절하네요  0     1
# 50                                             커피가 맛있어요.  0     1
# 51                                   커피 맛 좋기로 유명해서 종종 와요  0     1
# 52                                             베이커리도 맛있고  0     1
# 54                                      이야기 하기 좋은 룸도 있어요  0     1
# 55                                                    친절  0     1
# 56                                      리모델링 되고 나서 더 멋뎌요  0     1
# 58                                 로마노 향도 맛도 정말 최고인 듯!!!  0     1
# 59                                            본점 분위기도 좋고  0     1
# 60                                         야외 석도 많아 좋아요.  0     1
# 61      태어나서 먹은 커피 중에 제일 맛있음 고급 진 맛 커피를 조금 아는 남자가 아닌 정도임  0     1
# 62                                                 디져트맛나  0     1
# 63                                                 커피 맛집  0     1
# 64                                        느리게 나오지만 맛있습니다  0     1
# 65                                   카페 명칭에 걸맞는 커피와 원두들.  0     1
# 66     눈을 사로잡는 베이커리류까지 맛 좋은 커피를 즐기기에 더할 나위 없는 멋진 카페였습니다.  0     1
# 67                            워낙 유명한 커피 집이라 엄청 기대하고 갔어요.  0     1
# 68                   특히 상하 목장 우유로 만든 아이스크림 라떼가 정말 최고였어요.  0     1
# 69                  에스프레소도 이제까지 대구에서 마셔 본 어떤에쏘보다 맛있었습니다.  0     1
# 71                           디저트 빵도 넘나 맛나서 일행 모두 대만족했네요.  0     1
# 72                        날이 좋아 밖에서 마실 수 있었던 것도 너무 좋았어요.  0     1
# 73                                          핸드드립 커피도 맛있고  0     1
# 74                                        아이스크림도 넘 맛있었어요  0     1
# 75                          우유마리토쪼 퀸아망 다 너무 너무 너무 맛있구요!!  0     1
# 76                     커피 맛까지 좋으니까 디저트 더 더 더 더 맛있게 느껴지구요  0     1
# 77                             시그니쳐 로마노도 한 번 꼭 드셔 보셔야해요!  0     1
# 78                                     여기 로마노 짱 맛있어용..!!  0     1
# 81                           원하는 원두로 맛있는 커피 마실 수 있는 곳이에요  0     1
# 82                                      오랜만에 오니 더 분위기 좋고  0     1
# 83                         커피는 여전히 맛있어서 기분 좋은 디저트 타임이였어요  0     1
# 84                                         커피가 맛있는 집입니다.  0     1
# 85                              커피가 맛있어 샌 단장했다길래 다시 방문..  0     1
# 86                                                  친절하고  0     1
# 89                                          핸드드립 맛집 커조남!  0     1
# 90              일요일 오후 3시쯤 방문했는데 겨우 자리 앉았을 정도로 인기가 많았어요.  0     1
# 91                                 드립커피는 에티오피아 G1로 얼 그레이  0     1
# 93                          마리토쪼와 취향에 맞는 드립 커피를 추천 드립니다.  0     1
# 94                                           분위기가 너무 좋아요  0     1
# 95                                        음료도 이쁠뿐더러 맛있어요  0     1
# 96                                             붕어빵 꼭 드세요  0     1
# 97                                           도미빵 완전 맛있어요  0     1
# 100                                            카페 분위기 좋고  0     1
# 101                                            사진도 잘 나와요  0     1
# 102                           디저트 맛집 오늘은 도미 쑥 빵 처음 맛봤는 데  0     1
# 104                                          아메리카도 넘 맛있고  0     1
# 107                         예전 레트로 이미지와 클래식한 카페를 원한다면 추천  0     1
# 112                           커피 맛과 분위기 모두 좋아서 장국영님도 그립고  0     1
# 113                                               분위기 있고  0     1
# 114                                            특이하고 조용하고  0     1
# 115                                         크로플 되게 맛있었다.  0     1
# 116    불빛이 아른해서 올라왔는 데 커피도 맛있고 에그 크로와상, 도미쑥빵, 붕어빵, 진짜...  0     1
# 117    우연히 검색해서 들어갔는데 정말 개화기 시대 박물관을 다녀온 듯 인테리어도 예쁘고 ...  0     1
# 118                  그리고 시멘트 커피 위에 올려진 흑임자 아이스크림도 맛있음!!!  0     1
# 119                         커피 못 드시는 분들은 백도 에이드 강추 합니다!!  0     1
# 120                   진짜 너무 맛있어서 다음에 다른 미뉴들도 먹어 보고 샆어요!!  0     1
# 121                           버터 커피가 소금 커피처럼 짭쪼름해서 맛있었어용  0     1
# 122                                           사장님도 친절하시고  0     1
# 123                                        매장 인테리어도 멋있어용  0     1
# 126                                          디저트 맛있어서 깜놀  0     1
# 127                                             매우 친절하세요  0     1
# 129                                          분위기가 너무 좋네요  0     1
# 130                                          레트로풍의 최고조네요  0     1
# 131    신 메뉴 개발 중이라고 시식해 보라고 주셨어요 말차가 들은 붕어빵인 거 같은데 넘나...  0     1
# 132                커피는 흑임자 라떼? 시켰는데 저 석상 모양 아이스가 너무 귀엽네요  0     1
# 133                           우선 되게 외진 곳에 있는 데 분위기 너무 좋고  0     1
# 134                                            커피도 맛있어요!  0     1
# 135                                   분위기가 홍콩 영화 느낌 깡팹니다  0     1
# 136                                                 꽤 넓고  0     1
# 137                                             주변도 조용하고  0     1
# 138                                         크로플이 진짜 맛있어요  0     1
# 139                          정말 맛있음 시멘트 커피도 달고 고소하고 맛있어요  0     1
# 140    홍콩 느낌인 듯엔 틱한 인테리어가 마음에 들어 갔는 데 크로플이랑 커피 마시러 가겠...  0     1
# 143                                 버터 무슨 음료 이것도 너무 맛있어요  0     1
# 144                                       크로플이 진짜 미쳤습니다.  0     1
# 146                              진짜 너무 분위기도 좋고 걍 너무 행복해요  0     1
# 147           홍콩 영화 무드 때문에 재방문했는데 알고 보니 여기 엄청난 크로플 맛집입니다  0     1
# 149                                        인테리어 정말 아름답구요  0     1
# 150                                          바닐라 라떼 맛있어요  0     1
# 154                                            카페 너무 예쁘고  0     1
# 155                                          선곡도 너무 좋아요.  0     1
# 158                                        이용하기 편하고 저렴해용  0     1
# 159    커피 사장님 추천으로 우리는 해 목에서 밥 먹고 또 천장 지구 와서 바라 테이크 아...  0     1
# 160                                    유튜브와 tv 뮤직비디오 나오고  0     1
# 161                                           분위기가 진짜 깡패  0     1
# 162                                              커피 맛 있고  0     1
# 163                                             분위기가 좋아요  0     1
# 165                                      이 곳에 변화는 늘 조화롭다  0     1
# 166                                        강남 여행 내 힐링 공간  0     1
# 167                                         홍콩 분위기 넘 좋아요  0     1
# 168                                  분위기 정말 앤티크하고 멋지더라구요  0     1
# 169                          따로 다시 가서 편하게 시간 보내고 싶은 곳이에요  0     1
# 170                                          너무 예쁘고 좋았어요  0     1
# 171                                           분위기 좋은 커피집  0     1
# 172                                            분위기 좋은 카페  0     1
# 173                                                 조용하고  0     1
# 175                              분위기가 독특하면서도 묘하게 매력이 있어요  0     1
# 176                      음료도 달달하면서도 너무 싸구려 맛이 아니라서 좋았어요!  0     1
# 177                                          분위기 갑 카페입니다  0     1
# 178                               대박쓰 크로플도 맛있구 말쑥 라떼도 꿀맛  0     1
# 179                                         분위기 독특하고 멋져요  0     1
# 180                          인테리어가 정말 경성 느낌 그대로 독특하고 예뻐요  0     1
# 181                                   펑리수랑 시멘트 커피도 맛있습니다  0     1
# 184                               예쁜 인테리어 귀여운 강아지 맛있는 음료  0     1
# 186                                     친절 커피 맛있게 먹고 갑니다  0     1
# 187         무심코 들른 카페에서 친절한 사장님이 만들어 주기는 맛있는 커피 마시고 갑니다.  0     1
# 188    드립커피가 너무 맛있어서 원두 뭐 쓰시냐고 여쭤 봤는데 정신을 차리고 보니 드립 커...  0     1
# 189                 베이커리도 직접 만드시는 거 같은데 집사람이 매우 좋아라 합니다.  0     1
# 190                                            커피 맛도 좋은데  0     1
# 191                                             분위기도 좋아요  0     1
# 192                          가끔 갈 때마다 사장님께서 친절하게 응대해 주시고  0     1
# 193                               커피에 대한 설명도 친절하게해 주세요!!  0     1
# 194                                           몽블랑 맛있네요!!  0     1
# 195                               먹기 힘들 정도로 우유 크림이 가득했지만  0     1
# 197                                            바닐라 도넛 맛있  0     1
# 198                                    다행이도 자리가 있어서 먹고가용  0     1
# 199                                             인테리어 이뻐요  0     1
# 200                                  늘 케잌과 도넛 맛있게 먹고 있어요  0     1
# 202                                    쪼꼬푸딩 도넛 얼마나 맛 있께요  0     1
# 203                                              곰돌이 케이크  0     1
# 204                                         디저트가 너무 귀여워요  0     1
# 205                                        웨이팅은 여전히 있는 편  0     1
# 208                                        도넛이 유명한 노티드지만  0     1
# 209                                  크로플이랑 페이 글도 맛있네요!!!  0     1
# 210                                      망고 스마일 케잌 맛있었어요  0     1
# 212                                        도넛 정말 이쁘고 맛나요  0     1
# 214                  와 사람 진짜 많더라구요 포장 손님은 너무 많아요 깜짝 놀랐네요  0     1
# 215              애플 캐모마일 티 맛있어요 자리 잡고 드실 꺼면 2 층 가서 자리 잡고  0     1
# 216                                          직원 분들이 친절하고  0     1
# 217                                          도넛 너무 맛있어요!  0     1
# 218                                      케잌들이 정말 너무 귀여워요  0     1
# 219                                  크랙 치즈볼과 버터밀크 스콘 맛나요  0     1
# 220                     크리스마스트리 모양의 와인 병 넘 예뻐서 한 병 구입했어요  0     1
# 221                                  내부 인테리어도 노랑 노랑 예쁘네요  0     1
# 222                                      맛이 있는 곳 와인도 좋아요  0     1
# 223                         맨날 커피만 먹다가 도넛은 처음 먹는 데 맛있엇 움  0     1
# 225                                  할머니가 노티드꺼를 너무 좋아하세요  0     1
# 226                                       케익 종류가 많아서 좋아요  0     1
# 227                                   가게가 진짜 아기자기하고 이뻐요!  0     1
# 228                                          크림 도넛 맛있어요!  0     1
# 229                               청담 노티드는 첨 가 봤는데 좋았어요!!  0     1
# 232                   우유 크림은 맛있고 다른 건 특색은 있으나 대단히 맛있진 않다  0     1
# 233                                            커피 향이 좋아요  0     1
# 234                                        다양한 음료가 맛있어요.  0     1
# 235             포장 손님 엄청 많아요 몇 분 기다려서 픽업했어요 맛있어서 기다릴 만해요  0     1
# 237                                               존맛탱 구리  0     1
# 240                      맛있어요 평일 퇴근 후 가도 디저트 종류가 어마어마하네요  0     1
# 241                                                    굿  0     1
# 242                    #라이스치즈소금빵 메뉴 네임 그대로 위에 토핑 부분 바삭하고  0     1
# 243                                       생각보다 소금 빵 맛있어요  0     1
# 244                                    도넛과 케이크 사러 가끔 옵니다  0     1
# 245                                   가끔씩 당 충전으로 먹고 싶어요!  0     1
# 247                                                   넓고  0     1
# 250                                    분위기가 너무 좋은 곳이네요!!  0     1
# 251                                      맛도 있고 정말 최고였습니다  0     1
# 252                                                   넓고  0     1
# 253                                           인테리어가 귀여워요  0     1
# 254                                       레트로 한 디저트가 많아요  0     1
# 255                                                 깨끗하고  0     1
# 257                                           음료가 맛있습니다.  0     1
# 259                                   안쓰럽 주문하는 데도 기다려야하고  0     1
# 260                                                 맛있어여  0     1
# 261                                     강남 특별한 다방 특별한 메뉴  0     1
# 262                           평화 다방 명칭 때문에 갔는데 인테리어 깔끔하고  0     1
# 263                                              좌석도 편해요  0     1
# 264                                            화장실도 깨끗하고  0     1
# 265                                            대화하기 편했어요  0     1
# 266                                             커피가 맛있어요  0     1
# 267                                   메뉴가 신기한 것이 많아서 좋아요  0     1
# 268                                           아메리카노 맛있어요  0     1
# 270                                            알바생이 친절하고  0     1
# 271                                              분위기 좋은데  0     1
# 273                            음료는 강남 다른 곳에 비해 저렴하고 양 많음  0     1
# 274                                       미숫가루 맛있는 거 같아요  0     1
# 275                            다른 곳보다 조용하니 시간 보내기도 좋습니다!  0     1
# 276                                            분위기도 좋아요!  0     1
# 278                                       그래도 음식은 맛있었습니다  0     1
# 279                                            카페 내부가 넓고  0     1
# 280                                         좌석도 많아서 좋아요!  0     1
# 282                                        가성비 좋은 것 같아요!  0     1
# 283                                               맛있었어요!  0     1
# 284                                   사람이 너무 많아서 오래 기다렸엉  0     1
# 285                            다방 컨셉의 카페라서 엄마가 엄청 좋아하셨어요  0     1
# 286                                            옛날 갬성 좋아요  0     1
# 287                                        너무 맛있어서 다 마시고  0     1
# 288                                         다만 매장이 좀 추워요  0     1
# 289                                                율무차 짱  0     1
# 290                                                맛있었어요  0     1
# 294                            평화 다방 와 보고 싶었는 데 가성비 괜찮네여  0     1
# 295                                      특히 디저트 가성비 최고!!  0     1
# 296                            쑥쑥 라떼 쑥 향 좋아여 더 진했으면 좋겠어요  0     1
# 297                                         인절미 떡 꼬치 맛있고  0     1
# 298                                             분위기도 좋아요  0     1
# 300                                             분위기 귀여워요  0     1
# 301                                                커피 맛집  0     1
# 302                                      리모델링해서 더 쾌적해졌어요  0     1
# 303                                      커피 가성비 좋은 거 같아요  0     1
# 304                                   나른한 오후에 아이스 라떼 좋아요  0     1
# 306                                                 맛있어요  0     1
# 307                                             커피가 맛있어요  0     1
# 308                                                 친절하고  0     1
# 309                                           아이스크림 맛있어요  0     1
# 310                                         넓고 깨끗하고 좋아요!  0     1
# 311                                           커피도 맛있습니다.  0     1
# 312                                            커피도 맛있어요.  0     1
# 313                                  다음에는 케익도 먹어 볼까 합니다.  0     1
# 314                                         커피 값 싸고 맛있네요  0     1
# 315                                              커피도 맛있고  0     1
# 316                                    여럿이 편하게 얘기하기 좋아요.  0     1
# 317                                       커피값 상대적으로 저렴하고  0     1
# 318                                           화장실도 깨끗해요.  0     1
# 319                                              따땃한 생강차  0     1
# 320                                               매장이 넓고  0     1
# 321                                            음료도 저렴해요.  0     1
# 322                                             음료가 맛있었고  0     1
# 323                                          직원 분이 친절하세요  0     1
# 324                                                맛있어요!  0     1
# 326                                              자리는 좋은데  0     1
# 328                                         콩고물 팥빙수 맛있어요  0     1
# 329                                           음료 할인 받았어요  0     1
# 330                                             커피 맛 좋아요  0     1
# 331                                           까페라테가 맛있어요  0     1
# 332                                            수다 떨기 좋아요  0     1
# 333                                                 맛있어요  0     1
# 334                                                 맛있어요  0     1
# 335                                           할인이 돼서 좋아요  0     1
# 339                                           사장님이 친절하세요  0     1
# 340                                             신속하게 나와요  0     1
# 341                                             분위기 좋는데요  0     1
# 344                                          방배역 언덕 위 카페  0     1
# 346                                플랫 화 아트는 구 냥 아이스 라떼네요  0     1
# 347                                             커피 맛 있어요  0     1
# 348                              해가 참 잘 드는 카페 커피도 너무 맛있고  0     1
# 349                                              분위기 좋아요  0     1
# 350                                  직접 로스팅해서 원두 선택 가능하고  0     1
# 351                                싱글 오리진도 다양하게 보유하고 있어요  0     1
# 353                                  오랜만에 갔는데도 여전히 커피 맛집  0     1
# 354                               항상 커피 맛있고 좋은 공간 감사합니다.  0     1
# 355                                       오랜만에 가도 늘 친절하고  0     1
# 356                                        라떼가 맛있는 매장이에요  0     1
# 357                                    아이스 라떼 고소하고 맛있어요!  0     1
# 358                                             라떼가 맛있어용  0     1
# 359                                        라떼가 맛있는 매장이에요  0     1
# 360             드립백 만드셨다고 선물로 먹어 보라고 2개 주셔서 기분 좋은 날이였어요.  0     1
# 361    항상 친절하고 상냥하신 사장님 덕분에 맛있고 좋은 드립백도 지인 선물하려고 구입해 ...  0     1
# 362                                오늘 라떼도 넘 맛나게 잘 먹고 왔어요  0     1
# 363                         라떼 아트를 너무 이쁘게 해 주셔서 항상 감동이에요  0     1
# 364                                        커피 고소하고 맛있어요!  0     1
# 365                                      매장 분위기가 너무 좋아요!  0     1
# 366                                    무엇보다 사장님이 넘 친절하세요  0     1
# 367                                   라떼 아트가 이쁜 단골 카페에요.  0     1
# 368                                        하루에 힐링하는 장소에요  0     1
# 369                 라떼 아트를 너무 이쁘게 해 주셔서 기분 전환으로 최고인 곳이에요  0     1
# 370                           스콘도 직접 만들어 판매하셔서 고소하고 맛있어요  0     1
# 371                                    라떼 아트가 사랑스러운 곳이에요  0     1
# 372                                             커피 넘 맛있고  0     1
# 373                                          저만의 힐링 장소에요  0     1
# 375                                        카페 분위기 너무 좋아요  0     1
# 377                         분위기도 너무 좋고 차분하게 이야기하기 좋은 장소.  0     1
# 378                                     스콘이랑 커피도 너무 맛있음.  0     1
# 379                                     너무 진짜 정말 맛있어요!!!  0     1
# 380                                차도 맛보라구 주셨는 데 차도 취향저격  0     1
# 381                            방배 골목 지나가다 눈에 띄어 들어갔는데 와!  0     1
# 382                                    코코넛이 들어갔다는 업셋 라떼.  0     1
# 383                    갠적으로 코코넛 그닥인데 이건 엄청 호! 하면서 꿀떡 마심.  0     1
# 387               에티오피아 쉬파로우 단맛 중심에 약간에 딸기 뉘양스가 있는 것 같아요  0     1
# 388                                              너무 맛있어요  0     1
# 389                             드립커피랑 꾸덕꾸덕 브라우니 존 맛이구요..  0     1
# 390                  분명 카페인데 디퓨저를 좋은 거 쓰시는지 카페에서 향기가 나네요  0     1
# 392                            엄청 깔끔 집 주변에 있었으면 자주 갈 터인데  0     1
# 393                                  분위기 좋은 커피 맛집!!!!!!!  0     1
# 394                                           커피 맛이 좋아요!  0     1
# 395                      조용한 분위기 좋아하면 추천 업 셋 라떼 크럼블 맛있어요  0     1
# 396                                     코코넛 라떼 달달하고 맛나요!  0     1
# 397                                커피가 너무 맛있어서 자주 가고 있어요  0     1
# 398                                               라떼 맛집!  0     1
# 399                                #방배카페 #플랫화이트 #아이스카페라떼  0     1
# 400                                 바닐라 라떼 마시고 싶어서 배달 주문  0     1
# 401                                               넘 맛있어용  0     1
# 402                                             와플도 맛나요!  0     1
# 404                                             공부하기 좋아요  0     1
# 405                                        음료랑 디저트도 맛있어요  0     1
# 406                                    맛은 쏘쏘 매장 분위기는 좋아요  0     1
# 407                    딸기 요거트 스무디랑 레몬 망고 블랙 티 완전 맛있어요!!!  0     1
# 408                                            집중하기 좋습니다  0     1
# 409                          관악 근처 카페 어디 갈까 하다가 로고도 특이하고  0     1
# 410                                  작업할 때 종종 방문하는 데 좋아요  0     1
# 411                                         넓고 공부하기 좋아요.  0     1
# 412                             근데 사람도 많아서 자리 잡기 좀 힘들어요!  0     1
# 413               지하는 찐 공부하는 분위기라 조용하고 1 층은 그래도 편한 분위기에요  0     1
# 414                           흑임자 라떼 추천받아 갔는데 너무 맛있었어요!!  0     1
# 415                                      갠적으로 아인슈페너로 유명한  0     1
# 416                                             보다 맛있었어요  0     1
# 417                                      1 층은 이야기 나누기 좋고  0     1
# 418                                        지하는 또 콘센트도 많고  0     1
# 419                개인 시간도 보낼 수 있는 공간이라서 다음에 책 읽을 때 또 와야지  0     1
# 420                          한적한 곳에 위치해서 머물고 가기 좋은 카페에요.  0     1
# 421                                             공부하기 좋아요  0     1
# 422                                                 조용해요  0     1
# 423                                             퍼플이 맛있어용  0     1
# 424                               테이크아웃 이용 시 아아 저렴해서 조아용  0     1
# 425                                                   쾌적  0     1
# 426                                          집 근처 괜찮은 카페  0     1
# 429                        아인슈페너 맛집이라 듣고 방문했는 데 역시 맛있네요.  0     1
# 430                                          분위기 좋고 깔끔해요  0     1
# 431                                     흑임자 라떼 고소하고 맛있어요  0     1
# 432                     테라스, 지하 공간까지 있어서 얘기하기도 공부하기도 좋아요  0     1
# 433                                                 맛있어용  0     1
# 435                                        음료랑 디저트 다 맛있고  0     1
# 436                                           스터디 하기 좋아요  0     1
# 437                                              커피도 맛있고  0     1
# 438                                           디저트도 맛있었어요  0     1
# 440                                       공부하기도 좋을 거 같아요  0     1
# 441                    날씨가 따뜻해져서 폴딩창? 을 통째 다 열 수 있어 좋고..  0     1
# 442                                       좋은 음악이 항상 나옵니다  0     1
# 444                                              냠냠 맛있어요  0     1
# 445                                       흑임자 라떼 진짜 맛있어요  0     1
# 446                                    가끔 흑임자 라떼 먹으러 옵니다  0     1
# 447                   이번에 딸기 라떼랑 오레오 치즈케이크도 도전해 봤는데 맛있네용  0     1
# 448                                      알바 분들도 진짜 친절하셔요  0     1
# 450    야자수 인테리어 덕분에 시원한 휴양지느낌이라면 지하는 조용하고 따뜻한 분위기에 카 ...  0     1
# 451                       동네 카페인데 주민들이 좋아하는 카페라 사람이 많아요!  0     1
# 452                                  1 층은 대화지 하는 개인 볼 일!  0     1
# 453                        그리고 흑임자 크림 라떼 너무 고소하고 맛있었어요!!  0     1
# 454                       낮에 앉아서 여유 즐기며 커피 마시기 좋은 미유 커피.  0     1
# 455                             공부하거나 집중할 일 있으면 이 카페 추천.  0     1
# 456                                   커피와 디저트가 맛있는 미유 커피  0     1
# 457                책 읽거나 공부하기 좋은 카페라고 들어 갔는데 커피 맛이 넘 좋아요  0     1
# 458                          얼 그레이 케이크도 jmt에 용 블랙 티도 맛있음  0     1
# 459          콘센트 꽂을 수 있는 곳이 여러 군데 있어서 노트북 사용하기 편한 카페였습니다  0     1
# 460                                 잔잔하게 재즈 음악도 나와서 좋았어요  0     1
# 461                                              공부하기 좋고  0     1
# 462                                          음료 디저트 맛있어요  0     1
# 463                                          자리도 많아서 좋아요  0     1
# 464                        바닐라 라떼 레몬 망고 블랙 티 케이크 다 맛있어요.  0     1
# 465                                           콘센트 있는 카페!  0     1
# 466                                               지하도 넓고  0     1
# 467                                       집중하기 좋은 분위기예요.  0     1
# 468                              무엇보다 얼 그레이 초코 케이크가 맛있네요  0     1
# 469                                             티백은 트와닝!  0     1
# 471                                           커피도 너무 맛있고  0     1
# 472                                         케이크 진짜 짱 맛나요  0     1
# 473                                   카페 분위기 좋아 유 인스타 감성  0     1
# 474                                         딸기 라떼도 맛있네 유  0     1
# 475                                  매장 분위기 좋으면서 넓고 쾌적해요  0     1
# 476                                      자몽허니블랙티 넘 맛있고!!  0     1
# 477                  추운 날에는 따뜻한 아메리카노로 꽁꽁 언 몸을 녹일 수 있지요.  0     1
# 478                                           이곳은 가성비 좋고  0     1
# 479                                 커피 맛도 예전보다 많이 좋아졌어요.  0     1
# 480                                     열 번 먹으면 한번 공짜입니다  0     1
# 481                                          딥 라떼 진짜 존 맛  0     1
# 482                                             커피 맛 있어요  0     1
# 483                                                 친절하고  0     1
# 484                                              커피 맛있어요  0     1
# 485                                          가성비 좋고 맛있어요  0     1
# 486                                            바닐라 맛있어요.  0     1
# 487                                                 친절하고  0     1
# 488                                              커피 맛있어요  0     1
# 489                                               커피 맛있고  0     1
# 490                                                 친절해요  0     1
# 491                                              항상 친절하고  0     1
# 492                                              커피 맛있어요  0     1
# 493                                                 친절하고  0     1
# 494                                              커피 맛있어요  0     1
# 495                                              항상 친절하고  0     1
# 496                                              커피 맛있어요  0     1
# 498                                              커피도 맛있고  0     1
# 499                                                 친절해요  0     1
# 501                 아메리카노가 2천 원이고 카페 라떼가 3천 원인 혜자 카페였어요!  0     1
# 502                      커피도 맛있었는 데 대용량이라서 진짜 하루 종일 먹었네요  0     1
# 503                                              싸고 맛있어요  0     1
# 504                                                    굿  0     1
# 506                                               가성비 좋고  0     1
# 507                                            양도 많고 맛있고  0     1
# 508                                                 친절해요  0     1
# 509                                        커피도 맛있고 양도 많고  0     1
# 510                                                 친절해요  0     1
# 511                                         맛있고 저렴하고 좋네요  0     1
# 512                                     숙성 라떼 고소하고 맛있습니다  0     1
# 513                                  딥 카페라때 마셨는데 너무 맛있어요  0     1
# 516                            가끔 이용하는 데 괜찮은 테이크 아웃 점입니다  0     1
# 517                   가끔 커피 맛이 나쁠 때도 있지만 최근에는 개선된 것 같아요.  0     1
# 520                                            커피 맛 괜찮아요  0     1
# 521                딥 카페 라떼가 처음 사 먹을 땐 맛있었는데 점점 맛이 아쉬워지네요  0     1
# 522                                             커피 맛집!!!  0     1
# 523                                           맛있게 잘 먹었어요  0     1
# 524                                       딥 카페 라떼 짱 맛있어요  0     1
# 527                                           맛잇어요 양 많아요  0     1
# 529    커피 논 커피 메뉴 다양하고 뭘 시켜도 실패한 적 없지만 숙성 우유로 만든 딥 카페...  0     1
# 530                                              가성비 좋아요  0     1
# 533                              양도 딱 먹기 좋은 스몰 사이즈기도하고요.  0     1
# 535                                            가격 대비 좋아요  0     1
# 538                        숙성 우유로 딥 카페 라떼 먹었는데 고소하고 맛있어요  0     1
# 539                                                 맛있어요  0     1
# 540                       미국 레트로 감성이 충만한 오브제와 인테리어 아웃테리어  0     1
# 541                            시크 한 스탭 대응과 적절한 우드톤의 분위기.  0     1
# 542    대화하기 좋은 곳에서 적절한 가격의 음료와 친한 녀석들과의 추억은 올해를 마무리하는...  0     1
# 543                                              분위기도 좋고  0     1
# 544                                             라떼도 맛있어요  0     1
# 545                                   아인슈페너 너무 맛있게 먹었어요!  0     1
# 546                                  크림이랑 커피 조화가 너무 좋았어요  0     1
# 547                    블론디는 예상 가능한 맛인데 호두 아이스크림이 너무 맛있네요  0     1
# 548                             팝업으로 방문했는 데 커피 맛있어서 놀랬네요  0     1
# 549              술집 같은 데 커피와 음료도 팔고 있음 인테리어도 이쁘고 나쁘지 않았음  0     1
# 550                                             분위기 좋아요!  0     1
# 552                                           친절해서 좋았어요!  0     1
# 553                      오늘 또 옴 저녁에 온 건 처음인데 저녁도 분위기 좋네요  0     1
# 554                             오랜만에 크림모카 마셨는 데 정말 맛있었어요  0     1
# 555                  예전에 첫 입에 넘 맛있어서 눈 번쩍 하며 마셨는 데 여전하네요  0     1
# 556               크림 먹고 나면 소화시킬 때 좀 힘든데 이건 먹고 나서도 속 편했어요  0     1
# 557                      인테리어나 굿즈들 색감을 너무 잘 뽑으셔서 분위기 미쳐요  0     1
# 558                                   그리구 올 때마다 항상 음악 좋고  0     1
# 559                                      커피 음료 디저트 다 맛있고  0     1
# 560                                                친절하세요  0     1
# 561                            포말 커피 시절도 좋았는데 지금도 넘 좋습니당  0     1
# 562                                            커피 음료 맛있고  0     1
# 563                                        음악 좋아 인테리어 멋져  0     1
# 564                          그리고 무엇보다 바스크 치즈케이크가 참 맛있어요!  0     1
# 565                                    사장님은 옛날부터 참 친절하셨고  0     1
# 566    요즘 가면 세상 힙한 분들 많이 오심 사람 안 몰릴 시간에 다녀가는 데 올 때마다 ...  0     1
# 567                              밀크티 기대 없이 시켰는 데 맛있었어요!!  0     1
# 568                             뜨거운 것도 메뉴 개발 중이시라니 기대할게요  0     1
# 569                                               분위기 좋고  0     1
# 570                                             공간이 예뻐용!  0     1
# 573                                       매장 인테리어 너무 예쁘고  0     1
# 574                                           음료도 맛있었습니다  0     1
# 575                                           플랫 화이트 강추!  0     1
# 576                                             원두가 넘 맛남  0     1
# 578                                               카페 예뻐용  0     1
# 579                                  맛있어요 커피 향 너무 좋아요!!!  0     1
# 580                                            기분 좋아지는 맛  0     1
# 581                                             분위기가 좋아요  0     1
# 582                                          분위기가 너무 좋아요  0     1
# 583                                                친절하네요  0     1
# 586                                               분위기 최고  0     1
# 587                                             분위기가 좋네요  0     1
# 588                                              커피도 맛있고  0     1
# 589                                       아인슈페너 너무 맛있습니당  0     1
# 590                                            인테리어가 멋져요  0     1
# 591                                              음료도 멋져요  0     1
# 592                                  인테리어 빈티지 하면서 고급스러워용  0     1
# 593                                                  이뻐용  0     1
# 594                           평일 저녁에 방문했는 데 역시 핫플은 다르네요.  0     1
# 596                      근처 오면 한 번 쯤 방문해 볼 만한 카페인 듯 싶어요!  0     1
# 597                                             분위기는 좋은데  0     1
# 599                                               분위기 있고  0     1
# 600                                       바스크 치즈 케익 맛있어요  0     1
# 601                                    분위기랑 맛이 진심 최고예요!!  0     1
# 602                             아인슈페너 아이리쉬 케이크까지 다 완벽했어용  0     1
# 603                                            에스프레소 크림!  0     1
# 604                                          아인슈페너도 굿 굿!  0     1
# 605                                          플랫 화이트도 괜츈!  0     1
# 606                                               분위기도 굿  0     1
# 607                                              분위기 좋아요  0     1
# 609                           구석구석 분위기가 좋아 다 앉아 보고 싶었어요.  0     1
# 610                              아메리카노 바닐라 라떼 커피류 맛있었어요!  0     1
# 611                          파인 하와이도 요즘 같은 날씨에 잘 어울리는 맛!  0     1
# 612                                              맛있었습니다!  0     1
# 613                                                 친절하고  0     1
# 614                                             커피가 맛있어요  0     1
# 615                           미국인 줄 알았어여 진짜 너무 갬성 넘치는 곳!  0     1
# 618                                                  좋아요  0     1
# 619                                           분위기도 너무 좋고  0     1
# 620                                           커피 맛도 좋아요!  0     1
# 621                                      커피 맛 인테리어 너무 좋음  0     1
# 622                                              음료 맛있어영  0     1
# 624                                               분위기 좋고  0     1
# 625                                                음악 좋고  0     1
# 626                                        커피 맛 디저트 맛 좋음  0     1
# 627                                         분위기가 더 좋아졌어요  0     1
# 629                                              커피도 맛있고  0     1
# 630                                               차도 맛있고  0     1
# 631                                           디저트도 맛있어요!  0     1
# 632                                           카페 너무 귀여워요  0     1
# 633                                강아지랑 가기 너무 좋을 것 같아요..  0     1
# 634                                          음악도 귀여워서 좋고  0     1
# 635                                              케잌도 맛있고  0     1
# 636                                            음료도 맛있었어요  0     1
# 637                                    서울 여행 가면 또 가고 싶어요  0     1
# 639                                      케이크는 너무 귀여웠습니다!  0     1
# 640             그리고 케이크 다 맛있어요 크림치즈도 많이 들어 있구 안 느끼하고 존 맛  0     1
# 641    예전에 친구와 방문했을 때 쿠키랑 케이크가 너무 맛있었어서 이 번에 부모님께 드릴 ...  0     1
# 642    보통 인테리어가 예쁘면 맛은 보통이고 그 낭 그 인테이어를 위해서 간다는 편견이 있...  0     1
# 643               단순히 귀엽기만한 것이 아니라 맛도 정말 보장되서 너무 너무 좋아요.  0     1
# 644                         다음에는 친구 생일 케이크 주문하러 방문하겠습니다!  0     1
# 645                                              케이크 예쁘고  0     1
# 646                                    쿠키들도 예뻐서 선물하기 좋아요  0     1
# 648                                      케이크 디자인도 너무 예쁘고  0     1
# 649                                    레터링까지 마음에 쏙 들어요!!  0     1
# 650                                 예쁜 케이크 만들어 주셔서 감사합니다  0     1
# 651                    그리고 블루베리 크림 치즈 케이크 진짜 맛있습니당!!!!!!  0     1
# 652                    너무 너무 너무 귀여워요 아직 못 먹었는 데 먹기 아깝습니다  0     1
# 653                                      진짜 너무 너무 맛있어요!!  0     1
# 654                                      케이크랑 빵 진짜 맛있어요!  0     1
# 655                                    초코 라떼 완전 맛있어요!!!!  0     1
# 656                                        인테리어 귀여워서 좋아요  0     1
# 657               기념일로 도시락 케이크했는데 완전 만족스러웠습니다 케익 완전 귀여워요  0     1
# 658                                              너무 귀여워요  0     1
# 659                     사진이 안 이쁘게 나왔는데 케익 진짜 진짜 이쁘고 맛있어요  0     1
# 660                                 맞춤 레터 링 되는 것도 너무 좋아요  0     1
# 661                                  인테리어가 독특해 사진 찍기 좋아요  0     1
# 662                                      알록달록 너무 예쁜 곳이에요  0     1
# 663                                              아기자기해요!  0     1
# 664                                         아기자기 예쁜 곳이예요  0     1
# 665                          맛은 특별하진 않고 자세한 건 블로그에 작성할께요  0     1
# 666                                    귀엽고 맛있는 디저트가 가득해요  0     1
# 667                                   공간도 넓찍해서 쉬다 가기 좋아요  0     1
# 668                       생각보다 더 작은 사이즈였는데 디자인이 너무 귀여워요!  0     1
# 670                   케이크가 너무 예뻐서 아이부터 어른들까지 좋아하실 것 같아요.  0     1
# 671                       맛은 보지 못 해서 모르지만 너무 귀여워서 만족입니다.  0     1
# 673                                        맛은 보통이지만 예뻐요.  0     1
# 674                                   디자인이 너무 귀엽고 맛있습니다!  0     1
# 675                                             레터링도 이뻐요  0     1
# 676                                             예쁘고 맛있어용  0     1
# 677                            조카 생일이라 예약해서 먹었는데 너무 맛있네요  0     1
# 678         나중에 나오고 나서 보니까 이름을 잘못 쓰셨더라구요… 다음엔 제대로 써 주세요!  0     1
# 679                                        케이크는 맛있게 먹었대요  0     1
# 680                                                  이뻐요  0     1
# 681    컨셉이 귀여워서 소녀 감성 있으신 분들 좋아하실 꺼 같아요 케잌은 오레오초코는 진짜...  0     1
# 684                                             커피도 맛있었고  0     1
# 685                                      디저트가 예쁘면 모습에 비해  0     1
# 686        맛은 그저 그런 곳이 많던데 해피 베어 데이는 케이크도 촉촉하고 진짜 맛있었어용!  0     1
# 687                               여기 카페 진짜 귀엽고 맛있고하다 함..  0     1
# 688                                          카페가 너무 귀여워요  0     1
# 689                                            디저트도 맛있어요  0     1
# 690                                      디저트가 대체적으로 맛있네요  0     1
# 691                                 음료도 다른 곳보다 저렴하고 맛있어요  0     1
# 693    받기 전에 레터링 확인하고 포장해 주셨고 조금 비싼 감이 있지만 선물용으로 좋은 것...  0     1
# 694                                  케익도 쿠키도 너무 귀엽고 맛있어요  0     1
# 695                                          케이크가 너무 예뻐요  0     1
# 696                                 예쁜데 맛도 있어서 자주 갈 듯 해요  0     1
# 697                           카페는 이쁜데 가격은 비싸고 별로 안 친절하세요  0     1
# 698                                             인테리어 예쁘고  0     1
# 699                                         케익도 아기자기해요!!  0     1
# 700                                          선물하기 너무 좋아요  0     1
# 701                                                 맛있어요  0     1
# 704                                               매장도 넓고  0     1
# 705                                           인테리어가 귀여워요  0     1
# 706                           음료 가격, 디저트 가격도 합리적인 편입니다!!  0     1
# 707                            낮에 가면 사진 찍기도 좋은 공간일 것 같네요  0     1
# 708                                             디저트도 귀엽고  0     1
# 709                                          야외 공간이 좋았어요  0     1
# 710                                          카페가 너무 귀여워요  0     1
# 711                                                 맛있어요  0     1
# 712                                           케이크 넘 귀여워요  0     1
# 713    브샤용 케이크 주문했는 데 너무 예쁘고 귀염뽀짝해서 친구가 넘넘 맘에 들어했어요 실...  0     1
# 715                 하트 초나 포인트 초 꼭 사서 꽂아 주세요 너무 맛있고 귀여워요!  0     1
# 716                                    귀여운데 맛도 있어서 행복했어용  0     1
# 718                                   하지만 맛있고 친절함 또 갈 듯?  0     1
# 719                                              맛있얶어요!!  0     1
# 720                                            케익도 넘 귀엽고  0     1
# 721                                          카페 내부도 이쁮니다  0     1
# 722                                      케이크가 너무 색감이 예쁘고  0     1
# 723                    토끼 디자인이 있어서 토끼띠 아기 임밍 아웃할 때 썼어요!!  0     1
# 724           시부모님도 케이크 너무 예쁘다고 좋아하시고 맛도 좋아서 좋은 시간 보냈답니다  0     1
# 726                                               빵도 맛있고  0     1
# 727                                             커피도 맛있어요  0     1
# 728                                            뷰가 정말 멋져요  0     1
# 729                                           오션뷰 너무 예쁘고  0     1
# 730                                      카페 분위기도 취향저격이에요  0     1
# 734                                           인테리어가 예뻐요.  0     1
# 735                                            음료가 맛있어요!  0     1
# 736                    빵 종류가 많아요. 배뷸러서 못 먹었는 데 먹어 보고 싶어요  0     1
# 737                              진동 벨이 있었으면 좀 더 편할 거 같아요  0     1
# 739                         음료를 많이 시켰는 데 엘레베이터가 있어서 편했어요  0     1
# 741                                 주말이라 사람들이 많아서 좀 시끌벅적  0     1
# 744                       샤인머스켓에이드 코코넛이 들어서 씹는 맛도 있구 좋아요  0     1
# 745                                               뷰가 좋아요  0     1
# 746                                                   씨뷰  0     1
# 747                                      영 일대도 바라보는 예쁜 뷰  0     1
# 748                                    포스코 야경이 예쁘게 보이는 곳  0     1
# 749                                           커피 너무 좋습니다  0     1
# 750                                              분위기도 좋고  0     1
# 751                                   매장도 넓어서 대화하기 좋았어요!  0     1
# 753                                            화장실도 깔끔하고  0     1
# 754                                              빵도 맛있네요  0     1
# 755                                           가격대가 좀 있어요  0     1
# 758                                                깨끗하고.  0     1
# 759                                                전망 좋고  0     1
# 760                                        영 일대 해수욕장 인근.  0     1
# 763                            포항 가면 꼭 가 봐야하는 카페 리스트 1 순  0     1
# 764                                  맛있는 데 조금 비싼 감은 있어요.  0     1
# 765                                             분위기는 좋은데  0     1
# 767                                               사람 많음.  0     1
# 768                                           디저트 종류 많음.  0     1
# 769                                                 맛있음.  0     1
# 770                                딸기가 좋아 크림이… 너무 맛있습니다!  0     1
# 772                                    주말이라 사람 진짜 진짜 많네요  0     1
# 773                                   디저트류 맛있구 음료도 괜찮아요!  0     1
# 774                                                 뷰 좋고  0     1
# 775                                              인테리어 좋고  0     1
# 776                                               매장이 넓음  0     1
# 778                                             경치가 좋아요.  0     1
# 779                                             커피도 맛있지만  0     1
# 780                                          여기 빵 맛집입니다.  0     1
# 782                                  빵 겁내 맛있음 재방문 의사 있어요  0     1
# 784                                     음료나 케이크는 맛있었습니다.  0     1
# 785                                          화장실도 깨끗했어요!  0     1
# 786                                           깔끔하고 예쁜 카페  0     1
# 788                                        클쓰 분위기 너무 이쁘고  0     1
# 789                                          포토스팟 짱 많구..  0     1
# 790                                                뷰가 좋고  0     1
# 791                               빵류도 함께 있어서 간단히 식사하 좋네요  0     1
# 792                               아몬드 크림 라떼랑 자두에 이드 먹었어요  0     1
# 793                                                 맛있어요  0     1
# 794                                             오션뷰가 좋아요  0     1
# 795                                         아메리카노 빵 맛집이죠  0     1
# 799                                             빵이 맛있어요.  0     1
# 800                                              직원 친절해요  0     1
# 803                                 매장이 크고 넓은 데다 주차하기 좋고  0     1
# 804                                              전망이 좋아요  0     1
# 806                                       커피 브레드와 바다 경치…  0     1
# 807                                             뷰가 넘 이뻐요  0     1
# 808                                             케이크 맛있어용  0     1
# 809                            맘모스 빵이 지금까지 먹어 본 빵 으뜸이에요.  0     1
# 811                                               뷰 좋아요!  0     1
# 812                                         시그니처 커피 맛있어용  0     1
# 813                                                  예쁘고  0     1
# 814                                              커피 맛있어요  0     1
# 816                                 풍경이 쵝오 대형 카페 인증합니다..  0     1
# 817                              카페 안에서 바다도 보이고 넓어서 좋아요.  0     1
# 818                                            음료도 다 맛있고  0     1
# 819                                     베이커리 종류도 다 맛있습니다  0     1
# 820                                             뷰도 넘 좋아여  0     1
# 821                         제가 갔을 땐 평일이라 조용하고 쉬기 너무 좋았어요  0     1
# 822                                               빵도 맛있고  0     1
# 823                                             음료도 맛있어요  0     1
# 824                                    초코케익빼고 빵이 너무 맛있어용  0     1
# 825        무엇보다 이 곳은 뷰와 사진 찍기 좋은 곳 커피 빵 모두 맛집이예요 주차하기 좋고  0     1
# 827                                   주중에 가니 조용하고 넘 좋으네요  0     1
# 829                                               뷰가 좋아요  0     1
# 830                                              좋아요 경치가  0     1
# 831                                            뷰가 엄청 좋아요  0     1
# 832                                        어니언크로와상 맛있었어요  0     1
# 833                              헤이즐넛 라떼도 시그니쳐 메뉴도 괜찮았어요  0     1
# 834                                             음료 맛있어요.  0     1
# 836                                             뷰가 넘 좋아요  0     1
# 841                                시그니쳐 음료도 너무 맛있고 부드럽네요  0     1
# 842                                                뷰도 좋고  0     1
# 843                                             커피도 맛있어요  0     1
# 844                                             뷰 너무 좋아요  0     1
# 845                                          친절 커피가 맛있어요  0     1
# 847                                    언제나 다시 찾아도 뷰가 좋아요  0     1
# 848                                       주변 환경이 더 좋아졌어요  0     1
# 849                          평일에 방문했는 데 주차하기 좋고 조용하니 좋네요  0     1
# 851                                       빵 종류가 다양해서 좋아요  0     1
# 852                                         분위기, 뷰가 좋아요.  0     1
# 853                                       뷰 너무 좋구 빵 맛있어요  0     1
# 855                                         빵 종류 많아서 좋네요  0     1
# 857                                                뷰 짱!!  0     1
# 858                                               뷰가 멋져요  0     1
# 859                                                 뷰가 굿  0     1
# 860                                              브레드 좋아요  0     1
# 861                                               커피 좋아요  0     1
# 862                                  남편이랑 둘이 오붓하게 오기 좋네요  0     1
# 863                                              뷰 맛집입니다  0     1
# 865                              간절곶 구경하면서 티타임 즐기기엔 최고네요  0     1
# 866                            커피도 뷰도 굿 맛잇어요 고숩 한 원두 좋아용  0     1
# 867                                                친절합니다  0     1
# 868                                             깔끔하고 좋아요  0     1
# 873    팥빙수 가격 보고 읭 했는 데 4 인이 먹을 양이었네요 견과류에 인절미 가루 팥 듬...  0     1
# 874                                       간절곶 바로 앞이라 좋네요  0     1
# 875                                               뷰가 좋아요  0     1
# 876                                               뷰가 굿굿굿  0     1
# 877                                              뷰 맛집입니다  0     1
# 878                                              뷰가 좋은 곳  0     1
# 879                                     넓은 공원이 옆에 있어 좋아요  0     1
# 880                                           간절곶 뷰가 멋져요  0     1
# 881                 여직원들 말투가 친절한 척하지만 귀찮은 티 팍팍 내는 간호사 말투  0     1
# 883                                              위치는 좋음   0     1
# 885                                             뷰 맛집이 예여  0     1
# 887                                             조용하니 좋네요  0     1
# 890                                            뷰가 너무 좋아요  0     1
# 891                        명선도 가기 전에 들려서 커피 마시기 좋은 것 같아요  0     1
# 892                                              커피도 맛있고  0     1
# 893                                               뷰도 멋지고  0     1
# 894                                               너무 맛있고  0     1
# 895                                              분위기 좋아용  0     1
# 896                                         좋은 위치의 전망 좋은  0     1
# 898    맛은 있는 데 처음에 시킬 때 오래 걸릴 거 같다고 말해 주면 더 좋았을 거 같습니...  0     1
# 899                    다양한 디저트 음료랑 같이 바다 보면서 즐길 수 있어 좋아요  0     1
# 900                                              뷰 맛집입니당  0     1
# 901    명선 도에 갈려고 왔다가 너무 일찍 도착해서 들렸는데 왜인걸 분위기 커피 맛집이였다...  0     1
# 902                                                뷰 좋아요  0     1
# 904                                              분위기 좋아용  0     1
# 905                                                맛있는 집  0     1
# 906                                                뷰도 좋고  0     1
# 907                                             커피도 맛있어요  0     1
# 908                                                 친절해요  0     1
# 909                             바다 앞에 좋은 카페가 있어서 좋았습니다!!  0     1
# 910                                        내부 분위기도 좋아요!!  0     1
# ...
# 9938                                     상암 점 꼭 방문해야겠어요!  0     1
# 9939                             테라로사보다는 확실히 급이 더 높은 카페!  0     1
# 9941                                           한 번이면 됐어요  0     1
# 9942                                 대표 메뉴긴한데 많이 신맛이 났어요  0     1
# 9943     카페에 가면 셀프로 계산하는 것이 익숙해져 있어서 오랜만에 카페다운 곳에 다녀온 마음  0     1
# 9945                                          커피 맛도 좋았어요  0     1
# 9948                                             빵도 맛있어요  0     1
# 9949                                       주차장도 어마어마 합니다  0     1
# 9950                                         제 최애 커피숍입니다  0     1
# 9951                                     시간 날 때마다 가고 있어요  0     1
# 9952                                                명불허전  0     1
# 9953                                               최고입니다  0     1
# 9954                                              분위기 좋고  0     1
# 9956                             하우스 블렌딩 커피 주문했는데 맛 좋습니다  0     1
# 9957                                         커피 마시기 편안하고  0     1
# 9958                                            커피 맛 좋아요  0     1
# 9959                                            커피 맛 좋네요  0     1
# 9960                                           커피 맛있네요!!  0     1
# 9961                                          바다 보여서 좋아요  0     1
# 9962                                     이 곳만의 분위기가 있어요!  0     1
# 9963                                        커피 맛은 물론 좋구요  0     1
# 9967   기다리세요! 명령조는 기본.. 박이추님 커피 연구도 좋지만 직원 교육도 신경 쓰셔야...  0     1
# 9968                                           커피 맛 있어요.  0     1
# 9969                                    강릉 가면 들리는 커피 맛집!  0     1
# 9970                                          오늘도 행복한 시간  0     1
# 9971       소문으로만 듣던 박이추커피 자메이카 블루 마운틴 마셨는 데 좋아서 원두 구매했어요  0     1
# 9974                                      비엔나 커피 너무 맛있어요  0     1
# 9976   여름에도 지나가 봤는데 항상 주차장에 차가 많아 선뜻 들어가 볼 엄두가 나지 않았는...  0     1
# 9978                                             커피도 맛있고  0     1
# 9979                                           서비스도 좋아요.  0     1
# 9980   괜찮다는 평이 많아 가 보게 됐습니다. 제가 평소에 편의점에서 사 먹던 강릉 커피가...  0     1
# 9981   요새 게이샤가 대세라 한 번 시켜 봤는데 와!!! 정말 다 마실 때까지 맛있다를 연...  0     1
# 9983                      강릉 커피 커피믹스도 행사하고 있어 냉큼 사 왔습니다.  0     1
# 9984                               강릉 오시면 꼭 와 봐야할 커피 맛집.  0     1
# 9985                              조용하게 커피 향을 즐길 수 있는 카페.  0     1
# 9987                                           커피가 부드러워요  0     1
# 9988                                             커피숍 예뻐요  0     1
# 9989                                   강릉 갈 때마다 들르는 곳이에요  0     1
# 9990                   오늘의 커피 시다모는 깨끗하고 산미와 단맛이 풍부한 커피에요  0     1
# 9992                                 가을 날씨에 야외 데크 더 멋졌어요  0     1
# 9993                                       오늘의 커피도 맛있었구요  0     1
# 9994                커피는 양이 작고 비쌌지만 진한 맛을 좋아하는 제겐 괜지 않았어요  0     1
# 9995                                          예가체프 짱이었어요  0     1
# 9996                                                좋습니다  0     1
# 9997                                               커피 굿.  0     1
# 9998                                       아이스크림 넘나 맛있어횹  0     1
# 9999                                              커피도 짱짱  0     1
# 10000                                           커피 맛 있어요  0     1
# 10001                                 멋진 분위기를 원하신다면 2 층.  0     1
# 10003                        요즘에는 주로 오늘의 커피 테이크아웃하러 갑니다.  0     1
# 10004                                     모닝 세트와 커피 맛있어요  0     1
# 10005                                                조아용  0     1
# 10007            감동적인 대접 받구옴 깔라만시도 맛잇구 컵두 뷰도… 분위기도 체고였어용  0     1
# 10008              드립 커피를 잘 몰라서 맛 평가는 어렵지만 은은하게 잘 마셨습니다.  0     1
# 10010                                              드립 최고  0     1
# 10011               층마다 직원이 상주해서 주문 받고 커피도 가져다 주셔서 좋았어요!  0     1
# 10012                        바다도 넓은 창으로 볼 수 있어서 기분도 좋았구요  0     1
# 10013                                       커피도 참 맛있었습니당  0     1
# 10016                                        커피 향과 맛이 좋고  0     1
# 10017                                     아이스크림도 잘 먹었습니당  0     1
# 10018                                              맛있어 오  0     1
# 10019                                  드립커피 가격 대비 너무 맛있고  0     1
# 10020                                              몽블랑 짱  0     1
# 10021                                             커피 맛있고  0     1
# 10022                                          친절하진 않습니다  0     1
# 10024                평일 가서 대기 없이 시다모드립은 역시 맛과 향이 너무 좋았구요  0     1
# 10025                    이탈리안 아이스는 약간 더치 향이 나는 찐한 좋은 맛 요  0     1
# 10028   파나마 게이샤 커피랑 자 메이커 블루 마운틴 마셨는 데 자메이카 블루 마운틴 맛있었어요  0     1
# 10029                                                 깔끔  0     1
# 10031        파나마 게이샤가 얼마나 향과 바디 감이 좋은데 그런 걸 다 무시하는 핸드드립…  0     1
# 10032                                예가체프도 가장 기본인데도 불구하고  0     1
# 10036                         진심으로 많이 많이 아쉬운 1 세대 커피네요..  0     1
# 10037                                          커피 넘 맛있어요  0     1
# 10039                               커피는 맛있었지만 긴 웨이팅이 아쉽고  0     1
# 10040                               직원 분들 친절한 것도 잘 모르겠어요  0     1
# 10041                                  연휴라 사람도 많고 바쁘셨겠디만  0     1
# 10042                                          한 번으로 만족!  0     1
# 10044                            바나나 타르트가 커피와 정말 잘 어울렸어요  0     1
# 10045                                    커피는 언제 먹어도 맛있네요  0     1
# 10049                             정말 박이추커피는 커피 맛의 정석입니다!  0     1
# 10050  웨이팅 룸을 따로 둬서 조금 기다리긴했어도 정작 커피 마실 땐 주문도 직접 와서 받...  0     1
# 10051  커피를 테이블까지 가져다 주시니 정말 쾌적하고 여유 있게 커피를 즐길 수 있어서 좋았어요  0     1
# 10052  추가로 강릉 커피 너티 크림 맛 컵으로 된 거랑 강릉 커피 라떼 파우치도 밭았는데 ...  0     1
# 10053                              강릉 커피 라떼도 고소하고 맛있었어요.  0     1
# 10054  강릉 커피가 박이추랑 콜라 보한 줄 몰랐는 데 먹어 보니 맛있어서 자주 찾을 것 같아요.  0     1
# 10055                                 다음에는 카페도 방문하고 싶어요.  0     1
# 10058                                      직원들이 친절하지 않아요  0     1
# 10059                                강릉 커피 중에 유명해서 가 봤어요  0     1
# 10061                                      커피, 디저트도 맛납니다  0     1
# 10062   딸기 케잌 왜 다른 케잌은 일찍 품절이라 못 먹었어 요 담에 도전 커피 정말 맛있습니다  0     1
# 10063  개인적으로 클래식한 느낌의 예가체프. 그니까 십 몇 년도 더 전에.. 핸드드립은 여...  0     1
# 10066                             커피가 맛있러서 갔는 데 너무 오래 걸림  0     1
# 10067                                              커피 맛집  0     1
# 10068                                무척 오랜만에 왔는데 여전히 좋네요  0     1
# 10069                            사람 많은 시간대에 가면 웨이팅하고 있어요  0     1
# 10070                                           웨이팅 있어요.  0     1
# 10072                                 커피는 따뜻한 게 종류가 다양하고  0     1
# 10075                          디저트는 전체적으로 덜 달고 건강한 느낌입니다  0     1
# 10076                                        직원 분들 친절하세요  0     1
# 10077                                      2 층 뷰가 아주 예뻐요  0     1
# 10078                                              커피 맛집  0     1
# 10082                                          브런치 좋았습니다  0     1
# 10086                        첫 방문이였는 데 커피 너무 맛있게 잘 마셨어요.  0     1
# 10087                            시다모와 비엔나 등등 커피 너무 맛있어요!  0     1
# 10091               개인적으로 고흐가 즐겨 먹엇다는 예멘바니마 타르가 제일 좋 앗아요  0     1
# 10092                                            분위기 좋아요  0     1
# 10093                                               괜찮아요  0     1
# 10094          디카페인 아아가 7천원이라 했는데 다른 곳 디카페인과 다르게 진하고 좋네요  0     1
# 10095          커피에서 오만 가지 맛이 느껴지네요... 아름답게 표현하면 맛이 픙부하네요  0     1
# 10096                                      생각보다 친절하진 않지만  0     1
# 10097                                   커피랑 디저트가 너무 맛있어요  0     1
# 10098                                    모닝 세트 잘 먹고 갑니다.  0     1
# 10099            주문 후 음식이 나올때까지 시간이 걸려요 이용하실 분께서는 참조하세요!  0     1
# 10100                                        커피가 정말 맛있어요  0     1
# 10101                     아침 모닝 세트 먹었어요. 모닝 세트 커피는 평범해요.  0     1
# 10102                 강릉의 원조 커피 장인 중 한 분이라는 박이추 바리스타의 카페  0     1
# 10103                                  이미 너무나도 유명한 곳이에요.  0     1
# 10104                                    직원 분들 여전히 친절하시고  0     1
# 10106                                   커피도 음료도 참 맛있습니다.  0     1
# 10107                             강릉 간 김에 돌체테리아 휘낭시에 뇸!!  0     1
# 10109  12시에 현장 구매로 15개 구매했는 데 서비스로 3개 더 챙겨 주셨어요! 생각도 ...  0     1
# 10110                    일반 휘낭시에 보다 크구 식감은 약간 달랐는데 맛있습니다  0     1
# 10113  딸아이가 인스타에서 보고 여행 간 김에 방문했습니다만 가격 인테리어 친절 등등 정말...  0     1
# 10114                                  힌 번 맛본 것으로 만족합니다.  0     1
# 10116                                           휘낭시에 존맛탱  0     1
# 10117                               강릉 놀러 간 김에 갔는데 맛있어요!  0     1
# 10118                                           매장도 예뻐요.  0     1
# 10119                                 너무 가 보고 싶었던 돌체테리아!  0     1
# 10120                                       드디어 방문해 봤습니다  0     1
# 10122                                                맛나용  0     1
# 10124                                            너무 맛있어용  0     1
# 10126                                   직원 분들도 친절하시고 좋아요  0     1
# 10128                                        그래도 또 먹 싶네요  0     1
# 10129                               달달 이 돟아하는 제게는 완전 좋아요  0     1
# 10130                                           진짜 맛있어요!  0     1
# 10131                                             대박!!!!  0     1
# 10132  먹물 치즈 식빵 등 치즈 식빵 종류와 훠낭시에 등 여태껏 맛볼 수 없었던 완전 색다...  0     1
# 10133                                          진짱 짱! 이네요  0     1
# 10138                                            빵 넘모조어욥  0     1
# 10141                                        픽업 예약해서 갔어요  0     1
# 10142                    강릉 오면 꼭 들려서 먹어 볼 만한 디저트 가게입니다!!  0     1
# 10143                                            강릉 온 기념  0     1
# 10144                                            빵이 맛있어요  0     1
# 10145                                       예약 픽업 굿 맛 나요  0     1
# 10146                                          휘낭시에 맛있어요  0     1
# 10147                                               맛있네요  0     1
# 10148                                 오랜만에 갔는 데 여전히 맛있어요  0     1
# 10150                                            또 먹고 싶네  0     1
# 10152           크기는 손바닥만 하게 작지만 가격은 창렬 한 에쎈에스 유명 맛집 맛입니다  0     1
# 10153                        SNS에서 엄청 유명해서 솔직히 기대가 컷는데..  0     1
# 10154                         음 한 번 먹어 본 거로 만족!한 맛이었습니다.  0     1
# 10155  요즘 서울에도 재료 풍부하게 넣은 빵들이 많은데 빵 순이라 여러 유명 빵집을 직접 ...  0     1
# 10160  디저트 맛집이라고 해서 방문했는 데 포장으로 거의 다 팔리고 남는 것에 그 타르트랑...  0     1
# 10162                                        쫀득쫀득 맛있어요!!  0     1
# 10163                                          강릉 디저트 맛집  0     1
# 10165                              맛있기는 하지만 주문 속도도 느립니다.  0     1
# 10167  현장에서는 구매할 수 있는 것이 많지 않은 듯해 아침 9시 예약 성공해서 픽업으로 ...  0     1
# 10168                 빵도 빵인데 오도독 들어간 휘낭시에들하고 돌낭스크 너무 맛있음  0     1
# 10169                 매일 라인업이 조금씩 다르니 다음에 강릉 가게 되면 또 사야지  0     1
# 10171                                     그렇게 친절하지는 않았어요  0     1
# 10172                                       휘낭시에 쫀득!!!!!  0     1
# 10176                                예약 시스템이 잘 돼 있어서 좋아용  0     1
# 10177                                         가게가 너무 귀엽구  0     1
# 10178                                           깔끔 해여!!!  0     1
# 10179                                      직원분들 너무 친절하시고  0     1
# 10180                                        믿고 먹는 돌체테리아  0     1
# 10182  30분 훌쩍 시간이 가고 많은 분들이 계셨습니다 여행 와서 시간이 넉넉했기에 휘낭시...  0     1
# 10184                       달달한 걸 좋아하는 분들에게는 잘 맞을 것 같습니다  0     1
# 10186                                           커피는 맛있는뎅  0     1
# 10188                           카페 주변 분위기도 좋고 커피 마시기 좋아요  0     1
# 10191                                            커피도 맛있고  0     1
# 10192                                         디저트도 맛있어요!  0     1
# 10193                                          조용한 한옥 카페  0     1
# 10195                        여기 카페 예쁘고 다른 곳보다 늦게까지 운영해요!  0     1
# 10197                                          사장님 친절하시고  0     1
# 10198                                            분위기 좋아요  0     1
# 10199                            편안하고 오래 머물다 가고 싶은 그런 느낌  0     1
# 10200                                            음료도 맛있고  0     1
# 10201                                            분위기도 좋고  0     1
# 10202                                         뷰도 갬성갬성해요!  0     1
# 10204                                       커피숍 커피 맛은 만족  0     1
# 10206                오월 커피 좁은 골목 안에서 일본 가옥을 만난 느낌 건물 예뻐요  0     1
# 10207                                   바닐라 아인슈페너도 맛있었어요  0     1
# 10208                                100년 된 적산 가옥 건물이에요.  0     1
# 10210  강릉 여행 가셔서 저녁에 커피 한 잔 할 수 있는 카페 찾고 계시다면 여기 오시면 되요.  0     1
# 10211                                          커피 맛도 괜찮고  0     1
# 10212                                       분위기도 너무 좋아요.  0     1
# 10213                  콜택시 부르면 바로 카페 앞까지 와 줘서 이동하기도 편해요.  0     1
# 10214                                            분위기도 좋고  0     1
# 10215                                        케이크 너무 맛있어요  0     1
# 10216                                           분위기가 좋아요  0     1
# 10217                                          카페 너무 이뻐요  0     1
# 10218                                     바닐라아인슈페너가 맛있어요  0     1
# 10219                                                좋아용  0     1
# 10220                                           커피가 맛있어요  0     1
# 10223                                        아인슈페너 맛 좋아요  0     1
# 10224                            명주동 권역 8개 인기 카페 중 하나인 곳  0     1
# 10225                                   100년 넘은 적산 가옥 개조  0     1
# 10232                                           아늑한 카페네요  0     1
# 10234                           일본 갬성 좋아하신다면 여기 오시면 좋겠어요  0     1
# 10236                                  모카 커피는 보통의 맛이었습니다  0     1
# 10237                                                  굿  0     1
# 10238                                         맛있게 잘 먹었어용  0     1
# 10239                                     워낙 유명해서 방문했어요.  0     1
# 10240                                        커피 맛보단 분위기!  0     1
# 10241                                워낙 유명하고 와 보고 싶던 카페!  0     1
# 10242                   적산 가옥을 그대로 살려서 옛날 가옥 느껴 보기에 좋아요.  0     1
# 10245                         당근 케이크 아이디어 좋아요! 크림도 맛있습니다  0     1
# 10246                        인테리어가 예뻐서 여름에 꼭 다시 와 보고 싶어요  0     1
# 10248                    밀크티를 좋아하는 사람이 가야지 빛을 보는 카페 같습니당  0     1
# 10250                                  바게트는 짭짤 고소하니 맛있어요  0     1
# 10251                                         느낌 대박입니다!!  0     1
# 10252                                    너무 친절하게 설명해 주시고  0     1
# 10253                                      음료도 독특하고 맛있어요  0     1
# 10254                                          밀크티 맛있어요.  0     1
# 10258                              명란 감자 바게트랑 연유 커피 맛있어요  0     1
# 10259                                slow life of wonder  0     1
# 10261                                  한옥 개조 카페고 분위기 좋아요  0     1
# 10262  제가 먹은 것은 CODIAl TEA 중에 로즈힙 히비스커스 hot로 먹었는데 취향저...  0     1
# 10263  적당한 달달함과 상큼 상큼한데 텁텁하지 않고 따뜻하게 먹어도 맛있더라구요 다음엔 우...  0     1
# 10264                                         사장님도 친절하시고  0     1
# 10265                       한옥을 개조해서 만든 작은 카페인데 분위기 좋아요.  0     1
# 10269                      바게트가 꽤 맛있어서 셋트로 먹길 잘했다 생각했어요.  0     1
# 10270          커피도 맛있고 쑥 밀크 마셨는데 달달하고 향도 좋아서 맛있게 잘 먹었어요.  0     1
# 10271                                명란 감자 바게트랑 밀크티 맛있어요  0     1
# 10272                                       분위기가 진짜 좋아요.  0     1
# 10273                                        고요하고 한옥 느낌.  0     1
# 10275                            구옥의 분위기가 잘 살아 있어서 좋았어요.  0     1
# 10277                 혼자 조용히 머무를 수 있는 카페를 검색해 보다가 가게 됐어요  0     1
# 10279  카페 뒤뜰 쪽에 가서 앉게 됐는데 날씨가 흐려서인지 다른 손님들은 대부분 카페 안과...  0     1
# 10280      여유롭게 커피랑 바게트랑 먹으면서 힐링할 수 있는 시간을 가질 수 있어서 좋았어요  0     1
# 10281                       전부 다 너무 맛있게 먹었어요 빵도 커피도 맛있어요  0     1
# 10282                                             우유 맛집.  0     1
# 10283                                           인테리어 맛집.  0     1
# 10284                                             분위기 맛집  0     1
# 10285                                      인테리어가 너무 멋져요!  0     1
# 10286         오래 전부터 너무 가 보고 싶었던 카페였는데 미루고 미루다 이제서야 왔네요!  0     1
# 10287            사진에서 보던 느낌 그대로 고즈넉하고 조용했어요 딱 제가 좋아하는 느낌  0     1
# 10288                                       강릉 오면 꼭 추천!!  0     1
# 10290             아메만 먹었는데 다음에 갈 땐 명란 감자 바게트도 같이 먹어 볼라구요  0     1
# 10292                                     그래도 음료는 맛있었습니다  0     1
# 10294                                    곳곳에 포토존도 있고 이뻐요  0     1
