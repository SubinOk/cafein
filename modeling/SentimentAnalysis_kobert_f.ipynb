# %%
# !pip install transformers
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting transformers
#   Downloading transformers-4.25.1-py3-none-any.whl (5.8 MB)
#      |████████████████████████████████| 5.8 MB 27.9 MB/s
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.8/dist-packages (from transformers) (6.0)
# Collecting tokenizers!=0.11.3,<0.14,>=0.11.1
#   Downloading tokenizers-0.13.2-cp38-cp38-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (7.6 MB)
#      |████████████████████████████████| 7.6 MB 55.1 MB/s
# Requirement already satisfied: requests in /usr/local/lib/python3.8/dist-packages (from transformers) (2.23.0)
# Requirement already satisfied: tqdm>=4.27 in /usr/local/lib/python3.8/dist-packages (from transformers) (4.64.1)
# Requirement already satisfied: numpy>=1.17 in /usr/local/lib/python3.8/dist-packages (from transformers) (1.21.6)
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.8/dist-packages (from transformers) (2022.6.2)
# Requirement already satisfied: filelock in /usr/local/lib/python3.8/dist-packages (from transformers) (3.8.2)
# Collecting huggingface-hub<1.0,>=0.10.0
#   Downloading huggingface_hub-0.11.1-py3-none-any.whl (182 kB)
#      |████████████████████████████████| 182 kB 63.5 MB/s
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.8/dist-packages (from transformers) (21.3)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /usr/local/lib/python3.8/dist-packages (from huggingface-hub<1.0,>=0.10.0->transformers) (4.4.0)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in /usr/local/lib/python3.8/dist-packages (from packaging>=20.0->transformers) (3.0.9)
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/lib/python3.8/dist-packages (from requests->transformers) (3.0.4)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.8/dist-packages (from requests->transformers) (2022.12.7)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /usr/local/lib/python3.8/dist-packages (from requests->transformers) (1.24.3)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.8/dist-packages (from requests->transformers) (2.10)
# Installing collected packages: tokenizers, huggingface-hub, transformers
# Successfully installed huggingface-hub-0.11.1 tokenizers-0.13.2 transformers-4.25.1

# %%
import pandas as pd
import numpy as np
import urllib.request
import os
from tqdm import tqdm
import tensorflow as tf
from transformers import BertTokenizer, TFBertModel
from sklearn.model_selection import train_test_split

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# 데이터 불러오기
data = pd.read_csv('/content/drive/MyDrive/공장/train_fff.csv')
# data = data.drop('Unnamed: 0', axis=1)
data = data.sample(frac=1)
data['label'].value_counts()
# Out:
# 2    700
# 1    700
# 0    700
# Name: label, dtype: int64

# %%
# data.loc[data['label']==0]

# %%
train_data, test_data = train_test_split(data, test_size=.2)

print('훈련용 리뷰 개수 :', len(train_data))
print('테스트용 리뷰 개수 :', len(test_data))
# Out:
# 훈련용 리뷰 개수 : 1680
# 테스트용 리뷰 개수 : 420

# %% [markdown]
# ---

# %%
# # GPU 환경 설정
# # assert tf.test.is_gpu_available() == True, 'GPU 설정을 확인하세요.'
# print(tf.config.list_physical_devices('GPU'))
# print(tf.config.list_logical_devices('GPU'))

# %%
tokenizer = BertTokenizer.from_pretrained("bert-base-multilingual-cased")
# Out:
# Downloading:   0%|          | 0.00/996k [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/29.0 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/625 [00:00<?, ?B/s]

# %%
def create_examples(df):
    example = []
    label = []
    for (i, row) in enumerate(df.values):
        example.append(row[0])
        label.append(row[1:])
    
    return example, label

# %%
train_example, train_label = create_examples(train_data)
test_example, test_label = create_examples(test_data)

# %%
def convert_examples_to_features(examples, labels, max_seq_len, tokenizer):
    
    input_ids, attention_masks, token_type_ids, data_labels = [], [], [], []
    
    for example, label in tqdm(zip(examples, labels), total=len(examples)):
        input_id = tokenizer.encode(example, max_length=max_seq_len, pad_to_max_length=True)
        padding_count = input_id.count(tokenizer.pad_token_id)
        attention_mask = [1] * (max_seq_len - padding_count) + [0] * padding_count
        token_type_id = [0] * max_seq_len

        assert len(input_id) == max_seq_len, "Error with input length {} vs {}".format(len(input_id), max_seq_len)
        assert len(attention_mask) == max_seq_len, "Error with attention mask length {} vs {}".format(len(attention_mask), max_seq_len)
        assert len(token_type_id) == max_seq_len, "Error with token type length {} vs {}".format(len(token_type_id), max_seq_len)

        input_ids.append(input_id)
        attention_masks.append(attention_mask)
        token_type_ids.append(token_type_id)
        data_labels.append(label)

    input_ids = np.array(input_ids, dtype=int)
    attention_masks = np.array(attention_masks, dtype=int)
    token_type_ids = np.array(token_type_ids, dtype=int)

    data_labels = np.asarray(data_labels, dtype=np.int32)

    return (input_ids, attention_masks, token_type_ids), data_labels

# %%
max_seq_len = 256

# %%
train_X, train_y = convert_examples_to_features(train_example, train_label, max_seq_len=max_seq_len, tokenizer=tokenizer)
# Out:
#   0%|          | 0/1680 [00:00<?, ?it/s]Truncation was not explicitly activated but `max_length` is provided a specific value, please use `truncation=True` to explicitly truncate examples to max length. Defaulting to 'longest_first' truncation strategy. If you encode pairs of sequences (GLUE-style) with the tokenizer you can select this strategy more precisely by providing a specific strategy to `truncation`.
# /usr/local/lib/python3.8/dist-packages/transformers/tokenization_utils_base.py:2336: FutureWarning: The `pad_to_max_length` argument is deprecated and will be removed in a future version, use `padding=True` or `padding='longest'` to pad to the longest sequence in the batch, or use `padding='max_length'` to pad to a max length. In this case, you can give a specific length with `max_length` (e.g. `max_length=45`) or leave max_length to None to pad to the maximal input size of the model (e.g. 512 for Bert).
#   warnings.warn(
# 100%|██████████| 1680/1680 [00:00<00:00, 4647.48it/s]

# %%
test_X, test_y = convert_examples_to_features(test_example, test_label, max_seq_len=max_seq_len, tokenizer=tokenizer)
# Out:
# 100%|██████████| 420/420 [00:00<00:00, 4625.32it/s]

# %%
model = TFBertModel.from_pretrained("bert-base-multilingual-cased", from_pt=True)
# Out:
# Downloading:   0%|          | 0.00/714M [00:00<?, ?B/s]
# Some weights of the PyTorch model were not used when initializing the TF 2.0 model TFBertModel: ['cls.predictions.transform.dense.weight', 'cls.predictions.transform.dense.bias', 'cls.predictions.decoder.weight', 'cls.predictions.transform.LayerNorm.bias', 'cls.seq_relationship.weight', 'cls.seq_relationship.bias', 'cls.predictions.bias', 'cls.predictions.transform.LayerNorm.weight']
# - This IS expected if you are initializing TFBertModel from a PyTorch model trained on another task or with another architecture (e.g. initializing a TFBertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing TFBertModel from a PyTorch model that you expect to be exactly identical (e.g. initializing a TFBertForSequenceClassification model from a BertForSequenceClassification model).
# All the weights of TFBertModel were initialized from the PyTorch model.
# If your task is similar to the task the model of the checkpoint was trained on, you can already use TFBertModel for predictions without further training.

# %%
input_ids_layer = tf.keras.layers.Input(shape=(max_seq_len,), dtype=tf.int32)
attention_masks_layer = tf.keras.layers.Input(shape=(max_seq_len,), dtype=tf.int32)
token_type_ids_layer = tf.keras.layers.Input(shape=(max_seq_len,), dtype=tf.int32)

outputs = model([input_ids_layer, attention_masks_layer, token_type_ids_layer])

# %%
class TFBertForSequenceClassification(tf.keras.Model):
    def __init__(self, model_name):
        super(TFBertForSequenceClassification, self).__init__()
        self.bert = TFBertModel.from_pretrained(model_name, from_pt=True)
        self.classifier = tf.keras.layers.Dense(3,
                                                kernel_initializer=tf.keras.initializers.TruncatedNormal(0.02),
                                                activation='softmax',
                                                name='classifier')

    def call(self, inputs):
        input_ids, attention_mask, token_type_ids = inputs
        outputs = self.bert(input_ids=input_ids, attention_mask=attention_mask, token_type_ids=token_type_ids)
        cls_token = outputs[1]
        prediction = self.classifier(cls_token)

        return prediction

# %%
model = TFBertForSequenceClassification("bert-base-multilingual-cased")
optimizer = tf.keras.optimizers.Adam(learning_rate=5e-5)
# loss = tf.keras.losses.BinaryCrossentropy()
model.compile(optimizer=optimizer,  loss='sparse_categorical_crossentropy', metrics = ['accuracy'])
# Out:
# Some weights of the PyTorch model were not used when initializing the TF 2.0 model TFBertModel: ['cls.predictions.transform.dense.weight', 'cls.predictions.transform.dense.bias', 'cls.predictions.decoder.weight', 'cls.predictions.transform.LayerNorm.bias', 'cls.seq_relationship.weight', 'cls.seq_relationship.bias', 'cls.predictions.bias', 'cls.predictions.transform.LayerNorm.weight']
# - This IS expected if you are initializing TFBertModel from a PyTorch model trained on another task or with another architecture (e.g. initializing a TFBertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing TFBertModel from a PyTorch model that you expect to be exactly identical (e.g. initializing a TFBertForSequenceClassification model from a BertForSequenceClassification model).
# All the weights of TFBertModel were initialized from the PyTorch model.
# If your task is similar to the task the model of the checkpoint was trained on, you can already use TFBertModel for predictions without further training.

# %%
model.fit(train_X, train_y, epochs=5, batch_size=16, validation_split=0.2)
# Out:
# Epoch 1/5
# 84/84 [==============================] - 88s 939ms/step - loss: 1.0312 - accuracy: 0.4829 - val_loss: 0.8424 - val_accuracy: 0.6042
# Epoch 2/5
# 84/84 [==============================] - 81s 968ms/step - loss: 0.7599 - accuracy: 0.6696 - val_loss: 0.6734 - val_accuracy: 0.7262
# Epoch 3/5
# 84/84 [==============================] - 77s 917ms/step - loss: 0.5242 - accuracy: 0.8006 - val_loss: 0.6368 - val_accuracy: 0.7292
# Epoch 4/5
# 84/84 [==============================] - 81s 967ms/step - loss: 0.3455 - accuracy: 0.8884 - val_loss: 0.8254 - val_accuracy: 0.7411
# Epoch 5/5
# 84/84 [==============================] - 81s 968ms/step - loss: 0.2937 - accuracy: 0.8921 - val_loss: 0.9283 - val_accuracy: 0.7024

# %%
results = model.evaluate(test_X, test_y, batch_size=8)
print("test loss, test acc: ", results)
# Out:
# 53/53 [==============================] - 11s 153ms/step - loss: 1.0160 - accuracy: 0.6833
# test loss, test acc:  [1.015960693359375, 0.6833333373069763]

# %%
model.predict(test_X)
# Out:
# 14/14 [==============================] - 10s 533ms/step
# array([[0.03202765, 0.02396674, 0.94400567],
#        [0.01495154, 0.9783894 , 0.00665906],
#        [0.00148419, 0.9972523 , 0.00126352],
#        ...,
#        [0.9237603 , 0.00544156, 0.0707982 ],
#        [0.08900312, 0.0052427 , 0.9057542 ],
#        [0.09128083, 0.01531983, 0.89339936]], dtype=float32)

# %%
test_set = pd.read_csv('/content/drive/MyDrive/공장/test_fff.csv')
# test_set = test_set[['reviews']]
# test_set['y'] = 0
test_set = test_set.dropna()
test_set.tail()
# Out:
#                                      reviews  label
# 8592  아메만 먹었는데 다음에 갈 땐 명란 감자 바게트도 같이 먹어 볼라구요      1
# 8593                주택을 개조한 카페라 그런지 찾기 어려웠어요      0
# 8594                          그래도 음료는 맛있었습니다      1
# 8595                  더워서 툇마루 이용을 못 해서 아쉬웠지만      2
# 8596                         곳곳에 포토존도 있고 이뻐요      1

# %%
test_example, test_label = create_examples(test_set)
test_X, _ = convert_examples_to_features(test_example, test_label, max_seq_len=max_seq_len, tokenizer=tokenizer)
# Out:
#   0%|          | 0/8597 [00:00<?, ?it/s]/usr/local/lib/python3.8/dist-packages/transformers/tokenization_utils_base.py:2336: FutureWarning: The `pad_to_max_length` argument is deprecated and will be removed in a future version, use `padding=True` or `padding='longest'` to pad to the longest sequence in the batch, or use `padding='max_length'` to pad to a max length. In this case, you can give a specific length with `max_length` (e.g. `max_length=45`) or leave max_length to None to pad to the maximal input size of the model (e.g. 512 for Bert).
#   warnings.warn(
# 100%|██████████| 8597/8597 [00:02<00:00, 4201.63it/s]

# %%
pred = model.predict(test_X)
# Out:
# 269/269 [==============================] - 152s 565ms/step

# %%
len(pred)
# Out:
# 8597

# %%
predict = pred.copy()

# %%
predict = np.argmax(predict, axis=1)

# %%
len(predict)
# Out:
# 8597

# %%
test_set['pred'] = predict

# %%
pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows', None)

# %%
test_set.loc[test_set['pred']==0]
# Out:
#                                                 reviews  label  pred
# 2               술집 같은 데 커피와 음료도 팔고 있음 인테리어도 이쁘고 나쁘지 않았음      1     0
# 7                                         알바생 분인지 모르겠지만      1     0
# 29                             뜨거운 것도 메뉴 개발 중이시라니 기대할게요      1     0
# 32                                          1 층은 좀 시끄러움      1     0
# 53                                       인기가 좋은 이유가 있어요      1     0
# 56                                              음료도 멋져요      1     0
# 60                                  1 층 자리는 거의 다 찼더라고요.      1     0
# 62                                             분위기는 좋은데      1     0
# 63                                             커피 맛은 별루      1     0
# 74                           주말엔 사람이 많아서 사람 소리가 많이 들리지만      1     0
# 75                          일행과 대화하는 데에 불편함이 없어서 신기했습니다      1     0
# 87                   불친절해요 벨 잘못 눌러서 사람 불러 놓고 죄송하단 말도 없고      1     0
# 89                                   손님이랑 기 싸움하는 것도 아니고      1     0
# 97                                           사장님이 불친절해요      1     0
# 103   이전에는 자리가 없어서 허탕 친 일이 더러 있었는데 리뉴얼 되고 그런 적이 없어서 ...      1     0
# 114                                          그것이 좀 아쉽지만      1     0
# 117            그리고 케이크 다 맛있어요 크림치즈도 많이 들어 있구 안 느끼하고 존 맛      1     0
# 119   보통 인테리어가 예쁘면 맛은 보통이고 그 낭 그 인테이어를 위해서 간다는 편견이 있...      1     0
# 120              단순히 귀엽기만한 것이 아니라 맛도 정말 보장되서 너무 너무 좋아요.      1     0
# 122                                             케이크 예쁘고      1     0
# 124                                     케이크 디자인도 너무 예쁘고      1     0
# 130                                 아직 못 먹었는 데 먹기 아깝습니다      1     0
# 138                                 선물 받으신 분이 너무 좋아하셯어요      1     0
# 140                    사진이 안 이쁘게 나왔는데 케익 진짜 진짜 이쁘고 맛있어요      1     0
# 147                         맛은 특별하진 않고 자세한 건 블로그에 작성할께요      1     0
# 150                      생각보다 더 작은 사이즈였는데 디자인이 너무 귀여워요!      1     0
# 151                                             근데 비싸네용      1     0
# 152                  케이크가 너무 예뻐서 아이부터 어른들까지 좋아하실 것 같아요.      1     0
# 153                      맛은 보지 못 해서 모르지만 너무 귀여워서 만족입니다.      1     0
# 154   케이크 바닥에 고정 핀이 없어서 조심히 들고 가라고 하셨으니 구매하시는 분들 참고 ...      1     0
# 155                                       맛은 보통이지만 예뻐요.      1     0
# 166   컨셉이 귀여워서 소녀 감성 있으신 분들 좋아하실 꺼 같아요 케잌은 오레오초코는 진짜...      1     0
# 167                 그리고 일인 일 조각 케잌 하니깐 나중엔 넘 달고 느끼해서 힘겹      1     0
# 170                                     디저트가 예쁘면 모습에 비해      1     0
# 171       맛은 그저 그런 곳이 많던데 해피 베어 데이는 케이크도 촉촉하고 진짜 맛있었어용!      1     0
# 172                      그리고 컵이 너무 귀여워서 따로 판매하면 사고 싶었어요      1     0
# 173                                               아무튼..      1     0
# 181                                포장해 주셨고 조금 비싼 감이 있지만      1     0
# 182                                     선물용으로 좋은 것 같습니다      1     0
# 194                                               음료 가격      1     0
# 195                                 디저트 가격도 합리적인 편입니다!!      1     0
# 196                           낮에 가면 사진 찍기도 좋은 공간일 것 같네요      1     0
# 202                               브샤용 케이크 주문했는 데 너무 예쁘고      1     0
# 203                              귀염뽀짝해서 친구가 넘넘 맘에 들어했어요      1     0
# 205                                              먹기 아까움      1     0
# 214                                          친절함 또 갈 듯?      1     0
# 218                                     케이크가 너무 색감이 예쁘고      1     0
# 225                                           뷰가 정말 멋져요      1     0
# 226                                          오션뷰 너무 예쁘고      1     0
# 229                                              맛집이 에유      1     0
# 231                                   대추차가 맜있어요 전통 수제 차      1     0
# 235                              배뷸러서 못 먹었는 데 먹어 보고 싶어요      1     0
# 236                             진동 벨이 있었으면 좀 더 편할 거 같아요      1     0
# 237                           창가 쪽에 앉았는 데 모니터가 안 보이더라구요      1     0
# 238                        음료를 많이 시켰는 데 엘레베이터가 있어서 편했어요      1     0
# 240                                주말이라 사람들이 많아서 좀 시끌벅적      1     0
# 244                      샤인머스켓에이드 코코넛이 들어서 씹는 맛도 있구 좋아요      1     0
# 246                                              뷰가 좋아요      1     0
# 250                                     영 일대도 바라보는 예쁜 뷰      1     0
# 253                                                good      1     0
# 256                                        의자도 너무 푹신 하고      1     0
# 257                                           화장실도 깔끔하고      1     0
# 259                                          가격대가 좀 있어요      1     0
# 261                                주차는 길 건너 공용 주차장에 했어요      1     0
# 263                                               전망 좋고      1     0
# 266                                                미칩니다      1     0
# 269                                 맛있는 데 조금 비싼 감은 있어요.      1     0
# 270                                            분위기는 좋은데      1     0
# 271                매장이 너무 바빠서 테이블 정리가 잘 안 되 있던 것이 아쉬웠네요      1     0
# 272                                              사람 많음.      1     0
# 276                                        가격대가 좀 있긴하지만      1     0
# 278                                   주말이라 사람 진짜 진짜 많네요      1     0
# 283                                            경치가 좋아요.      1     0
# 286                     비싸기만 드릅게 비싸고 맛은 없는 그런 카페와는 달라요!      1     0
# 288                                    음료나 케이크는 맛있었습니다.      1     0
# 291                                     음료 사진을 못 찍었지만..      1     0
# 295                                         포토스팟 짱 많구..      1     0
# 296                                              또오고싶슴다      1     0
# 298                                               뷰가 좋고      1     0
# 308                                              맛은 있지만      1     0
# 309                                매장이 크고 넓은 데다 주차하기 좋고      1     0
# 310                                             전망이 좋아요      1     0
# 311                      가격은 착한 편이 아니지만 그래도 한 번씩 가게 되네요      1     0
# 313                                         말이 필요 없어요..      1     0
# 314                                            뷰가 넘 이뻐요      1     0
# 320                                                 예쁘고      1     0
# 322                                                 비싸요      1     0
# 323                                풍경이 쵝오 대형 카페 인증합니다..      1     0
# 327                                            뷰도 넘 좋아여      1     0
# 333       무엇보다 이 곳은 뷰와 사진 찍기 좋은 곳 커피 빵 모두 맛집이예요 주차하기 좋고      1     0
# 334                                               가슴이 뻥      1     0
# 338                                              뷰가 좋아요      1     0
# 346                                      오르막이라 차가 힘들어해요      1     0
# 347                                            뷰가 넘 좋아요      1     0
# 349                                    잠시 들렷는 데 너무 좋네요.      1     0
# 352                                           뷰가 환상입니다.      1     0
# 354                                               뷰도 좋고      1     0
# 362                         평일에 방문했는 데 주차하기 좋고 조용하니 좋네요      1     0
# 363                                  다만 1 층밖에 이용은 못 하지만      1     0
# 364   야외에도 앉을 수 있어서 뷰가 너무 좋음 카페 올라가는 길이 경사가 심해서 초보 운...      1     0
# 371                                             뷰가 좋아요.      1     0
# 374                                               멀긴하지만      1     0
# 382                                              뷰가 멋져요      1     0
# 388                                          가격은 좀 비싸지만      1     0
# 401                                              뷰는 좋은데      1     0
# 402                                     보수 공사 중이라 불편했어요      1     0
# 403          팥빙수 가격 보고 읭 했는 데 4 인이 먹을 양이었네요 견과류에 인절미 가루      1     0
# 407                                              뷰가 좋아요      1     0
# 411                                             뷰가 좋은 곳      1     0
# 417                                             위치는 좋음       1     0
# 423                                 뷰 맛집이라 커피 값이 비싸긴하지만      1     0
# 427                       명선도 가기 전에 들려서 커피 마시기 좋은 것 같아요      1     0
# 429                                              뷰도 멋지고      1     0
# 430                                         그냥 보통 정도입니다      1     0
# 441                                     안 왔으면 후회할 뻔했습니다      1     0
# 447                                               뷰도 좋고      1     0
# 452                                              뷰가 좋아요      1     0
# 454                                           뷰도 엄청 납니다      1     0
# 456                    명선도 바로 앞이라 야경 보면서 예쁜 사진 남길 수 있네요      1     0
# 460                                          좌석은 좀 불편해요      1     0
# 465                                           주차 여유 있음.      1     0
# 466                                    직원 분들이 퉁명스러운 느낌.      1     0
# 468                              서퍼들 보는 재미와 함께 바다뷰가 좋음.      1     0
# 477                                               깔끔...      1     0
# 478                    육 쪽 빵 오래 씹어야함... 좀 길긴 것 빼고는 맛있다.      1     0
# 479                                         창가 자리 추천...      1     0
# 486   루프 탑까지 있는 대형 오션 뷰 카페 명선도도 바로 앞이라 잘 보이고 예쁜 포토존도...      1     0
# 489                       주차가 어려운 진하 해변에서 2시간 무료 주차면...      1     0
# 491               정말 어디에서 마시든 뷰가 너무 좋아서 덩달아 기분도 좋아지더라구요      1     0
# 492             내부 좌석도 넓어서 가족이나 친구랑 다 같이 와도 너무 좋을 거 같아요      1     0
# 493                      주차공간도 2군데로 넓어서 주차 걱정 할 필요도 없었고      1     0
# 495                                    음료도 너무 예쁜데 맛도 있고      1     0
# 498                                          카페도 깔끔하구요.      1     0
# 502                                            주차하기 편하고      1     0
# 516                                          뷰가 너무 이뻐요!      1     0
# 519                                 그냥 찍어도 사진 엄청 잘 나오네요      1     0
# 520                            인테리어도 작은 결혼식 느낌으로 너무 예쁘고      1     0
# 525                                  파도치는 뷰에 카페 파도 딱이네요      1     0
# 526                                               뷰도 좋고      1     0
# 530                                            뷰가 너무 좋고      1     0
# 535                                               뷰가 좋고      1     0
# 541                                              뷰가 좋아요      1     0
# 542                                      뷰도 좋구 커피 맛도 좋구      1     0
# 545                                         더 좋은 거 같아요.      1     0
# 546                                           인테리어도 이쁘고      1     0
# 553                            커피는 산미가 있어서 제 스타일은 아니네요.      1     0
# 562                            분위기가 좋아요 피아노 쳐 보고 싶었는데..      1     0
# 563                                         비가 와서 아쉬웠어요      1     0
# 564                                              뷰가 좋아요      1     0
# 570                                             풍경이 멋져요      1     0
# 571                                        뷰가 너무 너무 예뻐요      1     0
# 576                                           커피도 딱 좋내요      1     0
# 582         저는 부모님 모시고 왔는데 인테리어도 깔끔해서 데이트 코스로도 좋을 것 같아용      1     0
# 584                                          주문할 수 있었어요      1     0
# 590                                            뷰도 너무 좋고      1     0
# 591                                           주차도 수월했어요      1     0
# 592                                             뷰가 좋아요.      1     0
# 593                                          커피 맛도 상큼하고      1     0
# 594                                            맛이 있습니다.      1     0
# 595                                        정말 좋은 거 같아요.      1     0
# 599                            개인적으론 안 섞고 먹는 것이 맛있는 듯요!      1     0
# 604                                               규모 크고      1     0
# 605                                           주차장이 넓습니다      1     0
# 606                                              뷰가 이쁘고      1     0
# 607                                          직원분이 친절하세요      1     0
# 609                                          오션뷰 너무 예쁘고      1     0
# 611                                            뷰도 너무 좋고      1     0
# 615                                               맛었있어요      1     0
# 623      주차장도 앞에 있어 주차하기도 편함 통장 유리로 뷰가 좋음 화장실 남녀 구분 깨끗함      1     0
# 624                                             까눌레가...      1     0
# 625                                누가 봐도 망친 까눌레 파는 것 같음      1     0
# 629                                  커피와 빵 가격도 비싸지 않았어요      1     0
# 633                                              맛이 좋아요      1     0
# 634                                               뷰도 좋고      1     0
# 635                                         의자가 너무 더러워요      1     0
# 637                                               뷰가 좋고      1     0
# 642   루프 탑 매장이 큰 데 그만큼 사람도 많아서 꽉 차 요 뷰는 말할 것도 없이 너무 좋아요      1     0
# 646                                       경치가 너무 멋져요...      1     0
# 650                       건물 자체가 5 층인데 전부 카페라서 마음에 들었어용      1     0
# 653                                                깔끔하고      1     0
# 658                     창가 자리도 좋기는한데 시선에 주차된 차들이 같이 보이고      1     0
# 660                                바다만 보여서 이것도 좋은 것 같아요      1     0
# 661                    1 층에는 반려견도 같이 있을 수 있는 공간인 것 같아요.      1     0
# 665                                 반려견 동반도 가능해서 너무 좋은데      1     0
# 678                                            주차하기 편하고      1     0
# 679                                            바다뷰는 좋은데      1     0
# 681                                   커피 맛은 말할 것도 없습니다.      1     0
# 694                                            커피는 괜찮은데      1     0
# 695                                          베이커리는 별로네요      1     0
# 699                           창가 바다뷰에서 커피 마시니 힐링되고 좋았어요      1     0
# 701                                     바닷가 앞이라 뷰가 좋아요.      1     0
# 702                                          케잌은 그냥이네요.      1     0
# 703                                        앙 버터는 괜찮았어요.      1     0
# 710                                                 비싸요      1     0
# 715                             그냥 케잌 뿐만이 아니라 다 맛있더라구용!      1     0
# 725                                빵 가격은 비싼 편이지만 맛은 있어요      1     0
# 728                                            맛이 훌륭합니다      1     0
# 731                                         빵이 너무 맛있었어요      1     0
# 738                                           주차 가능합니다.      1     0
# 747                               한판으로 시켯는데 맛이 겹쳐서 아쉬워용      1     0
# 754                                          반복 불가 좋맛탱?      1     0
# 758             찹쌀로 만든 떡 같은 느낌의 모찌 모찌랑 호밀빵에 아몬드 투척도 좋네요      1     0
# 760                                   단팥빵 맛집 이란 리뷰가 많은데      1     0
# 761                   저도 사진은 안 찍었지만 사 갔고 먹어 보니 너무 맛있었어요      1     0
# 763                                              맛이 있어요      1     0
# 764                                               좀 비싸요      1     0
# 767                                      사장님이신지 잘 모르겠어요      1     0
# 768                                       여자분이 너무 친절하시고      1     0
# 769          근처에 사는 지인 추천해서 방문했다고 하니깐 서비스도 몇 개 챙겨서 주셨어요      1     0
# 773                                            디자인이 예쁘고      1     0
# 781                                           내가 살찌는 이유      1     0
# 782                                 재료가 아낌없이 들어간 느낌이예요.      1     0
# 793   그리고 아메리카노도요 하지만 7천 원..... 뭐 커피값은 그 안에 많은 것이 포함...      1     0
# 797                                               뷰도 좋고      1     0
# 799                                               뷰 멋지고      1     0
# 804                           음료와 빵은 말하지 않아도 정말 맛있습니다!!      1     0
# 807                                            경치도 멋져요.      1     0
# 808                                      더할 나위 없이 좋네요!!      1     0
# 809                                            바다뷰가 예쁘고      1     0
# 810                                       빵이 너무 맛있어 보여요      1     0
# 816                                      뷰가 너무 예쁘고 깨끗해요      1     0
# 818                                               뷰도 좋고      1     0
# 826                                              경치도 좋고      1     0
# 834                                               뷰가 좋고      1     0
# 839                                               뷰도 좋고      1     0
# 841                                   사진보다 실물이 예쁜 카페에요!      1     0
# 846                                      뷰가 너무 좋은 거 같아요      1     0
# 847                                               뷰가 좋고      1     0
# 850              성산 지나시는 길에 들리시면 좋을 거 같아요 크리스마스 장식도 예뻐요      1     0
# 853                                              빵도 예쁘고      1     0
# 854                                           뷰가 너무 조아요      1     0
# 857                                      뷰가… 너무… 환상적이라…      1     0
# 869                                       만족스럽게 있다가 갑니다      1     0
# 872                                          뷰도 매장도 예쁘고      1     0
# 880                              와.......이건 찐이야 진짜 맛있어요      1     0
# 883               이 근처에서 이른 아침에 문 여는 곳는 이 곳밖에 없는 것 같아요.      1     0
# 887                                              매장도 크고      1     0
# 890                                               뷰도 좋고      1     0
# 901                                            또 오고 싶네요      1     0
# 902                                             뷰가 좋아요.      1     0
# 904                                              뷰는 좋았어      1     0
# 905                                   아이가 좋아하는 빨미까레가 있고      1     0
# 908                                              뷰도 멋찌고      1     0
# 922                               전통 있는 빵집의 충실한 맛이 좋네요.      1     0
# 928          다쿠아즈보다는 좀 더 파운드 케이크에 가까운 맛이고 바삭함 없어서 아숩..!      1     0
# 937                                 근데 김 말이 모양 빵은 별로...      1     0
# 940                                       달지 않고 맛이 좋아요.      1     0
# 941                      상품권 분쟁으로 문제가 있었다는 말 듣고 안타까웠네요.      1     0
# 942                         세상의 나쁜 맘 먹는 사람이 없었음...좋겠어요.      1     0
# 950                                           굿 주차 힘드네요      1     0
# 957                   지정 주차장도 한 시간 지원해 주니 주차 걱정 없어서 좋네요      1     0
# 964                                           여기가 찐이예요.      1     0
# 966                             그런데 재료가 잘 들어가 있어서 만족해 료      1     0
# 977                                타집에 비해 가격도 크게 비싸지 않다      1     0
# 987                                    근데 초코파이 종류는 똑같아요      1     0
# 989                                    주차장은 구비돼 있어 좋아요!      1     0
# 995                                 건너편에 주차장 있으니 참고하세요!      1     0
# 1001                       그냥 장사가 잘 되니깐 기계적인 느낌이 들었습니다.      1     0
# 1002   초코파이도 그냥 이제는 대량 생산된 대기업 제품의 맛이 나서 좀 아쉬운 느낌이었습니다.      1     0
# 1005                                        생각보다 크진 않아요      1     0
# 1009                 초코를 별로 안좋아하는데 옛날 전주 파이보다 훨씬 맛있어졌어요      1     0
# 1011                                         주차하기에도 편하고      1     0
# 1012                                            테이블도 많고      1     0
# 1013                              뷰도 예쁘고해서 힐링하고 온 것 같아요      1     0
# 1022                                            건물이 이뻐요      1     0
# 1023                                            비싼 편이지만      1     0
# 1026                                             뷰가 좋아요      1     0
# 1031                                             뷰가 좋아요      1     0
# 1032                                             뷰가 예뻐요      1     0
# 1041                                          뷰가 너무 예쁘고      1     0
# 1043                                          뷰가 너무 예쁘고      1     0
# 1049                                      화이트 톤의 깔끔한 카페      1     0
# 1051                                           뷰도 넘 멋져요      1     0
# 1052                                          뷰가 정말 이뻐요      1     0
# 1055                                          뷰가 진짜 예뻐요      1     0
# 1057                             음료는 들고 갈 수 없는 데 너무 좋아요      1     0
# 1059                                            뷰도 좋았어요      1     0
# 1060                                         뷰가 정말 멋집니다      1     0
# 1062                                             뷰가 좋아요      1     0
# 1064                                      생각했던 것보다 달랐지만      1     0
# 1065                                             뷰가 좋아요      1     0
# 1073                                지금 앉아만 있는 데도 넘 행복해요      1     0
# 1074                                      커피 맛이 나쁘진 않은데      1     0
# 1075                                   뷰가 나쁘지도 않은데 음...      1     0
# 1077                                   사진이 장난 아니게 이쁘거덩요      1     0
# 1081                                             뷰가 좋아요      1     0
# 1083                                      그리고 뷰가.. 미쳤어요      1     0
# 1085                       하늘도 되게 가깝게 느껴질 만큼 탁 트여 있어요!!      1     0
# 1089                                       사진 찍기도 너무 좋고      1     0
# 1092                                             뷰만 좋아요      1     0
# 1097                                               핫한 곳      1     0
# 1101                                   커피 맛도 나쁘지 않았습니다.      1     0
# 1104                                     전체적인 인테리어는 멋져요      1     0
# 1109                                              뷰도 좋고      1     0
# 1112                                          커피 양이 많네요      1     0
# 1114  하지만 뷰가 멋지네요 추워서 제대로 구경 못 했지만 따뜻한 봄에 한 번 더 가 봐야겠어요      1     0
# 1116                                             산뷰도 좋고      1     0
# 1117                                          야외 석이 좋던데      1     0
# 1119                                        뷰는 참 멋있더라구요      1     0
# 1121                         주차 요원 분들도 친절하게 길을 안내해 주시네요      1     0
# 1122                                          음료도 괜찮았어요      1     0
# 1123                                 야외도 있엇는데 분위기가 괜찮아요      1     0
# 1127                   주차장 넓고 여러 곳에 여러 종류의 테이블과 좌석이 많아요      1     0
# 1130  가창 대형 신상 카페 주문 받으시는 남자분이 친절함 카페가 크기에 비해서 자리가 야...      1     0
# 1138                                             뷰가 좋아요      1     0
# 1141                           주차장도 넓고 바로 앞에 산이 보여서 좋아요      1     0
# 1144                        저는 산미를 좋아하지 않는 데 딱 제 취향입니다.      1     0
# 1146                 바질 토마토 스프레드가 양파스프래 드보다 더 맛이 좋았습니다.      1     0
# 1147                                              무좋아요.      1     0
# 1148                             픽업이랑 카페가 별도 공간에 있어서 좋고      1     0
# 1150                           야외 테이블도 많아서 자연에 온 느낌입니다.      1     0
# 1153                                         풍경도 너무 예쁘고      1     0
# 1157                                        대구와 접근성이 좋고      1     0
# 1158                                          방문하기는 좋다.      1     0
# 1159         마운틴뷰를 즐길 수 있으며 잔잔히 깔아 주는 브금은 분위기에 좋은 듯 하다.      1     0
# 1161                         주차 요원도 많아 주차는 편안히 할 수 있었다.      1     0
# 1168                                     하지만 탁 트인 곳이라 봄      1     0
# 1171                                 별관 2 층 전망도 너무 좋네요.      1     0
# 1172                                      전망 고려하면 괜찮아요.      1     0
# 1174                                         주차 공간은 넓은데      1     0
# 1176                       커피도 단가가 좀 있는 데 드립백도 주셔서 괜찮아요      1     0
# 1181             공간도 의자며 테이블이며 모두 정성 들이지 않은 곳이 없더라구요..!      1     0
# 1182                                        넘나 제 입맛이였어요      1     0
# 1184                                         바깥에 자리도 많고      1     0
# 1188                                   경치 좋아 2번째 방문이예요.      1     0
# 1193                                      너무 좋은 시간이엇어요.      1     0
# 1194                무엇보다 테라스와 야외에 강아지 입장이 가능해서 넘넘 좋네요..      1     0
# 1195                            카페가 뭔가 웅장한 느낌이 들고 좋아요..      1     0
# 1196                                       야외도 잘 돼 있고..      1     0
# 1200                                              뷰도 좋고      1     0
# 1204  체리 얼 그레이 선택해서 먹었는 데 진심 대 존 맛 특히 체 리얼 그레이 따로 판매...      1     0
# 1211  주차장이 엄청 넓은 공터인데 안내해 주시는 분들이 잘 정리해 주셔서 편했어요 자동 ...      1     0
# 1212                            커피 가격이 좀 있지만 그만큼 맛있었어요!      1     0
# 1213  야외 자리가 엄청 많았고 2 층 실내에서 게이샤 커피 마시며 보는 마운틴뷰는 힐링 ...      1     0
# 1215                                              뷰도 좋고      1     0
# 1218                                             뷰는 좋은데      1     0
# 1220                                           마운틴뷰가 좋고      1     0
# 1225                                           자리도 넓어요.      1     0
# 1226                                           주차 요원 있고      1     0
# 1229                                            뷰가 예쁘네요      1     0
# 1231                                         뷰는 정말 짱입니다      1     0
# 1232                                          뷰가 너무 멋져요      1     0
# 1239                                             뷰도 멋지고      1     0
# 1241  커피숍에서 보는 야외가 든 전경 굿 게이샤 마시러 갔는 데 핸드드립이 아니 여서 아...      1     0
# 1242                                           눈이 즐거운 곳      1     0
# 1244                                             경치도 좋고      1     0
# 1247                                            뷰가 좋아요.      1     0
# 1249                                새로 생 간 지 얼마 안돼 깨끗하고      1     0
# 1250                                             뷰가 좋아요      1     0
# 1251                                 주로 485 카페 정원이 예쁘네요      1     0
# 1254                                          뷰도 너무 이쁘고      1     0
# 1261                                            뷰가 좋아요.      1     0
# 1268                                              주차 넓고      1     0
# 1270                                     눈과 입이 호강하고 갑니다      1     0
# 1271                                             뷰는 좋은데      1     0
# 1275                                              뷰도 좋고      1     0
# 1285              카페로 올라오는 길 알록달록 단풍 보는 재미 또한 너무 아름다워요.      1     0
# 1287                                             뷰가 좋아요      1     0
# 1292   먼 산에 단풍이 울긋 불긋 이쁘게 물들어 멋진 뷰가 커피 맛을 더 맛있게하는 것 같아요      1     0
# 1297              가을엔 단풍 뷰가 너무 예뻥뻐요 자리도 넓어서 지금 딱 가기 좋아요      1     0
# 1298                                              뷰도 좋고      1     0
# 1300                                  지금 단풍 철이라 너무 이쁘네요      1     0
# 1302                                        진짜 뷰가 끝내줍니다      1     0
# 1306                                          마운틴뷰도 좋지만      1     0
# 1309                          뷰가 대박 대구에서 많이 멀지 않아서 좋아요!      1     0
# 1313  뷰만 봐도 커피값 안 아까운 가창주리커피숖 위치는 이미 유명한 오퐁드부아 가는 길목...      1     0
# 1314  내려가는 주차장 길 경사가 높아 아찔하나 일단 주차 후 내리면서 알록달록 앞산 뷰를...      1     0
# 1322                                  야외라 조금 춥긴해도 뷰도 좋고      1     0
# 1323                                      담요도 있어서 좋았어요.      1     0
# 1329                        가격 좀 있지만 지금 단풍과 산뷰가 엄청 이뻤어요      1     0
# 1330                                  무섭지만 내려가면 주차공간 넓음      1     0
# 1332                                        단풍이 너무 이뻐요.      1     0
# 1337                        대신 이쁜 단풍 산뷰 보며 눈 호강 제대로 했네요      1     0
# 1339                                              뷰도 좋고      1     0
# 1345                        뷰가 공기도 넓어서 대구랑 가까워서 애견 동반이라      1     0
# 1346                                   산으로 둘러싸인 느낌이 좋아요      1     0
# 1349                          사진을 안 찍을 수 없은 뷰에 폰이 바빴어요.      1     0
# 1350               이런 카페가 점점 많아지고 있는 데 가 창에도 생겨서 행복하네요.      1     0
# 1358                                          뷰가 너무 멋져요      1     0
# 1362                                           뷰가 진짜 좋고      1     0
# 1367                            이 근방에 뷰는 좋은데 맛없는 곳이 많은데      1     0
# 1368                                  여기는 맛도 뷰도 다 잡았 내용      1     0
# 1370                                    음식도 뷰도 음악도 서비스도      1     0
# 1375                             풍경 뷰 진짜 최강 최강 자리 진짜 많고      1     0
# 1382                                일단 자연과 어우러진 느낌이 좋았고      1     0
# 1383                        오픈한 지 오래되지 않아 전체적으로 깔끔했습니다!      1     0
# 1387                                  올라가서 보면 뷰가 더 좋아요.      1     0
# 1389                                카페도 너무 이쁜 데 뷰가 미쳤어용      1     0
# 1392                                    모두들 함성이 절로 나는 곳      1     0
# 1401                                       넓어서 주차도 용이하고      1     0
# 1402                                        뷰도 좋고 쾌적했어요      1     0
# 1403                                     주위 풍경이 아주 장관임돠      1     0
# 1404                                                 크으      1     0
# 1407                                  가만 앉아만 있어도 걍 좋으네요      1     0
# 1410                                              뷰도 좋고      1     0
# 1416                                  층고도 높아서 확 트인 느낌이고      1     0
# 1419                                            한 반만...      1     0
# 1423  음악도 좋아서 크리스마스가 다가오고 있구나 하는 생각이 들었음 카페인 줄이기 실천 ...      1     0
# 1424  위에 올려 주는 사과 조각도 잘 어울려서 입맛에 맞았음 감자 크림 치아바타도 빵은 ...      1     0
# 1431             소리가 나왔을 정도로 크리스마스 분위기가 아주 따뜻해 보이고 예뻤어요      1     0
# 1433                                      직원 분들 다 친절하시고      1     0
# 1435                                좀 멀지만 조만간에 다시 또 와야지      1     0
# 1436                                  이라는 생각이 들 만큼 좋았네요      1     0
# 1452                                              뷰가 좋고      1     0
# 1470                                   양송이 스프는 꼭 먹어야 해요      1     0
# 1479                                      가을 경치가 너무 예뻐요      1     0
# 1488                                              뷰 굳뜨       1     0
# 1492                                    주차장 넓게 잘 돼 있구요.      1     0
# 1493                      주말 붐비는 시간대에 방문하면 손님이 많을 것 같네요      1     0
# 1494                             근처에 멋진 폭포가 있어 경치가 좋네요.      1     0
# 1502                                         뷰가 너무 좋으네요      1     0
# 1504                                           분위기는 좋지만      1     0
# 1509                                     소금 빵이 차암 맛있습니다      1     0
# 1518                   좌석도 많아 사람이 많았음에도 복 작한 느낌은 아니었어요.      1     0
# 1527                                       커피는 그럭저럭입니다.      1     0
# 1536                                둘러보니 카페는 사람 많고 북적이고      1     0
# 1545                                          이색적인 카페..      1     0
# 1546                                              이색적이고      1     0
# 1548                  기차가 음료를 가져다 줘서 아이가 신기하다고 놀라워 하네요.      1     0
# 1553                  다시 와 보는 가창 온 더 레일은 기차가 서빙해 주는 카페고      1     0
# 1556                                             특색 있네요      1     0
# 1560                         뷰도 좋고 기차 가 서빙해 주는 것이 신박하네요      1     0
# 1562                               기차가 가져다주는 커피 멉어러 왔어요      1     0
# 1564               음료 배달 방식이 작은 기차로 주는 것이 너무 특색 있고 귀여워요      1     0
# 1566                              커피가 테이블까지 올 때 특색 있구요.      1     0
# 1567                                      재미 있는 기차 서빙과       1     0
# 1571                                     아기가 좋아해서 자주 와요      1     0
# 1574                                          명함도 유니크하고      1     0
# 1575                       기차가 음료 갖다 준다는 것이 신선하고 재미있었어요      1     0
# 1576                     기차 좌석은 8개뿐이라 주말에 오면 기다려야할 듯합니다      1     0
# 1578               기찻길에 기차가 음료가어다 주는 서비스는 정말 획기적인 거 같아요      1     0
# 1579                           아이가 너무 신기해하고 보는 저도 신기하네요      1     0
# 1582                                            주차장이 넓고      1     0
# 1583                                 기차가 배달해 주는 것이 귀여워요      1     0
# 1584                                              뷰가 좋고      1     0
# 1588                             기차가 음료 배달해 주는 것이 신기했어요      1     0
# 1590                            초입부터 좀 가파르긴해도 카페 내부도 좋고      1     0
# 1599                                        온 더 레일 좋아요.      1     0
# 1600                                              뷰도 좋고      1     0
# 1612  디저트는 레인보우 케이크를 선택해서 먹었는데요 케이크는 부드러운 시트지에 은은한 크...      1     0
# 1613                           스무디는 망고와 딸기를 위에 얹어 주기도하고      1     0
# 1614              과육이 엄청 많아서 음료를 마시면서 과육을 씹는 맛이 재미있더라구요      1     0
# 1615  그리고 창문이 뻥 뚫려 있고 바로 앞에 산이라 단풍이 알록달록 예쁘게 물들어서 뷰도...      1     0
# 1616       그리고 기차 테이블에 앉으면 기차가 음료를 배달해 주는 것이 너무 재미있었어요!      1     0
# 1617                                        사진도 이쁘게 나오고      1     0
# 1619                            기차 차로 음료 주는 거 너무 신기했어요!      1     0
# 1621                             기차가 서빙해 주는 커피라 더 특별했어요      1     0
# 1626                         단풍 철이라서 전면에 보이는 단풍 뷰가 예쁘네요      1     0
# 1627                                  초록 초록할 때 와도 예쁘겠어요      1     0
# 1628  별 기대감 없이 온지라 더 만족한 듯 투박한 빵은 생각보다 맛있었고 남아서 셀프 포...      1     0
# 1629                                            커피도 갠찬코      1     0
# 1631                                           주차도 수월하고      1     0
# 1636                             가족끼리 도란도란 얘기 나누기도 좋네요.      1     0
# 1640                                      너무 정겹고 아늑해해요.      1     0
# 1641                한 번씩 기차가 경적을 울릴 때면 동심의 세계로 온 듯 하구요.      1     0
# 1643                                           컨셉이 좋아요.      1     0
# 1646                                          뷰가 정말 좋네요      1     0
# 1649                                       레일 서빙이 신기했어요      1     0
# 1654                      아이가 기차를 좋아해서 왔어요 서빙하는 기차가 좋아요      1     0
# 1655                                              뷰가 좋고      1     0
# 1658                          뷰도 좋고 기차 좋아하는 아들도 너무 좋아해요      1     0
# 1659                       이렇게 진하게 신선하게 마신 곳은 여지껏 없었어요.      1     0
# 1661                                  특히 기차 서빙 유치하지 않음.      1     0
# 1663                                             뷰가 모쩌여      1     0
# 1665      기차 가 서빙해 주는 것이 너무 재밌어요 아이들과 함께 가도 편안한 분위기라 좋고      1     0
# 1668                             아이가 기차 좋아하는 데 특별한 카페네요      1     0
# 1673                           오늘 하늘이 너무 예뻐서 사진도 잘 나오네요      1     0
# 1675                       아이들이 기차에 신이 나서 핸드폰도 안 보고 좋네요      1     0
# 1681                                        주차도 매우 편합니다      1     0
# 1683                                기차가 커피 가져다주는 카페가 자고      1     0
# 1690                                 기차가 서빙하는 이색적인 카페!!      1     0
# 1693                              자연 뷰 좋은 카페라 낮이 더 예쁠 듯      1     0
# 1694                                    평일 방문이라 주차도 편했고      1     0
# 1701                           기차가 음료를 배달해서 아이가 참 좋아하네요      1     0
# 1703                                       아기가 무척 좋아하네요      1     0
# 1704                                         색다른 경험이였어요      1     0
# 1708                  아기랑 함께 방문했는 데 너무 이색적이고 예쁜 공간이었어요.      1     0
# 1714                       가끔 바람 쐬러 나들이 오는 데 여기 너무 좋아요.      1     0
# 1716                                              뷰도 좋고      1     0
# 1719                                             뷰가 좋아요      1     0
# 1720                                          명함도 특이해요.      1     0
# 1721                                 서빙 방식도 아이들이 환장하네요.      1     0
# 1727                                          커피 빨리 나오고      1     0
# 1735                               엄마 사람이 안 타도 기차가 움직여요      1     0
# 1740                                             카페도 크고      1     0
# 1741                          채광이 좋아서 사진 찍기 너무 좋았던 카페에요      1     0
# 1746                                          카피 맛은 몰라서      1     0
# 1747                                   기차가 가져다줘서 색다른 경험      1     0
# 1749                    기차가 서빙해 주는 이색 카페 아이가 너무 좋아하더라구요      1     0
# 1752                          기차가 메뉴들을 배달시켜 줘 볼 거리가 있어요      1     0
# 1753                    기차가 서빙해 주는 이색 카페로 아이들이 정말 좋아해요!      1     0
# 1754                          기차 좋아하는 아이가 너무 좋아하는 곳이에요.      1     0
# 1757                      가족들이랑 차 마시러 왔는데 레일에 음료수가 나오네요      1     0
# 1759                                    처음 와 봤는데 이색적이고       1     0
# 1764                                     저수지 보이는 뷰 멋지네요      1     0
# 1765                                 기차가 써빙해 주는 재미있는 카페      1     0
# 1768                          기차가 서빙해 주는 카페 이색적이고 좋았어요!      1     0
# 1779                                아기가 기차를 좋아해서 방문했는 데      1     0
# 1785                                             맛도 있구요      1     0
# 1787                                      기차 잼 있는 경험이에요      1     0
# 1791                     기차가 서빙을 해 주는 이색 카페라고 해서 가 봤어요.      1     0
# 1793                    기차가 지나갈 때마다 재밌어져서 새로운 느낌이 좋았어요.      1     0
# 1795                                       분위기가 밝고 따뜻하고      1     0
# 1813                                   직원 뷰인들 너무 친절하셧어욜      1     0
# 1818     햇살을 무척이나 좋아하는 사람으로써 햇살이 따땃하게 들어오는 자리들이 있어 좋았어여      1     0
# 1821                        음료도 예뻤어 요 담에는 디저트 먹으러 가야겟어욤      1     0
# 1828                       야외 테이블에 앉으니 밖에 보는 재미도 쏠쏠했습니당      1     0
# 1841           그래도 치즈 파운드 케이크는 맛있었어요! 사 천 원이면 괜찮은 것 같아요      1     0
# 1842                         친구는 녹차시켰는데 이거는 따뜻하게 나왔더라구요      1     0
# 1843                               치즈는 조금 차가웠는데 저는 좋았어요      1     0
# 1848                                        야외 자리도 넉넉하고      1     0
# 1850  파운드 케이크가 따끈따끈하게 나와서 신기했어요! 세 가지 맛 다 맛있었지만 원 픽은...      1     0
# 1852                                      까눌레 더 팔 아주 새욤      1     0
# 1854         주택을 개조해서 만든 카페에 야외 테라스도 있고 곳곳이 사진 찍기 좋더라구요      1     0
# 1855                                          커피 메뉴도 많고      1     0
# 1858           레몬 파운드 코코넛 파운드 케잌 막 구워서 따뜻하고 정말 내용물이 알쪄요      1     0
# 1859                           사장님 솜씨가 대박 좋으셔요 그리고 좋아요.      1     0
# 1864                                          그냥 뷰맞집...      1     0
# 1866                                            뷰가 죽여줘요      1     0
# 1869               뷰가 너무좋아요 한참을 멍하니 바다를 바라보며 곡물 라떼 마셨어요      1     0
# 1876                                아침에도 이쁘고 또 아기랑 갈께요.      1     0
# 1877              제가 먹은 건 과일 청 들은 거인데 따뜻하게 담요랑 화장실 깨끗해요      1     0
# 1880                                           뷰도 너무 좋고      1     0
# 1882                2시간만 이용 가능한 것이 아쉽지만 바닥도 따뜻하고 좋았습니다!      1     0
# 1883                                             뷰 맛집이죠      1     0
# 1884                                            경치는 좋네요      1     0
# 1887                  날이 많이 춥지 않을 때는 야외의 자유로운 분위기 딱 좋네요      1     0
# 1894                                              뷰도 좋고      1     0
# 1897                                            뷰가 좋아요.      1     0
# 1905                                  커피 맛이 안 좋을 수가 없다.      1     0
# 1906                              따뜻한 별채에 앉아 마시는 커피란...      1     0
# 1910                                            건물이 예쁘고      1     0
# 1912                음료 시키면 별채 이용도 가능하다고 해서 별 채도 이용해 봤어요      1     0
# 1914                                불빛에 비치는 바다뷰도 정말 좋네요      1     0
# 1917                                         뷰가 너무 좋아요.      1     0
# 1918                                       정말 뷰가 끝내 주네요      1     0
# 1922             바람이 마니 불어서 실내에 자리 잡았지만 왔다갔다 구경하기에 괜찮아요      1     0
# 1923                                            주차하기 좋고      1     0
# 1924                                            애견 동반되고      1     0
# 1925                                            뷰도 좋아요.      1     0
# 1926                                  음료는 가격이 비싸지만 좋습니다      1     0
# 1928                                             뷰는 좋은데      1     0
# 1929                                               넘 좋음      1     0
# 1931               일 층에 사람이 너무 많아서 올라왔는 데 조용하고 훨씬 좋은 듯!      1     0
# 1934                                 뷰가 좋아서 간만에 또 방문했어요      1     0
# 1935                                  뷰 하나는 끝내 주는 것 같아요      1     0
# 1938                   뷰가 너무 예쁜 데 밤에도 바다 뷰가 아예 없는 건 아니고      1     0
# 1939                                 운치 있고 파도 소리가 좋습니다.      1     0
# 1940                       그리고 얼마 전에 리뉴얼 돼서 빈 백도 깔끔하네요.      1     0
# 1942                  역시 낮보다는 저녁에 사람이 조금 덜 붐벼서 저는 좋았어요.      1     0
# 1943                                           뷰가 넘 좋아요      1     0
# 1944                                           뷰가 아름다워요      1     0
# 1947                                          건물 외관 이쁘용      1     0
# 1948                                           커피 맛이...      1     0
# 1954                                            풍경이 좋음.      1     0
# 1956                                 2 층 실내뷰도 충분히 좋더군요.      1     0
# 1957  방문한 날 날이 좋아도 바닷가라 바람은 제법 불었는 데 카페 담요가 두꺼워 견딜 만...      1     0
# 1960                                그리고 주차도 신경 잘 써 주시네요      1     0
# 1962  예전에 음료는 맛없던 기억이 있었는데 많이 개선된 거 같아요 여전히 사람은 너무 많...      1     0
# 1965  티라미수 쑥절미 등은 덤이고 무조건 풍경이 주는 진정한 행복이 가득합니다 부산 가면...      1     0
# 1966             커피 한 잔과 파도가 주는 행복 웨이브 온 오늘은 무척이나 행복합니다      1     0
# 1967                                           뷰가 좋은 까페      1     0
# 1969                                             뷰가 이뻐요      1     0
# 1970                                              뷰도 좋고      1     0
# 1972                                             뷰가 좋아요      1     0
# 1978                              주차 초보도 주말 빼고는 주차하기 쉬움      1     0
# 1982                                         뷰도 좋고 최고에요      1     0
# 1983                                             뷰가 좋은데      1     0
# 1984                                            뷰는 좋아요.      1     0
# 1987                                         사진이 잘 나옵니다      1     0
# 1989                                         뷰는 정말 끝내줘요      1     0
# 1996                                             뷰 대박이죠      1     0
# 1999                                           별 채가 좋아요      1     0
# 2004                                         뷰는 진짜 좋아요       1     0
# 2007                             별채가 있어서 강아지 이용 가능 편리해요      1     0
# 2008                                         음료 메뉴도 새롭고      1     0
# 2011                                          뷰가 끝내 줘요.      1     0
# 2012                                             뷰가 좋아요      1     0
# 2014                                    웨이브 온 야외 뷰가 좋은데      1     0
# 2022                                     전망이 너무 너무 좋습니다      1     0
# 2023                                          뷰가 너무 이쁘고      1     0
# 2029                                  뷰가 좋아서 잘 즐기다 갑니다.      1     0
# 2040                                         소금 빵이 유명해요      1     0
# 2044                                    너무 편하고 예쁜 곳이네요.      1     0
# 2045                     최선의 서비스를 다하기 위해 노력한다는 느낌이 들었어요      1     0
# 2046  갑자기 가서 못 꾸미고 가서 사진은 못 찍고 대충 에 사진만 찍은 것이 너무 아쉬워...      1     0
# 2052                               가격이 좀 비싼 데 뷰가 정말 좋아요      1     0
# 2060                   그래도 별관에 강아지가 들어올 수 있어서 이 점은 좋습니다      1     0
# 2065                                              뷰도 좋고      1     0
# 2068  부산 여행 기장 힐튼으로 가기 전 웨이브 온 까페 방문 뷰가 다했다 해도 과언이 아...      1     0
# 2069                                             뷰가 좋아요      1     0
# 2072                          밖에 많이 추웠는 데 담요가 두꺼워서 좋았어요      1     0
# 2076                          뷰가 너무 좋아서 모든 것이 용서되는 곳...      1     0
# 2077                              웨이브 온은 최고의 카페예요 뷰가 좋고      1     0
# 2082                                          사진 찍기 좋지만      1     0
# 2083                                       커피 맛은 좀 아쉬워요      1     0
# 2085                    뷰가 정말 좋고 느긋한 오후 쉬고 즐기기에 좋은 곳이에요      1     0
# 2087                                              뷰도 좋고      1     0
# 2088                     뷰가 아주 좋다 소풍 가는 기분으로 갈 수 있는 카페다      1     0
# 2089                                          케이크 맛도 좋다      1     0
# 2090                                            뷰는 좋아요.      1     0
# 2094                                             뷰가 좋아요      1     0
# 2099                                   뷰가 좋아서 전 두 번째 방문      1     0
# 2100                                 뷰가 끝내 줘요 의자도 넘 편하고      1     0
# 2103                                            뷰가 좋아요.      1     0
# 2105                                     사진 찍음 예쁘게 나와요.      1     0
# 2106                              뷰는 좋은 만큼 사진 찍기가 좋습니다.      1     0
# 2108                                             뷰가 멋져요      1     0
# 2110                              직원이 많아 음료는 빨리 나오는 편이고      1     0
# 2111  조용하게 이야기를 나누고 싶을 때 나이 지긋한 어른들과 함께 갔을 때 편안히 쉬다 ...      1     0
# 2118  눈 덮힌 모양이 귀여워서 몽블랑 기대 없이 시켰는 데 8000원 너무맛있었어요 강추...      1     0
# 2129                                             뷰가 멋져요      1     0
# 2130                                  기장의 핫 플레이스라고 해 방문      1     0
# 2131     시원한 바람과 드넓은 바다를 바라보고 있으니 무거운 마음도 잠시 내려 놓게 되네요.      1     0
# 2133                                            자리도 편하고      1     0
# 2134                                깔끔하게 잘 관리하는 것 같았어요.      1     0
# 2136               5년 된 것 같던데 연식에 비해 까페 관리 진짜 잘 되는 것 같고      1     0
# 2137                             주차 요원도 여러 분 계신 것 같았고요.      1     0
# 2139              부모님과 점심 식사 후 리뷰 보고 첫 방문했는 데 경치는 좋았어욤.      1     0
# 2143                                          자연 경관 예쁘고      1     0
# 2144                        마당에 쉴 수 있는 데크나 테이블도 많아서 좋음.      1     0
# 2145                                             뷰값이긋지유      1     0
# 2147                                    웨이브 온 뷰가 정말 멋쪄요      1     0
# 2153                                       주차장이 넓고 편하죠.      1     0
# 2154  이번 혼자서 부산 기장 출장 중이라 일정이 바빠서 후딱 간단히 게 아이스 아메만 한...      1     0
# 2156                    모처럼 휴일에 와이프랑 들렀는 데 분위기가 너무 좋네요.      1     0
# 2158                              야외 테라스에 편하게 앉을 자리도 있고      1     0
# 2160                                             뷰는 좋아요      1     0
# 2167                                    그래도 뷰가 큰 한몫했습니다      1     0
# 2168                                             뷰도 좋은데      1     0
# 2170                                              뷰가 좋앙      1     0
# 2172                                       사진이 너무 잘 나와요      1     0
# 2174                                         뷰가 너무 예뻐요!      1     0
# 2176       드립 커피를 주문하면 초콜렛을 하나 주는 데 부드러워서 따로 시켜 먹고 싶었어요      1     0
# 2180           뷰 맛집....................................      1     0
# 2182                          뷰가 너무 좋아서 멍하니 시간이 금방 갑니다.      1     0
# 2184                       뷰만 좋은 것이 아니라 커피도 맛이 아주 좋습니다.      1     0
# 2190                                        뷰 하나는 좋습니다.      1     0
# 2194            다양한 자리 빈 백이나 루프 탑 등등 마련돼 있어서 너무 너무 좋아요.      1     0
# 2196                                             뷰는 좋지만      1     0
# 2197                                             뷰는 좋아요      1     0
# 2199                                          뷰가 너무 이뻐요      1     0
# 2201                                         바다 전망은 좋아요      1     0
# 2202                 대한민국에 이런 멋진 뷰를 지닌 카페가 있다는 것이 자랑스럽고      1     0
# 2203                                      경관이 너무 아름답습니다      1     0
# 2207                커피 가격이 좀 비싸긴해도 자릿 값으로 생각하고 아깝지 않습니다      1     0
# 2212                                         따뜻한 담요도 있고      1     0
# 2214  스트레스는 바다에 던져 버리고 상쾌한 바다 소리만 가슴에 담아 올 수 있어서 정만 ...      1     0
# 2217            바다 뷰랑 푹신한 빈 백이 너무 편해서 비싸다는 생각도 딱히 안 드네요      1     0
# 2218                                             뷰가 좋아요      1     0
# 2223                                              뷰도 좋고      1     0
# 2225                처음 와 봤는 데 뷰도 좋구 커피 맛도 좋구 사람만 좀 적었으면      1     0
# 2227                           관리하시는 분이 있어서 주차하기 편했어요!!      1     0
# 2228  유명한 만큼 사람들 많아서 자리 잡기 조금 힘들었는 데 그만큼 뷰는 이뻐요 사진도 ...      1     0
# 2234                                          뷰가 너무 이뻐요      1     0
# 2235                                             뷰가 멋져요      1     0
# 2243                                             뷰도 좋은데      1     0
# 2245                                              뷰도 좋고      1     0
# 2248                                     이런 뷰에 커피 너무 좋죠      1     0
# 2250                                   주차장이 굉장히 넓고 좋습니다      1     0
# 2251                         음료 먹는 쪽과 주문하는 쪽이 구분이 돼 있어요      1     0
# 2254                                          뷰가 정말 멋져요      1     0
# 2255                                       음료 가격 나쁘지 않고      1     0
# 2263                              음료는 맛있는 데 빵이 조금 아쉬웠어요      1     0
# 2270                              실내 가구 배치도 센스 있게 잘 하시고      1     0
# 2272               특히 야외 테라스에서 내려 보는 바다와 파도치는 소리는 일품입니다      1     0
# 2279                                       가격이 아깝지 않네요.      1     0
# 2281                                              뷰도 좋고      1     0
# 2282                                 직원 분들도 친절하시고 다 좋은데      1     0
# 2292                                              뷰도 좋고      1     0
# 2295                                             뷰가 좋아요      1     0
# 2297                    뷰가 좋은 줄은 알고 있었는 데 음료가 기대 이상이에요!      1     0
# 2300                             뷰는 더더욱 좋고 재방문 또 하고 싶네요      1     0
# 2301                                        뷰는 말할 것도 없고      1     0
# 2302                                      실내 디자인이 특이해요.      1     0
# 2304       요즘 카페 참 선수 입니다. 경관 분위기 맛 어느 것 하나 빠지는 것이 없네요.      1     0
# 2305                         가는 길에 대변항 쪽 구경하는 것도 재밌었구요.      1     0
# 2307                                             넘 좋았어요      1     0
# 2315                                      야외 사진 넘넘 잘 나옴      1     0
# 2321                                        왜 유명한지 알겠어요      1     0
# 2322       주차 자리는 부족하지만 관리하시는 분이 친절하게 안내해 주시니 기다리면 됩니다.      1     0
# 2324                                     뷰가 압도적인 카페입니다.      1     0
# 2325                                             뷰가 좋아요      1     0
# 2327                                              뷰도 좋고      1     0
# 2336                                       핸드드립 커피 깔끔했고      1     0
# 2337  바닐라 크림 라떼는 양이 좀 적고 많이 달아서 커피 맛은 거의 안 느껴졌지만 마실 ...      1     0
# 2340                                             뷰가 좋아요      1     0
# 2342                                        건물도 뷰도 멋있네요      1     0
# 2343                                           뷰가 넘 이뻐요      1     0
# 2346                                     자리도 여유로워서 좋았어요      1     0
# 2347                  호텔 조식 양이 부담스러워서 검색해서 찾아왔는데 너무 좋네요      1     0
# 2348                         가볍게 먹으려했는데 샌드위치 양이 장난 아니네요      1     0
# 2352                         채소도 신선하고 양도 많아서 먹고 나서 든든해요      1     0
# 2353                      양 많아도 채소가 많아서 더부룩하지도 않고 딱 좋아용      1     0
# ...
# 7966                       대표님 돈 안 되는 곳에도 신경 좀 쓰셨으면합니다.      0     0
# 7967                       음식을 다루는 곳에서 위생과 청결은 기본 아닌가요.      0     0
# 7968                      여길 생각하면 최악의 화장실부터 떠오를 것 같습니다.      0     0
# 7970                   그 넓은 커피숍에 남자 화장실이 3 층밖에 없어서 불편함.      0     0
# 7971                  빵이 맛있음 맛있어서 사진 찍는 걸 까먹구 다 먹구 찍엇네요      1     0
# 7976  보통 구석구석 청소하기 힘들어서 먼지도 많이 쌓여 있고 얼룩 묻어 있고 사진만 예쁘...      1     0
# 7981    베이커리 가격이 비싼 데 비해서 퀄이 안 좋음 맛이 별로 임 베이커리류는 비 추천함.      0     0
# 7982                                     음료는 다른 데보다 비싸고      0     0
# 7983                          뷰 이쁜 곳이랑 똑같음 그냥 그냥 그냥 그럼.      1     0
# 7984  뷰는 좋은데 근데 앞에 유리 난간 있어서 사진 찍고 보고 있기에 이쁘지는 않음 야외...      2     0
# 7986  직원 분들 진짜 불친절해요 리뷰 보면 불친절하다는 말 많던데 서비스 개선 좀 해야할...      0     0
# 7987                 이런 리뷰 안 남기는 데 여행 와서 기분만 나빠져서 남깁니다.      0     0
# 7989                                   디저트랑 음료 맛도 별로였어요      0     0
# 7990                                     에이드 티 맛 없습니다..      0     0
# 7991                                   빵이 종류가 많고 맛있습니다.      1     0
# 7995                           아메리카노는 좀 탄 맛? 나는 원두 맛이에요      2     0
# 7996  빵은 소금 빵 팡도르인데 다른 데서 먹는 맛이에요. 포장해 간 애들이 맛있었 름 좋겠네요      1     0
# 7997                                  맛은 굉장히 평범 사람은 많아요      2     0
# 7999                     한적한 시간에 갔음에도 불구하고 주문 받는 직원 불친절      0     0
# 8000                                             뷰는 좋아요      1     0
# 8003                                          빵이 맛있었습니다      1     0
# 8004                                         음료도 괜찮았어요.      1     0
# 8005                                비가 오면 루프탑은 개방하지 않아요      2     0
# 8007                                             뷰는 좋아요      1     0
# 8008                        실연당한 사람들은 바다를 보면서 멍 때리기 좋아요      1     0
# 8016                               안 왔으면 서운할 뻔 출근하기 싫어요      1     0
# 8017                           크기도 크고 가격도 좋고 다양한 빵이 있어요      1     0
# 8020                                  바다 뷰 찾아왔는 데 탁월했어요      1     0
# 8023                   카페 앞이 바다인데 밤이라 오션뷰가 보이지 않아 아쉬워요.      2     0
# 8025                                       카페가 너무 더러웠어요      0     0
# 8026    사람이 많아서 쉽게 지저분해지는 데 중간 중간에 청소를 잘 안 하는 듯..한 느낌..      0     0
# 8027                                    창문도 청소해야할 것 같아요      0     0
# 8028                                   커피랑 디저트... 맛도 별로      0     0
# 8030                                            뷰는 좋아요.      1     0
# 8033    매장은 넓은데 사람이 많아서 주차도 힘들고 정신없었어요. 평일에 가는 걸 추천합니다.      0     0
# 8036                       시그니처 음료수는 품절이라 먹지 못 해 아쉬웠어요.      0     0
# 8037  천국의 계단에서 사진 찍는 사람들도 많았습니다. 바다 배경으로 높은 곳에서 찍으니 ...      1     0
# 8038                     저는 기다리기 싫어서 안 찍고 왔는데 살짝 후회됩니다.      2     0
# 8039                   단점은… 사람이 많은데… 화장실이 너무 작아서 불편했어요.      0     0
# 8041                                       빵이 너무나도 맛있음.      1     0
# 8042                                        커피는 완전 맛없음.      0     0
# 8043                                 주차공간과 화장실이 많이 부족함.      0     0
# 8045  배 아파서 화장실 갔는데 직원분이 화장실 치우는 중 물론 직원이 할 일은 맞지만 손...      0     0
# 8047                                 지나가다가 들렀는 데 너무 좋네요      1     0
# 8050                                             나쁘지 않음      2     0
# 8053      3 층 루프 탑도 있고 3 층에서 한 계단 올라 가면 전망대 같은 곳도 있네욤..      2     0
# 8054   이런 베이커리 카페는 빵은 어디 가나 맛이 동일한 거 같아요 제가 빵 맛을 모르는 건지      0     0
# 8061       많아서 다 먹고 싶은데 뭘 골라야할지 고민하다 그래도 덜 배부른 종류로 골랐어요      2     0
# 8067                                   청소가 전혀 안 되 있네요..      0     0
# 8068                       바다뷰를 봐야하는 데 통유리는 너무 더러워서 뭐..      0     0
# 8075                                    생각보다 가격도 안 비싸요.      1     0
# 8077                 사천 해변 바로 앞에 있는 카페라 바다도 보이고 뷰가 좋아요!      1     0
# 8079                                          주차하기 편하고!      1     0
# 8082                              많이 넓은데 울려서 조금 시끌시끌 해용      0     0
# 8083                       차는 저번보다 맛있어졌는데 몽블랑은 맛이 변했네요.      2     0
# 8084  더군다나 2 층 책상에 이미 빵 부스러기들이 잔뜩이길래 1 층 내려가 직원 두 분한...      0     0
# 8085                                 서비스는 개선이 필요해 보입니다.      0     0
# 8086                                                불친절      0     0
# 8087                                             뷰가 좋아요      1     0
# 8094                                 자리도 많고 넓어서 아주 좋네요.      1     0
# 8096                                       바다 배경도 멋지고요.      1     0
# 8097       시간이 늦어 디카페인 커피 마셨는데..원두 블랜딩이 과한 거인지 약간 한약 맛?      0     0
# 8110                                             뷰도 이쁘고      1     0
# 8112                          다만 창문은 색이 탁함 창문 깨끗하면 좋을 듯      0     0
# 8115                                     가격은 좀 있지만 맛있어요      1     0
# 8121                           커피 맛이 한약 맛이 나서 깜짝 놀랐습니다.      0     0
# 8124                                             뷰가 좋네요      1     0
# 8125                                     풍경이 아름다운 곳입니다.      1     0
# 8126                                           매우 큰 규모고      1     0
# 8127                        하늘을 닿을 듯한 계단은 명소지만 조금 무서워요.      1     0
# 8129  크림 브륄레는 위에 캬라멜을 깨 먹을 수 있는 것이 아니라 그냥 흐르는 형태라 실망...      0     0
# 8131                                         음료는 평범했어요.      0     0
# 8133                               창문이 지저분해 바다색도 달라 보이고      0     0
# 8134                 바닥도 끈적거려 너무 별로였음 매장 청결에 신경 써 주시길..      0     0
# 8136  아인슈패너 6500원 작은 플라스틱 잔에 나오는 데 쫌 그래요.. 맛있는 카페라 찾...      0     0
# 8138                                              뷰도 좋고      1     0
# 8141  잘 알지도 못하면서 화풀이 하려고 손님한테 잔소리하는 모자 쓴 남자 직원 때문에 정...      0     0
# 8143                           좌석도 많고 3 층까지 있어서 넓어서 좋아요      1     0
# 8145                                              뷰도 좋고      1     0
# 8150                                         뷰가 대박이에요!!      1     0
# 8152  빵 맛있긴한데 말차 라떼 주문했는데 주시는 바리스타가 쏟아 놓고 그거 그대로 주더라...      0     0
# 8153                                     사진이 멋지게 나오는 카페      1     0
# 8155                                     빵이 맛나고 뷰가 좋습니다      1     0
# 8156                             근데 후기대로 정말 시장판처럼 시끄럽네요      0     0
# 8158                                초코파이 음료는 플라스틱 잔에 나옴      1     0
# 8159       대형 카페는 아니고 중형 카페 정도인데 직원들 차가움. 동해 바다처럼 차가움..      0     0
# 8160                             매장 안 식물들도 시들어서 기운 없음..      0     0
# 8170                                              뷰도 좋코      1     0
# 8171                                           뷰는 넘 좋은데      1     0
# 8172                  실내가 웅웅거려요 창문이 오픈돼 있으면 좋을 터인데 아쉽네요      0     0
# 8176                      계산할 때 빼 준다면서 소통도 안 돼서 계산 같이 함      0     0
# 8178  케이크 좀 많이 얼어 있는 것까진 그러려니 했는 데 계산 미스랑 친절하기만했어도 이...      0     0
# 8179                 취소 후 재결제 할 수 있었지만 시간 더 버릴까 봐 그냥 나옴      0     0
# 8180                                    여긴 절대 다시는 안 갈래요      0     0
# 8182                                간편하게 커피 한 잔 하기 딱 좋음      1     0
# 8184                  스페셜 커피를 맛보러 리뷰보고 들른 곳 그러나 토스트는 실망      0     0
# 8187                                            따뜻한 커피.      1     0
# 8188                                         뷰도 좋고 조용하고      1     0
# 8194                                          주차도 편리하네요      1     0
# 8200                                              뷰도 좋고      1     0
# 8202  줄 서지 않고 대기실에서 편하게 기다리니 여유롭고 직원들이 서빙해 줘서 번거롭지 않습니다      1     0
# 8205                                          위치도 너무 좋고      1     0
# 8207                      원두별로 ice hot 메뉴가 정해져 있어 아쉽네요.      0     0
# 8210                                     이번에도 어김 없이 방문.      1     0
# 8211                                오늘의 커피가 오늘은 좀 아쉬웠음.      0     0
# 8213                                  카페오레는 라떼랑 맛이 똑같아요      1     0
# 8217                드립 커피는 안 마셔 봤지만 에스프레소 베이스 커피는 별로에요.      0     0
# 8218                요즘 커피 맛있는 데 너무 많아서 굳이 찾아갈 정도는 아니에요.      0     0
# 8220                                           드립은 훙륭했고      1     0
# 8221                                   너티 크림 라떼는 별로입니다…      0     0
# 8222                                         커피 맛이 좋았어요      1     0
# 8230                              드립커피주문시 아이스가 없어서 불편해요      0     0
# 8236                   커피 맛 진짜... 핸드드립은 이렇게 먹는 거구나. 감탄.      1     0
# 8237        그 동안 마신 커피는 뭐였나 싶을 정도로 커피 맛 진짜 최고였어요. 인생커피.      1     0
# 8238  산미는 입맛에 적당하게 살짝 있고 고소하고 부드럽고 커알못인데도 고스란히 맛에 다 ...      1     0
# 8239          너무 맛있어서 홀짝홀짝 마시다 보니 자꾸 줄어드는 커피가 어찌나 아쉽던지.      1     0
# 8241                            테라로사보다는 확실히 급이 더 높은 카페!      1     0
# 8242                                   장인 정신이 고스란히 느껴진다      1     0
# 8243                                          한 번이면 됐어요      0     0
# 8245    카페에 가면 셀프로 계산하는 것이 익숙해져 있어서 오랜만에 카페다운 곳에 다녀온 마음      1     0
# 8246     테이블로 주문을 받으러 오시고 커피도 갖다 주시고 오랜만에 대접 받는 커피 마셨네요      1     0
# 8249                             커피 맛은 커피가 말도 안 되게 부드럽고      1     0
# 8265                                       커피 맛은 물론 좋구요      1     0
# 8266                               커피에 대해선 말이 필요 없는 곳..      1     0
# 8268                          영수증 굳이 달라고 해서 리뷰 남기긴 처음..      2     0
# 8269  기다리세요! 명령조는 기본.. 박이추님 커피 연구도 좋지만 직원 교육도 신경 쓰셔야...      0     0
# 8274    박이추 커피 기대 많이 하고 갔는데 커피 맛이 특별한 것두 아니었어요 그냥 쏘쏘합니다      0     0
# 8277                   게이샤는 취향은 아니지만 너무 궁금해서 한 잔 마셔 봤어요      2     0
# 8278  여름에도 지나가 봤는데 항상 주차장에 차가 많아 선뜻 들어가 볼 엄두가 나지 않았는...      1     0
# 8279                                   내부 시설은 오래 돼 보였지만      2     0
# 8282  괜찮다는 평이 많아 가 보게 됐습니다. 제가 평소에 편의점에서 사 먹던 강릉 커피가...      2     0
# 8284     아시는 분이 여기 비엔나 커피도 맛나다고 해서 다음엔 비엔나 커피 먹으러 오렵니다.      1     0
# 8288                      다만 다른 카페처럼 바다가 보이는 뷰가 아니어서 아쉽      1     0
# 8289                                          커피가 부드러워요      1     0
# 8293                                 카페 라떼는 음 이디야 수준입니다      2     0
# 8296               커피는 양이 작고 비쌌지만 진한 맛을 좋아하는 제겐 괜지 않았어요      0     0
# 8297                                         예가체프 짱이었어요      1     0
# 8298                                               좋습니다      1     0
# 8304                          하지만 웨이팅이 길다는 것은 모두 아는 사실.      0     0
# 8310              드립 커피를 잘 몰라서 맛 평가는 어렵지만 은은하게 잘 마셨습니다.      1     0
# 8311      매장 전체적인 분위기는 바쁜 편이고 그래서 그런지 직원 분들 태도는 기계적이에요.      0     0
# 8314                        바다도 넓은 창으로 볼 수 있어서 기분도 좋았구요      1     0
# 8317          자리에 앉아 있으면 주문 받으러 오시고 커피를 갖다 주시는 것이 신기했어요      1     0
# 8318                                        커피 향과 맛이 좋고      1     0
# 8324                                          친절하진 않습니다      0     0
# 8325                                    하지만 커피는 맛있으니 난감      1     0
# 8326                평일 가서 대기 없이 시다모드립은 역시 맛과 향이 너무 좋았구요      1     0
# 8333        파나마 게이샤가 얼마나 향과 바디 감이 좋은데 그런 걸 다 무시하는 핸드드립…      0     0
# 8334  예가체프도 가장 기본인데도 불구하고 향도 그렇고 맛도 무슨 맛인지 모를 정도의 황당...      0     0
# 8335                          기대 많이 하고 간 곳인데 실망만 하고 가네요      0     0
# 8336                             다만 바나나 타르트는 먹을 만 하네요..      1     0
# 8338                         진심으로 많이 많이 아쉬운 1 세대 커피네요..      0     0
# 8340  10시 쯤 갔는 데 매장 자리가 없어 웨이팅이 좀 있었어요 11시에 밥 먹으러 갈 ...      0     0
# 8341                               커피는 맛있었지만 긴 웨이팅이 아쉽고      2     0
# 8342                               직원 분들 친절한 것도 잘 모르겠어요      2     0
# 8343                                  연휴라 사람도 많고 바쁘셨겠디만      2     0
# 8345                                      재방문은 없을 것 같네요      0     0
# 8348                                        믿고 마시는 커피죠.      1     0
# 8349                                       대기가 길고 복잡함..      0     0
# 8350                                            카피향은조으다      1     0
# 8352  웨이팅 룸을 따로 둬서 조금 기다리긴했어도 정작 커피 마실 땐 주문도 직접 와서 받...      1     0
# 8359                                         케이크는 맛 없어요      0     0
# 8360                                      직원들이 친절하지 않아요      0     0
# 8362                                     저는 커피 맛은 잘 몰라서      2     0
# 8365  개인적으로 클래식한 느낌의 예가체프. 그니까 십 몇 년도 더 전에.. 핸드드립은 여...      1     0
# 8366  여전히 커피를 잘 아는 건 아니지만 나중에 본점 가서 박이추 대표님이 내려 주시는 ...      1     0
# 8367             사실 여기 원두는2-3 종 사 먹어 봤는데.. 그땐 그냥 평범했거든요      2     0
# 8374                                 커피는 따뜻한 게 종류가 다양하고      1     0
# 8375                                   아이스는 거의 없더라고요...      0     0
# 8376               아이스만 좋아하시는 분들은 선택지가 적다는 걸 감안하고 가셔야해요      0     0
# 8377                          디저트는 전체적으로 덜 달고 건강한 느낌입니다      1     0
# 8381  커피와 아이스티 시켰는데 물어 보지도 않고 시럽을 너무 많이 넣어서 물 좀 더 넣어...      0     0
# 8382  아가씨가 삐죽하더니 찔금 한 모금 정도 물을 더 넣어 주더라구요 그래도 너무 달아서...      0     0
# 8383  옆에 주인 박이추 분이 계셨어요 내가 왔다 갔다하는 모습 그대로 쭈우욱 지켜보고 이...      0     0
# 8385                                             돈이 아깝다      0     0
# 8387                                              빵도 없고      0     0
# 8391                                       넘 기대했나 봐요 그닥      0     0
# 8392  여러 가지 커피를 맛봣네요 커피 안 먹는 친구도 커피를 맛보고 너무 깔끔하니 맛 잇...      1     0
# 8397          커피에서 오만 가지 맛이 느껴지네요... 아름답게 표현하면 맛이 픙부하네요      1     0
# 8398                                      생각보다 친절하진 않지만      0     0
# 8415  딸아이가 인스타에서 보고 여행 간 김에 방문했습니다만 가격 인테리어 친절 등등 정말...      0     0
# 8441         충전 물의 맛과 양 빵과의 비율이 저와 일행에게는 아쉽게도 맞지 않았습니다.      0     0
# 8453                            우선 한 줄 평은 맛있지만 특별할 것 없고      1     0
# 8454           크기는 손바닥만 하게 작지만 가격은 창렬 한 에쎈에스 유명 맛집 맛입니다      0     0
# 8456                         음 한 번 먹어 본 거로 만족!한 맛이었습니다.      0     0
# 8458  솔직히 빵이니 맛은 있었지만 그렇다고 돌체테리아만의 특별한 무언가의 맛이 있거나 하...      0     0
# 8459  크기는 너무 작은 데 가격은 사악해서 이것이 과연 그 정도인가 의문이 드는 맛이였습니다.      0     0
# 8461       자리 세 비싼 서울 유명 빵집보다 비싼 가격이 결코 이해되지 않는 맛이었습니다.      0     0
# 8462  디저트 맛집이라고 해서 방문했는 데 포장으로 거의 다 팔리고 남는 것에 그 타르트랑...      1     0
# 8466                                 전반적으로 가격이 비싼 듯합니다.      0     0
# 8468                                        맛있는 데 비싸요..      0     0
# 8472                              가격은 비싼 편인데 확실히 맛은 있어요      1     0
# 8473                                     그렇게 친절하지는 않았어요      0     0
# 8475                                         간판은 올드함...      0     0
# 8477  휘낭시에 틀이 집에 있고 베이킹을 할 수 있다면 궂이 가지 않아도 됨 쉽게 말해 파...      0     0
# 8479                                         가게가 너무 귀엽구      1     0
# 8481                                      직원분들 너무 친절하시고      1     0
# 8485                          하지만 다시 강릉에 간다면 기다릴 수는 없어요      0     0
# 8488                                           커피는 맛있는뎅      1     0
# 8489                                            케이크는 비추      0     0
# 8492                            동네 미관을 헤치지 않는 건물이었음 하네요      2     0
# 8496                                          옛날 감성 납니다      1     0
# 8498                                  더 누르고 싶은데 안 눌러지네요      1     0
# 8505                                          주차는 불편하지만      0     0
# 8506                                       커피숍 커피 맛은 만족      1     0
# 8523                                       근데 주차장이 아쉽네요      0     0
# 8524                             가격에 비해 케이크가 너무 쥐똥만 함..      0     0
# 8528                            2 층 구조인데 2층은 다다미 좌식도 있응      2     0
# 8529                                2 인이 자리할 수 있는 곳이 많음      2     0
# 8532                                      간단한 디저트 메뉴 있음      2     0
# 8534                                           아늑한 카페네요      1     0
# 8537             1 자리 빼고 꽉 찼는 데 다다미 자리였어요 양반 다리가 아쉬웠지만요      2     0
# 8538                                  모카 커피는 보통의 맛이었습니다      2     0
# 8541                                     워낙 유명해서 방문했어요.      2     0
# 8545              시그니처인 바닐라 아인슈패너 달달해서 맛이 없을 수가 없는 맛이죠.      1     0
# 8546                         대신 기본 커피 메뉴는 맛이 좀 떨어지긴합니다.      0     0
# 8549                                덕분에 이쁜 장소에서 프사건졌어욥.      1     0
# 8550                    밀크티를 좋아하는 사람이 가야지 빛을 보는 카페 같습니당      1     0
# 8558                                  가격도 저렴한 편인 거 같아요.      1     0
# 8559               세트로 주문하지 않았는데 계산 시 더 저렴한 세트 적용해 주셨어요      1     0
# 8561                                slow life of wonder      2     0
# 8565  적당한 달달함과 상큼 상큼한데 텁텁하지 않고 따뜻하게 먹어도 맛있더라구요 다음엔 우...      1     0
# 8568        바깥에 자리가 3개 정도 있는 데 옆자리랑 가까워서 조용히 대화하긴 어렵고요.      0     0
# 8569         딱히 뷰 같은 것도 없어서 그냥 실내에서 먹는 것도 나쁘지 않은 것 같네요.      2     0
# 8576                                   비 와서 운치가 너무 좋았다는      1     0
# 8578                          음료는 전통적인 느낌이 많아서 호불호 갈려요.      2     0
# 8580  가 보니 혼자보다는 둘 셋 또는 단체로 오시는 경우도 있긴했지만 대부분 오래 머무르...      1     0
# 8589            사진에서 보던 느낌 그대로 고즈넉하고 조용했어요 딱 제가 좋아하는 느낌      1     0
# 8591                                     쉬다 가는 느낌의 카페네요      1     0
# 8594                                     그래도 음료는 맛있었습니다      1     0
# 8595                             더워서 툇마루 이용을 못 해서 아쉬웠지만      2     0

# %%
from sklearn.metrics import classification_report

print(classification_report(test_set['label'], test_set['pred']) )
# Out:
#               precision    recall  f1-score   support
#
#            0       0.16      0.67      0.26       549
#            1       0.99      0.50      0.67      7739
#            2       0.07      0.57      0.13       309
#
#     accuracy                           0.52      8597
#    macro avg       0.41      0.58      0.35      8597
# weighted avg       0.90      0.52      0.62      8597
