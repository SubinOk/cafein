# %%
# !pip install kiwipiepy
# Out:
# ...
#      ------------------------------------ 651.8/651.8 kB 733.2 kB/s eta 0:00:00
# ...
#      -------------------------------------- 30.5/30.5 MB 540.3 kB/s eta 0:00:00
#   Preparing metadata (setup.py): started
#   Preparing metadata (setup.py): finished with status 'done'
# ...
#   Created wheel for kiwipiepy-model: filename=kiwipiepy_model-0.14.0-py3-none-any.whl size=30560048 sha256=76519cfcda5f3bfa7d253c9f1dc42d793b5bad1efd72dfb1bac337f90d99ac65
#   Stored in directory: c:\users\user\appdata\local\pip\cache\wheels\cd\10\8e\2d32ad6e25239a4edf2b1d862924c86e646eb3b0f677297320
# Successfully built kiwipiepy-model
# ...
# [notice] A new release of pip available: 22.2.2 -> 22.3.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
import pandas as pd
from kiwipiepy import Kiwi

kiwi = Kiwi()

# %%
data = pd.read_csv('./data/train_data_1.csv', encoding='utf-8-sig')

# %%
review = data['review']

# %%
kiwi.tokenize(review[0])
# Out:
# [Token(form='맛있', tag='VA', start=0, len=2),
#  Token(form='어요', tag='EF', start=2, len=2),
#  Token(form='~', tag='SO', start=4, len=1)]

# %%
for i in range(0, 50):
    result = kiwi.tokenize(review[i])
    for token in result:
        print(f"{token.form}\t{token.tag}")
    
    print('-'*30)
# Out:
# 맛있	VA
# 어요	EF
# ~	SO
# ------------------------------
# 만족도	NNG
# 최상	NNG
# 의	JKG
# 커피	NNG
# 맛	NNG
# 집	NNG
# ------------------------------
# 찌	VV
# ᆫ	ETM
# 커피	NNG
# 맛	NNG
# 집	NNG
# ㅎㅎ	SW
# ------------------------------
# 로마노	NNP
# 진짜	MAG
# 달달하	VA
# 고	EC
# 맛있	VA
# 고	EC
# 아이스크림	NNG
# 라	NNG
# 떼	NNG
# 도	JX
# 꼬소	NNG
# 하	XSA
# 고	EC
# 달달하	VA
# 고	EC
# 진짜	MAG
# 맛있	VA
# 어요	EF
# !!	SF
# 마리토쪼도	NNG
# 크림	NNG
# 부드럽	VA-I
# 고	EC
# 빵	NNG
# 도	JX
# 포실포실	MAG
# 🥰	SH
# 재	XPN
# 방문	NNG
# 의사	NNG
# 있	VA
# 어요	EF
# ------------------------------
# 커조남	NNG
# 커피	NNG
# 는	JX
# 힐링	NNP
# 이	VCP
# ᆸ니다	EF
# 소금	NNG
# 빵	NNG
# 도	JX
# 맛있	VA
# 어요	EF
# ------------------------------
# 시나몬	NNG
# 롤	NNG
# 맛있	VA
# 어용	EF
# ✨	SW
# 하지만	MAJ
# 소금	NNG
# 빵	NNG
# 은	JX
# 동굴	NNG
# 이	JKS
# 없	VA
# 고	EC
# 좀	MAG
# 마르	VV
# 어	EC
# 있	VX
# 어서	EC
# 아쉽	VA-I
# 었	EP
# 어요	EF
# ------------------------------
# 드립커피	NNG
# 하	XSV
# 면	EC
# 커조남	NNG
# !	SF
# 오늘	MAG
# 드립커피	NNP
# 는	JX
# 좀	MAG
# 애매	NNG
# 하	XSA
# ᆫ	ETM
# 맛	NNG
# 이	VCP
# 기	ETN
# ᆫ	JX
# 하	VX
# ...

# %%
# !pip install py-hanspell
# Out:
# ...
# [notice] A new release of pip available: 22.2.2 -> 22.3.1
# [notice] To update, run: python.exe -m pip install --upgrade pip
# ...

# %%
from hanspell import spell_checker
result = spell_checker.check(u'(붕어빵)')
print(result)
# for i in range(50):
#     result = spell_checker.check(review[i])
#     print(result.original)
#     print(result.checked)
#     print()
# Out:
# Checked(result=True, original='(붕어빵)', checked='(붕어빵)', errors=0, words=OrderedDict([('(붕어빵)', 0)]), time=0.04706311225891113)

# %%
# !pip install git+https://github.com/haven-jeon/PyKoSpacing.git
# Out:
# ...
#   Cloning https://github.com/haven-jeon/PyKoSpacing.git to c:\users\user\appdata\local\temp\pip-req-build-s2lwq7gd
#   Resolved https://github.com/haven-jeon/PyKoSpacing.git to commit 1f8d11c59ac93525432f164e4c237ece4e298691
#   Preparing metadata (setup.py): started
#   Preparing metadata (setup.py): finished with status 'done'
# ...
#      -------------------------------------- 444.1/444.1 MB 6.1 MB/s eta 0:00:00
# ...
#      ---------------------------------------- 2.7/2.7 MB 11.5 MB/s eta 0:00:00
# ...
#      ---------------------------------------- 1.6/1.6 MB 20.8 MB/s eta 0:00:00
# ...
#      ---------------------------------------- 5.8/5.8 MB 21.8 MB/s eta 0:00:00
# ...
#      ---------------------------------------- 42.6/42.6 kB ? eta 0:00:00
# ...
#      ------------------------------------- 438.7/438.7 kB 26.8 MB/s eta 0:00:00
# ...
#   Created wheel for pykospacing: filename=pykospacing-0.5-py3-none-any.whl size=2268708 sha256=05ca889cef241fea3ba1b4e32c69144dd1d214f6533d5ab53e6048078dd3d2de
# ...

# %%
from pykospacing import Spacing

sent = '김철수는 극중 두 인격의 사나이 이광수 역을 맡았다. 철수는 한국 유일의 태권도 전승자를 가리는 결전의 날을 앞두고 10년간 함께 훈련한 사형인 유연재(김광수 분)를 찾으러 속세로 내려온 인물이다.'

new_sent = sent.replace(" ", '') # 띄어쓰기가 없는 문장으로 만들기
print(new_sent)

spacing = Spacing()
kospacing_sent = spacing(new_sent) 

print(sent)
print(kospacing_sent)
# Out:
# 김철수는극중두인격의사나이이광수역을맡았다.철수는한국유일의태권도전승자를가리는결전의날을앞두고10년간함께훈련한사형인유연재(김광수분)를찾으러속세로내려온인물이다.
# 1/1 [==============================] - 1s 834ms/step
# 김철수는 극중 두 인격의 사나이 이광수 역을 맡았다. 철수는 한국 유일의 태권도 전승자를 가리는 결전의 날을 앞두고 10년간 함께 훈련한 사형인 유연재(김광수 분)를 찾으러 속세로 내려온 인물이다.
# 김철수는 극중 두 인격의 사나이 이광수 역을 맡았다. 철수는 한국 유일의 태권도 전승자를 가리는 결전의 날을 앞두고 10년간 함께 훈련한 사형인 유연재(김광수 분)를 찾으러 속세로 내려온 인물이다.

# %%
spacing = Spacing()
test = []

for sent_i in review:
    new_sent_i = spell_checker.check(sent_i).checked
    new_sent_i = spacing(new_sent_i)
    print('원본 : ', sent_i)
    print('맞춤법+띄어 : ', new_sent_i)
    print()
# Out:
# 1/1 [==============================] - 0s 35ms/step
# 원본 :  맛있어요~
# 맞춤법+띄어 :  맛있어요~
#
# 1/1 [==============================] - 0s 41ms/step
# 원본 :  만족도 최상의 커피맛집
# 맞춤법+띄어 :  만족도 최상의 커피 맛 집
#
# 1/1 [==============================] - 0s 39ms/step
# 원본 :  찐 커피맛집ㅎㅎ
# 맞춤법+띄어 :  찐 커피 맛집 ㅎㅎ
#
# 1/1 [==============================] - 0s 38ms/step
# 원본 :  로마노 진짜 달달하고 맛있고 아이스크림라떼도 꼬소하고 달달하고 진짜 맛있어요!! 마리토쪼도 크림 부드럽고 빵도 포실포실🥰 재방문 의사 있어요
# 맞춤법+띄어 :  로마노 진짜 달달하고 맛있고 아이스크림 라테도 고소하고 달달하고 진짜 맛있어요!! 마리도 쪼도 크림 부드럽고 빵도 포슬포슬🥰 재방문 의사 있어요
#
# 1/1 [==============================] - 0s 34ms/step
# 원본 :  커조남 커피는 힐링입니다 소금빵도 맛있어요
# 맞춤법+띄어 :  커도 남 커피는 힐링입니다 소금 빵도 맛있어요
#
# 1/1 [==============================] - 0s 45ms/step
# 원본 :  시나몬롤 맛있어용 ✨
# 하지만 소금빵은 동굴이 없고 좀 말라있어서 아쉬웠어요
# 맞춤법+띄어 :  시나몬롤 맛있어요 ✨ 하지만 소금 빵은 동굴이 없고 좀 말라 있어서 아쉬웠어요
#
# 1/1 [==============================] - 0s 46ms/step
# 원본 :  드립커피하면 커조남! 오늘 드립커피는 좀 애매한 맛이긴 했지만 리필커피가 맛있어서 괜춘~바로 앞 공영주차장에 주차가능
# ...
