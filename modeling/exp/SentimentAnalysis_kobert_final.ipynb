# %%
# !pip install transformers
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: transformers in /usr/local/lib/python3.8/dist-packages (4.25.1)
# Requirement already satisfied: tqdm>=4.27 in /usr/local/lib/python3.8/dist-packages (from transformers) (4.64.1)
# Requirement already satisfied: filelock in /usr/local/lib/python3.8/dist-packages (from transformers) (3.8.2)
# Requirement already satisfied: requests in /usr/local/lib/python3.8/dist-packages (from transformers) (2.23.0)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.8/dist-packages (from transformers) (6.0)
# Requirement already satisfied: huggingface-hub<1.0,>=0.10.0 in /usr/local/lib/python3.8/dist-packages (from transformers) (0.11.1)
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.8/dist-packages (from transformers) (2022.6.2)
# Requirement already satisfied: tokenizers!=0.11.3,<0.14,>=0.11.1 in /usr/local/lib/python3.8/dist-packages (from transformers) (0.13.2)
# Requirement already satisfied: numpy>=1.17 in /usr/local/lib/python3.8/dist-packages (from transformers) (1.21.6)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.8/dist-packages (from transformers) (21.3)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /usr/local/lib/python3.8/dist-packages (from huggingface-hub<1.0,>=0.10.0->transformers) (4.4.0)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in /usr/local/lib/python3.8/dist-packages (from packaging>=20.0->transformers) (3.0.9)
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/lib/python3.8/dist-packages (from requests->transformers) (3.0.4)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /usr/local/lib/python3.8/dist-packages (from requests->transformers) (1.24.3)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.8/dist-packages (from requests->transformers) (2022.12.7)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.8/dist-packages (from requests->transformers) (2.10)

# %%
import pandas as pd
import numpy as np
import urllib.request
import os
from tqdm import tqdm
import tensorflow as tf
from transformers import BertTokenizer, TFBertModel
from sklearn.model_selection import train_test_split

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# 데이터 불러오기
data = pd.read_csv('/content/drive/MyDrive/공장/train_fff.csv')

idx = data[data['label']==2].index
data.drop(idx , inplace=True)

data = data.sample(frac=1)

data['label'].value_counts()
# Out:
# 0    700
# 1    700
# Name: label, dtype: int64

# %%
train_data, test_data = train_test_split(data, test_size=.2, random_state=2022)

print('훈련용 리뷰 개수 :', len(train_data))
print('테스트용 리뷰 개수 :', len(test_data))
# Out:
# 훈련용 리뷰 개수 : 1120
# 테스트용 리뷰 개수 : 280

# %% [markdown]
# ---

# %%
tokenizer = BertTokenizer.from_pretrained("klue/bert-base")

# %%
def create_examples(df):
    example = []
    label = []
    for (i, row) in enumerate(df.values):
        example.append(row[0])
        label.append(row[1:])
    
    return example, label

# %%
train_example, train_label = create_examples(train_data)
test_example, test_label = create_examples(test_data)

# %%
def convert_examples_to_features(examples, labels, max_seq_len, tokenizer):
    
    input_ids, attention_masks, token_type_ids, data_labels = [], [], [], []
    
    for example, label in tqdm(zip(examples, labels), total=len(examples)):
        input_id = tokenizer.encode(example, max_length=max_seq_len, pad_to_max_length=True)
        padding_count = input_id.count(tokenizer.pad_token_id)
        attention_mask = [1] * (max_seq_len - padding_count) + [0] * padding_count
        token_type_id = [0] * max_seq_len

        assert len(input_id) == max_seq_len, "Error with input length {} vs {}".format(len(input_id), max_seq_len)
        assert len(attention_mask) == max_seq_len, "Error with attention mask length {} vs {}".format(len(attention_mask), max_seq_len)
        assert len(token_type_id) == max_seq_len, "Error with token type length {} vs {}".format(len(token_type_id), max_seq_len)

        input_ids.append(input_id)
        attention_masks.append(attention_mask)
        token_type_ids.append(token_type_id)
        data_labels.append(label)

    input_ids = np.array(input_ids, dtype=int)
    attention_masks = np.array(attention_masks, dtype=int)
    token_type_ids = np.array(token_type_ids, dtype=int)

    data_labels = np.asarray(data_labels, dtype=np.int32)

    return (input_ids, attention_masks, token_type_ids), data_labels

# %%
max_seq_len = 128

# %%
train_X, train_y = convert_examples_to_features(train_example, train_label, max_seq_len=max_seq_len, tokenizer=tokenizer)
test_X, test_y = convert_examples_to_features(test_example, test_label, max_seq_len=max_seq_len, tokenizer=tokenizer)
# Out:
#   0%|          | 0/1120 [00:00<?, ?it/s]Truncation was not explicitly activated but `max_length` is provided a specific value, please use `truncation=True` to explicitly truncate examples to max length. Defaulting to 'longest_first' truncation strategy. If you encode pairs of sequences (GLUE-style) with the tokenizer you can select this strategy more precisely by providing a specific strategy to `truncation`.
# /usr/local/lib/python3.8/dist-packages/transformers/tokenization_utils_base.py:2336: FutureWarning: The `pad_to_max_length` argument is deprecated and will be removed in a future version, use `padding=True` or `padding='longest'` to pad to the longest sequence in the batch, or use `padding='max_length'` to pad to a max length. In this case, you can give a specific length with `max_length` (e.g. `max_length=45`) or leave max_length to None to pad to the maximal input size of the model (e.g. 512 for Bert).
#   warnings.warn(
# 100%|██████████| 1120/1120 [00:00<00:00, 4986.82it/s]
# 100%|██████████| 280/280 [00:00<00:00, 5234.12it/s]

# %%
base_model = TFBertModel.from_pretrained("klue/bert-base", from_pt=True)
# Out:
# Some weights of the PyTorch model were not used when initializing the TF 2.0 model TFBertModel: ['cls.predictions.transform.LayerNorm.weight', 'cls.predictions.transform.dense.weight', 'bert.embeddings.position_ids', 'cls.predictions.decoder.weight', 'cls.seq_relationship.weight', 'cls.predictions.transform.LayerNorm.bias', 'cls.predictions.transform.dense.bias', 'cls.seq_relationship.bias', 'cls.predictions.bias', 'cls.predictions.decoder.bias']
# - This IS expected if you are initializing TFBertModel from a PyTorch model trained on another task or with another architecture (e.g. initializing a TFBertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing TFBertModel from a PyTorch model that you expect to be exactly identical (e.g. initializing a TFBertForSequenceClassification model from a BertForSequenceClassification model).
# All the weights of TFBertModel were initialized from the PyTorch model.
# If your task is similar to the task the model of the checkpoint was trained on, you can already use TFBertModel for predictions without further training.

# %%
input_ids_layer = tf.keras.layers.Input(shape=(max_seq_len,), dtype=tf.int32)
attention_masks_layer = tf.keras.layers.Input(shape=(max_seq_len,), dtype=tf.int32)
token_type_ids_layer = tf.keras.layers.Input(shape=(max_seq_len,), dtype=tf.int32)

x = base_model.bert([input_ids_layer, attention_masks_layer, token_type_ids_layer])[1]
outputs = tf.keras.layers.Dense(1, kernel_initializer=tf.keras.initializers.TruncatedNormal(0.02), activation='sigmoid', name='classifier')(x)

# %%
class TFBertForSequenceClassification(tf.keras.Model):
    def __init__(self, model_name):
        super(TFBertForSequenceClassification, self).__init__()
        self.bert = TFBertModel.from_pretrained(model_name, from_pt=True)
        self.classifier = tf.keras.layers.Dense(1,
                                                kernel_initializer=tf.keras.initializers.TruncatedNormal(0.02),
                                                activation='sigmoid',
                                                name='classifier')

    def call(self, inputs):
        input_ids, attention_mask, token_type_ids = inputs
        outputs = self.bert(input_ids=input_ids, attention_mask=attention_mask, token_type_ids=token_type_ids)
        cls_token = outputs[1]
        prediction = self.classifier(cls_token)

        return prediction

# %%
model = tf.keras.models.Model(inputs=[input_ids_layer, attention_masks_layer, token_type_ids_layer], outputs=outputs)
optimizer = tf.keras.optimizers.Adam(learning_rate=5e-5)
loss = tf.keras.losses.BinaryCrossentropy()
model.compile(optimizer=optimizer,  loss=loss, metrics = ['accuracy'])

# %%
model.fit(train_X, train_y, epochs=5, batch_size=16, validation_split=0.2)
# Out:
# Epoch 1/5
# 56/56 [==============================] - 39s 460ms/step - loss: 0.3204 - accuracy: 0.8728 - val_loss: 0.2295 - val_accuracy: 0.9241
# Epoch 2/5
# 56/56 [==============================] - 25s 439ms/step - loss: 0.1258 - accuracy: 0.9632 - val_loss: 0.2044 - val_accuracy: 0.9241
# Epoch 3/5
# 56/56 [==============================] - 24s 422ms/step - loss: 0.0562 - accuracy: 0.9799 - val_loss: 0.4581 - val_accuracy: 0.8839
# Epoch 4/5
# 56/56 [==============================] - 24s 433ms/step - loss: 0.0830 - accuracy: 0.9777 - val_loss: 0.3245 - val_accuracy: 0.9152
# Epoch 5/5
# 56/56 [==============================] - 24s 434ms/step - loss: 0.0413 - accuracy: 0.9922 - val_loss: 0.4505 - val_accuracy: 0.9018

# %%
results = model.evaluate(test_X, test_y, batch_size=8)
print("test loss, test acc: ", results)
# Out:
# 35/35 [==============================] - 6s 83ms/step - loss: 0.4340 - accuracy: 0.8786
# test loss, test acc:  [0.43404513597488403, 0.8785714507102966]

# %%
model.predict(test_X)
# Out:
# 9/9 [==============================] - 5s 256ms/step
# array([[5.7624775e-04],
#        [4.3686056e-03],
#        [9.8941642e-01],
#        [9.9917573e-01],
#        [9.9906021e-01],
#        [9.9801755e-01],
#        [1.1070370e-02],
#        [6.0794955e-01],
#        [9.9879253e-01],
#        [7.0077246e-01],
#        [4.6862548e-04],
#        [4.8948936e-03],
#        [4.0427604e-04],
#        [9.9758577e-01],
#        [1.9313545e-04],
#        [9.9961603e-01],
#        [9.9341488e-01],
#        [9.9981540e-01],
#        [1.1259083e-04],
#        [8.8930305e-04],
#        [2.9319723e-04],
#        [9.9944240e-01],
#        [5.0472573e-04],
#        [9.9902904e-01],
#        [9.1650498e-01],
#        [3.2678616e-01],
#        [7.9625010e-05],
#        [9.7904086e-01],
#        [4.0084790e-03],
#        [1.3684400e-04],
#        [5.0249521e-04],
#        [9.9941730e-01],
#        [1.1830962e-02],
#        [9.8212665e-01],
#        [2.1684734e-04],
#        [9.9929917e-01],
#        [9.9922442e-01],
#        [9.9896061e-01],
#        [8.3175766e-01],
#        [9.2622991e-05],
#        [8.8892025e-01],
#        [7.9340016e-04],
#        [3.8127189e-03],
#        [4.4475519e-04],
#        [9.8432868e-04],
#        [9.9956161e-01],
#        [9.9895966e-01],
#        [6.0189992e-01],
#        [9.9957377e-01],
#        [1.9874737e-04],
#        [9.9863487e-01],
#        [9.9932551e-01],
#        [9.9973482e-01],
#        [2.8895994e-04],
#        [1.4470154e-04],
#        [2.5616735e-03],
#        [9.8459458e-01],
#        [2.0703825e-03],
#        [2.4450494e-03],
#        [3.9638171e-04],
#        [9.9856853e-01],
#        [1.0394502e-03],
#        [1.7555198e-04],
#        [9.9784195e-01],
#        [9.8551327e-01],
#        [8.1439537e-04],
#        [9.9815935e-01],
#        [1.2053673e-04],
#        [1.3808269e-04],
#        [7.0295442e-04],
#        [5.4452330e-04],
#        [9.9881268e-01],
#        [2.8927797e-03],
#        [9.9929881e-01],
#        [9.9973935e-01],
#        [5.7981708e-03],
#        [5.9715664e-04],
#        [9.9923563e-01],
#        [9.9983323e-01],
#        [9.9957782e-01],
#        [9.9953151e-01],
#        [5.3848920e-04],
#        [8.8126552e-01],
#        [9.9428457e-01],
#        [8.9413047e-01],
#        [5.8518932e-04],
#        [5.2714380e-03],
#        [9.9845755e-01],
#        [9.9638063e-01],
#        [2.6275538e-02],
#        [9.9973935e-01],
#        [6.1348516e-01],
#        [8.0891530e-04],
#        [9.6529692e-01],
#        [1.0041881e-03],
#        [9.9972481e-01],
#        [9.9916279e-01],
#        [9.9428719e-01],
#        [9.9874026e-01],
#        [3.3739783e-04],
#        [9.9906129e-01],
#        [1.7008277e-04],
#        [1.0566709e-04],
#        [9.9945754e-01],
#        [1.4657028e-04],
#        [6.0141065e-05],
#        [3.1429768e-04],
#        [5.3665839e-04],
#        [1.4348981e-04],
#        [9.3211675e-01],
#        [3.1481232e-04],
#        [2.9715872e-04],
#        [7.4997731e-03],
#        [2.2814704e-04],
#        [2.1993373e-01],
#        [9.9741685e-01],
#        [9.9959248e-01],
#        [9.9961406e-01],
#        [9.9160528e-01],
#        [3.8323319e-04],
#        [9.9964428e-01],
#        [9.9511456e-01],
#        [9.9945039e-01],
#        [9.9933654e-01],
#        [9.9836987e-01],
#        [3.0058202e-01],
#        [7.8589132e-05],
#        [9.9972612e-01],
#        [9.8052043e-01],
#        [9.9957687e-01],
#        [1.3827202e-04],
#        [9.9793041e-01],
#        [1.9773234e-04],
#        [9.2100626e-01],
#        [9.9800783e-01],
#        [9.9448782e-01],
#        [9.9926358e-01],
#        [2.8993574e-03],
#        [6.2545872e-01],
#        [2.6731429e-04],
#        [9.9898392e-01],
#        [8.9155853e-04],
#        [9.9954033e-01],
#        [6.2286569e-04],
#        [3.7728794e-02],
#        [9.9979347e-01],
#        [1.9358384e-04],
#        [9.9963546e-01],
#        [5.3728107e-02],
#        [3.6113933e-01],
#        [9.9964643e-01],
#        [3.0951649e-03],
#        [1.4093857e-04],
#        [3.3204662e-04],
#        [9.9960858e-01],
#        [8.3474195e-01],
#        [9.9937409e-01],
#        [9.9784255e-01],
#        [9.9954128e-01],
#        [9.9840540e-01],
#        [4.4956690e-04],
#        [9.9975401e-01],
#        [9.9685788e-01],
#        [9.9848515e-01],
#        [2.4987257e-04],
#        [9.9973935e-01],
#        [9.9895084e-01],
#        [9.9952674e-01],
#        [2.2844461e-04],
#        [3.8767995e-03],
#        [1.4486804e-04],
#        [2.2878811e-04],
#        [9.9980360e-01],
#        [9.9942422e-01],
#        [5.5024831e-04],
#        [1.0272814e-02],
#        [9.9952281e-01],
#        [2.0114527e-04],
#        [3.0317539e-04],
#        [1.1308398e-03],
#        [3.5686377e-02],
#        [9.3583196e-02],
#        [9.5999885e-01],
#        [4.7945997e-04],
#        [2.9602766e-04],
#        [7.7947264e-04],
#        [2.3735042e-04],
#        [2.3155082e-04],
#        [9.9973220e-01],
#        [4.4660259e-04],
#        [1.7694908e-03],
#        [1.6997884e-04],
#        [1.3718853e-04],
#        [9.9819666e-01],
#        [9.9986863e-01],
#        [2.2794607e-03],
#        [9.9782348e-01],
#        [1.0697781e-04],
#        [1.8183154e-03],
#        [1.6094065e-04],
#        [2.3157995e-04],
#        [2.6166043e-03],
#        [1.6099759e-04],
#        [2.5988472e-04],
#        [1.9983560e-04],
#        [9.3011692e-02],
#        [3.9468944e-01],
#        [9.9948716e-01],
#        [9.8963213e-01],
#        [1.7445269e-03],
#        [2.4148753e-04],
#        [9.9964941e-01],
#        [1.6041377e-04],
#        [9.9824560e-01],
#        [5.0835928e-04],
#        [1.0069937e-01],
#        [1.1901496e-04],
#        [2.8782769e-04],
#        [9.9885738e-01],
#        [1.0234464e-04],
#        [9.9971086e-01],
#        [4.4381057e-04],
#        [6.9884013e-04],
#        [5.1552337e-04],
#        [1.6215106e-04],
#        [8.4765270e-05],
#        [1.0213850e-03],
#        [9.9976581e-01],
#        [9.9969327e-01],
#        [9.9764305e-01],
#        [3.8256604e-04],
#        [9.9801266e-01],
#        [9.9970704e-01],
#        [9.9924338e-01],
#        [8.5038372e-04],
#        [9.9940574e-01],
#        [3.3785973e-04],
#        [9.9885416e-01],
#        [9.8716903e-01],
#        [9.9936110e-01],
#        [2.2571725e-01],
#        [4.9054099e-04],
#        [3.1130246e-04],
#        [9.3913870e-04],
#        [9.9948823e-01],
#        [9.9896038e-01],
#        [2.8102644e-04],
#        [9.9559093e-01],
#        [9.9926347e-01],
#        [9.9962175e-01],
#        [9.9885416e-01],
#        [9.1617182e-04],
#        [6.3010520e-01],
#        [6.7373348e-04],
#        [1.0541815e-01],
#        [9.9951673e-01],
#        [1.4942361e-03],
#        [9.9957711e-01],
#        [1.4873875e-04],
#        [9.9822825e-01],
#        [4.4966739e-04],
#        [9.5948542e-04],
#        [9.6521276e-04],
#        [3.6443733e-02],
#        [9.6446967e-01],
#        [9.9865121e-01],
#        [5.5866310e-04],
#        [3.6274511e-04],
#        [1.0257557e-03],
#        [9.9695790e-01],
#        [9.9985576e-01],
#        [1.4444776e-02],
#        [9.9948847e-01],
#        [9.9900913e-01],
#        [7.6147401e-01],
#        [3.3939514e-02],
#        [9.9984229e-01],
#        [9.9976438e-01],
#        [9.9974829e-01],
#        [2.7132244e-04]], dtype=float32)

# %%
model.save("/content/drive/MyDrive/공장/SA_kobert_model.")
# Out:
# WARNING:absl:Found untraced functions such as embeddings_layer_call_fn, embeddings_layer_call_and_return_conditional_losses, encoder_layer_call_fn, encoder_layer_call_and_return_conditional_losses, pooler_layer_call_fn while saving (showing 5 of 420). These functions will not be directly callable after loading.

# %%
test_set = pd.read_csv('/content/drive/MyDrive/공장/test_fff.csv')
# test_set = test_set[['reviews']]
# test_set['y'] = 0
test_set = test_set.dropna()
idx = test_set[test_set['label']==2].index
test_set.drop(idx , inplace=True)
test_set = test_set.sample(frac=1)

test_set = test_set.sample(500)

test_set['label'].value_counts()
# Out:
# 1    467
# 0     33
# Name: label, dtype: int64

# %%
test_example, test_label = create_examples(test_set)
test_X, _ = convert_examples_to_features(test_example, test_label, max_seq_len=max_seq_len, tokenizer=tokenizer)
# Out:
#   0%|          | 0/500 [00:00<?, ?it/s]/usr/local/lib/python3.8/dist-packages/transformers/tokenization_utils_base.py:2336: FutureWarning: The `pad_to_max_length` argument is deprecated and will be removed in a future version, use `padding=True` or `padding='longest'` to pad to the longest sequence in the batch, or use `padding='max_length'` to pad to a max length. In this case, you can give a specific length with `max_length` (e.g. `max_length=45`) or leave max_length to None to pad to the maximal input size of the model (e.g. 512 for Bert).
#   warnings.warn(
# 100%|██████████| 500/500 [00:00<00:00, 5206.27it/s]

# %%
pred = model.predict(test_X)
# Out:
# 16/16 [==============================] - 4s 263ms/step

# %%
len(pred)
# Out:
# 500

# %%
predict = pred.copy()

# %%
# predict = np.argmax(predict, axis=1)
predict = np.where(pred>0.5, 1, 0).reshape(-1)

# %%
len(predict)
# Out:
# 500

# %%
test_set['pred'] = predict

# %%
pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows', None)

# %%
# test_set.loc[test_set['pred']==0]
test_set
# Out:
#                                                 reviews  label  pred
# 5541                                      역대 급 인생 도너츠..      1     1
# 5836                         늦은 저녁이나 사람 많은 시간 피해 가시길...      0     0
# 987                                    근데 초코파이 종류는 똑같아요      1     0
# 5659                                   시그니처 메뉴 꼭 드셔 보세요      1     1
# 2762                                          사진 찍기 좋아요      1     1
# 2081                                             분위기 좋고      1     1
# 4149                         무엇 보다 생 애플 망고 빙수가 너무 맛있었어요      1     1
# 787                                  소문 듣고 찾아온 제주도 빵집!!      1     1
# 5513  메뉴가 다 빠지고 없어서 우도 땅콩 도너츠만 샀는데 너무 맛있어서 그 다음 날 또 갔어요      1     1
# 7227                     토요일인데도 운이 좋아서 웨이팅 짧아서 완전 좋았어요!      1     1
# 6975              30분 웨이팅 음료 제조 30분 마시는 시간 3분 걸린 툇마루 커피      0     0
# 2638             인테리어가 정말 멋진 이 곳 넓은 정원에서 커피타임 하는 거 같아요!      1     1
# 7993                   빵 명장이 한다길래 와 봤는데 기대를 너무 많이 했나 봐요      0     1
# 6157                                         빵 종류 정말 많고      1     1
# 3150                          경주 카페 마르쉐 디저트와 커피가 맛있는 곳.      1     1
# 4634                               다음에는 감자 스프 먹어 보려구요!!      1     1
# 1208                                당근 케이크와 잠봉뵈르도 맛있어요!      1     1
# 6544                               버스 타고도 충분히 이동이 가능하네요      1     1
# 406                                      간절곶 바로 앞이라 좋네요      1     1
# 1862                          쌀쌀한 날씨에 따뜻한 라떼 마시면서 힐링했어요      1     1
# 2949                                       뷰가 넘 예쁜 곳이네요      1     1
# 4803                         매장에 가위와 집게 있는 것도 센스 있어 좋았고      1     1
# 4220                                  주차하기도 좋고 실내도 갈끔해요      1     1
# 1489                                 함께 언냐 동생 모두 굳뜨라 야호      1     1
# 8172                  실내가 웅웅거려요 창문이 오픈돼 있으면 좋을 터인데 아쉽네요      0     0
# 2011                                          뷰가 끝내 줘요.      1     1
# 3581                        말차는 맛있는 데 초코는 살짝 맹 맹한 느낌..?      1     1
# 4367                                      회전율이 좋은 거 같아요      1     1
# 3445                                    빵과 커피 부드럽고 맛있네요      1     1
# 8043                                 주차공간과 화장실이 많이 부족함.      0     0
# 7018                             흑임자 커피 워우워 맛있다!!!!!!!!      1     1
# 753                                                 완전!      1     1
# 2223                                              뷰도 좋고      1     1
# 7743  관광지라고 비싸기만하고 뷰로 그냥 퉁 치는 곳들이 많은데 여기는 베이커리 종류도 커...      1     1
# 6798                                     입장권 할인 받으니 좋네요      1     1
# 1233                          야외 테이블이 많아서 가을 단풍 즐기기 좋아요      1     1
# 7844                                            경치가 좋아요      1     1
# 5804                                       선물로 샀는 데 좋아요      1     1
# 8081                                        음료랑 빵은 쏘쏘..      0     1
# 5832                                     가격 대비 빵과 크림의 맛      1     1
# 7774                                              뷰도 좋고      1     1
# 4442                                        제주 베이글 맛집!!      1     1
# 6806                                          카페 안도 예쁘고      1     1
# 1886                                      편안하게 휴식하기 좋아요      1     1
# 5860                                      직원이 부족한 느낌입니다      0     0
# 3377                                          커피도 좋았어요.      1     1
# 3474                                  소금 빵 종류별로 있어서 좋아요      1     1
# 3551                        이름도 귀엽고 아이스크림이랑 쉐이크 다 맛있어요!      1     1
# 2512                                  크리스마스 트리 보려갔어여!!!      1     1
# 5248  한 번 도전적으로 용두암 클라우드 주문해 봤는 데 커피 못 마시는 제게는 너무 강한...      1     1
# 4828                                        다음에 또 와야겠어요      1     1
# 813                                         커피도 빵도 맛있어요      1     1
# 2446                                               맛있어여      1     1
# 2182                          뷰가 너무 좋아서 멍하니 시간이 금방 갑니다.      1     1
# 3160                                   세 번째 방문인데 항상 좋아요      1     1
# 1384                                  샌드위치와 음료 모두 맛있었어요      1     1
# 6551  매장이 정말 작아서 한 명씩만 들어올 수 있는 데 오히려 조용하고 편한 분위기여서 ...      1     1
# 1428                                           다시 방문 예정      1     1
# 3674  에그타르트 위에 계핏 가루 슈가 파우더 기호에 맞게 뿌려서 먹으니 더욱 더 맛있어요!!!      1     1
# 6040                    안에 떡 들어 있는 빵도 있던데 쫀득쫀득하니 맛있었어요.      1     1
# 2979                                       늦게까지 해서 좋았어요      1     1
# 255                                  매장도 넓어서 대화하기 좋았어요!      1     1
# 1456                                        언제 와도 경치 좋고      1     1
# 3428                      자두에이드랑 빵시켰는데 맛은 쏘쏘하지만 경치가 좋아요      1     1
# 6827                                    바깥에 공간이 있어서 좋아요      1     1
# 1129                                             넓고 좋아요      1     1
# 5474                              웨이팅이 있었지만 기다린 보람이 있네용      1     1
# 513                                     플레인 크 로플도 좋았어요!      1     1
# 2328                                           커피도 맛있어요      1     1
# 3652                      경주 오면 황리단길 에그타르트 맛집 있대서 방문!!!      1     1
# 6022                                        빵들이 다 맛있어요.      1     1
# 7553                                             바다 전망.      1     1
# 4998                                        직원 분들이 친절해요      1     1
# 261                                주차는 길 건너 공용 주차장에 했어요      1     0
# 8170                                              뷰도 좋코      1     1
# 1407                                  가만 앉아만 있어도 걍 좋으네요      1     1
# 169                                            커피도 맛있었고      1     1
# 6341                                            오메기는 고소      1     1
# 7926             사람이 많아 평소 엄두도 못 내던 곳인데 평일이라 여유 있어 좋네요.      1     1
# 7339                                강릉 가면 다시 가고 싶을 만큼요!      1     1
# 5988           한라봉 크림 빵 순수 우유 오메기떡소보로 결론은 제 입맛에는 안 맞았어요      0     0
# 7999                     한적한 시간에 갔음에도 불구하고 주문 받는 직원 불친절      0     0
# 5640                                  우도 땅콩 크림 토핑도 넉넉하고      1     1
# 3247                                     아기자기 귀여운 매장이에요      1     1
# 5906                                             빵이 맛나요      1     1
# 4992                             천천히 먹었는데 마지막까지 빵이 촉촉하고      1     1
# 1759                                    처음 와 봤는데 이색적이고       1     1
# 4343         제주도 여행으로 왔다가 맛집이라고 해서 아침으로 먹을 겸 포장하러 왔어요!!      1     1
# 3037                                              넘 조아요      1     1
# 2558                                            너무 멋집니다      1     1
# 5074                                           커피도 맛있어요      1     1
# 6055                                      진짜 맛있음 또 올 거임      1     1
# 4538                               파 크림 치즈 최애인데 너무 기대되요      1     1
# 4575                                    매장도 깨끗하고 너무 예뻐요      1     1
# 1876                                아침에도 이쁘고 또 아기랑 갈께요.      1     1
# 4854                                      종류도 많고 너무 좋아요      1     1
# 6410                                       ~순우유는 너무 달아요      0     0
# 6103                        우도 땅콩이 시그니쳐지만 모든 빵이 다 미쳐쒀..      1     0
# 2040                                         소금 빵이 유명해요      1     1
# 3932                                       제주공항 근처 뷰 맛집      1     1
# 3570                                 덕분에 두 손 무겁게 선물도 사고      1     1
# 473                                                   굳      1     1
# 4833                                       베이글도 맛있어 보여요      1     1
# 1587                                     따뜻할 때 또 가고 싶네요      1     1
# 8035                                빵 엄청 엄청 부드럽고 맛있습니다.      1     1
# 1005                                        생각보다 크진 않아요      1     0
# 6763                                    주변 풍경이 매우 예쁨니하다      1     1
# 3935                            2 층에서 바라보는 바다가 정말 멋 있어요      1     1
# 3579                                               맛있네요      1     1
# 3530     아이스크림이 이뻐서 사진 찍기 좋아요 밑에는 우유 맛 하얀 슬러시 같은 음료 예여!      1     1
# 4775                    계란이랑 버터를 안 써서 그런가 속도 편하고 좋더라구요.      1     1
# 8519                                          카페 너무 이뻐요      1     1
# 5635                             도너츠에 진심 아닌데 아베베엔 진심할래요      1     1
# 3743               매장 분위기며 뷰도 좋아서 경주 한옥 분위기 물씬 나서 좋았어요!      1     1
# 5960                                               맛있네요      1     1
# 1571                                     아기가 좋아해서 자주 와요      1     1
# 2               술집 같은 데 커피와 음료도 팔고 있음 인테리어도 이쁘고 나쁘지 않았음      1     1
# 720                                 재고 처리 보다 그날 빵으로 주세요      1     0
# 6494                                    하나만 산 걸 후회했어요..      1     0
# 5285                                           뷰가 넘 좋아요      1     1
# 7578                      빵이 너무 맛있고 다른 곳에서 먹어 본 맛이 아니에요      1     1
# 5882                                        맛있는 도넛이 많아여      1     1
# 6455                                                비싸고      0     0
# 1368                                  여기는 맛도 뷰도 다 잡았 내용      1     1
# 508                                         포항 남구 구룡포읍!      1     1
# 7602                                       베이커리 맛집이에요!!      1     1
# 6652                                        먹을 때마다 맛있어요      1     1
# 172                      그리고 컵이 너무 귀여워서 따로 판매하면 사고 싶었어요      1     1
# 7930                          과테말라 게이샤는 산미가 1도 없어 아쉬웠어요      0     0
# 5019                                          인테리어도 이쁘고      1     1
# 29                             뜨거운 것도 메뉴 개발 중이시라니 기대할게요      1     1
# 122                                             케이크 예쁘고      1     1
# 1241  커피숍에서 보는 야외가 든 전경 굿 게이샤 마시러 갔는 데 핸드드립이 아니 여서 아...      1     0
# 3774                                                좋네요      1     1
# 6420                                   빵 순이라면 꼭 가 보세요!!      1     1
# 5726                                       땅콩 크림 빵 맛있어요      1     1
# 6435                                   우도땅콩크림도너츠도 맛있어요.      1     1
# 7269  워낙 유명해서 한 시간 반 정도 기다리다 먹었는데 맛있긴했지만 그 정도 웨이팅할 정...      0     0
# 5305                                       노래랑 분위기가 좋아요      1     1
# 1361                              또 가고 싶어요 커피 맛도 너무 좋아요      1     1
# 3240                           이렇게 다양한 케익이 있는 카페 드문 듯요.      1     1
# 6961                                     진짜 맛있어요 툇마루 커피      1     1
# 7772                                           빵 맛이 좋아요      1     1
# 1802                                    커피 향 좋고 넘 맛있어요.      1     1
# 5520                  빵 순이 뇨로분 달달 이 러버님들 저기는 꼭 가셔야합니다!!      1     1
# 2493                                           인테리어 예쁘고      1     1
# 5199                                              뷰 맛집.      1     1
# 3414                                               친절해요      1     1
# 6217                                   빵이 묵직하니 먹음직스러워요!      1     1
# 4918                                     소금 베이글이 맛있습니다.      1     1
# 2530                                          디저트류도 맛있고      1     1
# 296                                              또오고싶슴다      1     1
# 1257                                    예쁘구 봄에 가도 좋을 듯!      1     1
# 595                                        정말 좋은 거 같아요.      1     1
# 8544                   적산 가옥을 그대로 살려서 옛날 가옥 느껴 보기에 좋아요.      1     1
# 4184             가성비 좋은 애망빙 집이 있다고 해서 찾아왔는데 왜인걸 존맛탱이네요!      1     1
# 352                                           뷰가 환상입니다.      1     1
# 3898                           뷰 너무 좋구 공항 근처라 비행기 다 보여요      1     1
# 2511                                        커피도 맛있어요...      1     1
# 1243                                        진짜 뷰 맛집이예요.      1     1
# 5156                                       우선 제주도 뷰 맛집!      1     1
# 7504                                    뷰 맛집에 빵 맛집 인정!!      1     1
# 3203                                창 밖으로 보이는 꽃 정원이 좋네요      1     1
# 4855                                  아기자기 인테리어도 너무 귀엽고      1     1
# 7733                                     요거트 진짜 맛이 미쳤어요      1     1
# 3318                                   빵도 맛 나구 분위기도 조아요      1     1
# 7773                                           빵 맛이 좋아요      1     1
# 3925                                              뷰 쩌러요      1     1
# 7334                              대표적인 커피를 맛보기 위해 갔습니다.      1     1
# 6302                                              평범했어요      0     0
# 2528                                   여기는 진짜 오고 싶었는데!!      1     1
# 2143                                          자연 경관 예쁘고      1     1
# 6648  직원 분 넘 친절하시고 맛있게 잘 먹었어 요 담엔 녹차 맛이랑 커스터드 푸딩 먹으려고 용      1     1
# 1981                                         리얼 뷰 맛집!!!      1     1
# 888                                         빵 종류도 많아요!!      1     1
# 103   이전에는 자리가 없어서 허탕 친 일이 더러 있었는데 리뉴얼 되고 그런 적이 없어서 ...      1     0
# 3385                                  2 층 능 뷰가 평화롭고 좋아요      1     1
# 1064                                      생각했던 것보다 달랐지만      1     0
# 5257                                        자리값인듯 음료 별로      0     0
# 3483                                          뷰가 너무 예뻐요      1     1
# 8152  빵 맛있긴한데 말차 라떼 주문했는데 주시는 바리스타가 쏟아 놓고 그거 그대로 주더라...      0     1
# 4716         가위도 준비돼 있어서 더 작게 컷팅하실 분들은 편하게 사용하실 수도 있어요!      1     1
# 1984                                            뷰는 좋아요.      1     1
# 8470                 빵도 빵인데 오도독 들어간 휘낭시에들하고 돌낭스크 너무 맛있음      1     1
# 6151                                        바로 먹는 것이 최고      1     1
# 4058  망고 빙수랑 따뜻한 영귤차 빙수랑 차도 맛있고 카페 분위기도 좋고 아삭하니 씹히는 ...      1     1
# 3993                            탱글탱글 푸딩한 입 입안에서 사르르 녹아요      1     1
# 77                                        다 앉아 보고 싶었어요.      1     1
# 5029                                    베이글 종류도 많고 맛있어요      1     1
# 7790                                             공간도 넓고      1     1
# 2096                                             뷔가 죽여요      1     0
# 6882                              소문의 툇마루 커피가 맛있긴 맛있네요.      1     1
# 4696                                         매장이 너무 예쁘고      1     1
# 1027                                                좋아요      1     1
# 1305                                   무엇보다 커피가 진짜 맛있어요      1     1
# 7865                                       규모나 주차 시설 넓고      1     1
# 3899                                콘센트도 너무 많아서 너무 좋았어요      1     1
# 2301                                        뷰는 말할 것도 없고      1     0
# 3794                                        차랑 커피도 맛있음.      1     1
# 5155                                          커피도 맛 있네요      1     1
# 5542                                제주도 올 때마다 무조건 사야겠어요      1     1
# 4263                 안에 우유 얼음 위에 아이스크림도..맛있어서 끝까지 먹게 돼요      1     1
# 1633                                              카페 넓고      1     1
# 4318                              공항 근처라 딱 먹고 공항 가기 좋네요      1     1
# 603                                                 좋아요      1     1
# 788       아기 때문에 아쿠아 플라넷 왔다가 어른들은 서귀피 안 베이커리에서 힐링하고 가요.      1     1
# 1955                                     누구나 인정하는 뷰 맛집.      1     1
# 2130                                  기장의 핫 플레이스라고 해 방문      1     1
# 7577                       베이커리 쪽 장인이시고 상도 많이 받으신 것 같아요      1     1
# 2013                                            뷰 맛집 강추      1     1
# 601                                     분위기 있어서 쉬기 좋았네요      1     1
# 5455                                      더티초코도 넘 맛있구!!      1     1
# 3221                                      커피랑 디저트도 맛있어요      1     1
# 5128                                           뷰는 더 좋아요      1     1
# 5003                                     콘 치즈 베이글도 특별하고      1     1
# 1756                                           빵도 맛있어요.      1     1
# 6723      다른 곳에서 못 먹어 보는 거라 사 봤는 데 가격은 아무래도 비싸게 느껴지긴해요.      0     0
# 7972  메뉴 연탄 빵 커피 오렌지 브리오 캐모마일 이렇게 먹었는데요! 연탄 빵 안에 생크림...      1     1
# 41                                  맛있어요 커피 향 너무 좋아요!!!      1     1
# 5596                 개인적으로 우도 땅콩하고 한라산 1100 고지 쑥이 맛있네요.      1     1
# 3711                    인테리어도 완전제스퇄 바닐라 아이스크림은 사용하시더라구여      1     1
# 225                                           뷰가 정말 멋져요      1     1
# 7238                              주차장이 방문객에 비하면 많이 협소하고      0     0
# 8359                                         케이크는 맛 없어요      0     0
# 1062                                             뷰가 좋아요      1     1
# 6292                                        빵이 조금 느끼하지만      0     0
# 3057  비 오는 날이라 야외 앉기도 어려웠는 데 운치가 너무 좋아서 지붕 있는 야외 자리로...      1     1
# 1543                           아기 의자가 있어서 아기랑 오기에도 좋아요!      1     1
# 6409                                 제 입맛에는 땅콩이 가장 맛있네요      1     1
# 3301                              컵도 차가 와서 시원하게 잘 먹었어용.      1     1
# 2577                   그래도 카페뷰를 생각하면 또 가고 싶은 정말 예쁜 카페예요      1     1
# 8167                                                 좋아      1     1
# 8493                                            커피도 맛있고      1     1
# 822                       빵도 여러 가지 있어서 필수로 다녀올 곳인 거 같아요      1     1
# 5969       오메기 소보로 샀는데 모두 빵 피가 쫄깃하구 크림은 적당히 달달해서 맛있었습니다      1     1
# 1029                                     뷰도 인테리어도 좋았어요.      1     1
# 2094                                             뷰가 좋아요      1     1
# 2275                                        크림이 정말 맛있어요      1     1
# 4603                                            주차도 편하고      1     1
# 5174                         빵, 커피 모두 먹을 만한데 뷰도 좋은 카페에요      1     1
# 611                                            뷰도 너무 좋고      1     1
# 6876                                      빵은 정말 맛있습니당!!      1     1
# 2853                                         한옥이라 넘 좋아요      1     1
# 7118                                  커피 좋아하시면 강추 드려요!!      1     1
# 1242                                           눈이 즐거운 곳      1     1
# 6123                                 특히 우도땅콩크림도너츠 기절!!!      1     1
# 6118                                        전체적으로 좀 답니다      0     1
# 420                                            뷰 맛집이 예여      1     1
# 168                            외국인들이 많이 와서 사진 찍고 가시더라구요      1     1
# 5013                                          아기도 잘 먹어용      1     1
# 5500                                    가면 잔뜩 사 오는 곳이예요      1     1
# 6299             쑥이랑 땅콩 맛 구매했는 데 개인적으로 땅콩이 진짜 맛난 거 같아요.      1     1
# 1230                                          가을 느낌 좋아요      1     1
# 5482                                       맛이 다양해서 좋습니다      1     1
# 6153                               선물용으로 너무 좋은 아베베 시그니쳐      1     1
# 4229                           직원 분들도 너무 친절하시고 잘 쉬다 갑니다      1     1
# 7442                                      바다가 다 보요서 좋아요      1     1
# 2815                             그늘진 툇마루 자리에서 잘 쉬다 갑니다.      1     1
# 2225                처음 와 봤는 데 뷰도 좋구 커피 맛도 좋구 사람만 좀 적었으면      1     1
# 1001                       그냥 장사가 잘 되니깐 기계적인 느낌이 들었습니다.      1     0
# 2161                                           뷰 짱 좋아요!      1     1
# 7607                                       주차장이 넓어서 좋아요      1     1
# 1126                           매 계절을 느낄 수 있는 좋은 카페 같아요.      1     1
# 678                                            주차하기 편하고      1     1
# 7075                                   다음에 또 방문하고 싶어요!!      1     1
# 3516                               가족 모두 말차를 좋아해서 가기도했고      1     1
# 5354  제주의 정원이 잘 가꿔진 아담한 카페 특별히 따 이공 크림이 들어간 땅콩슈페너의 맛...      1     1
# 7618                                              매장 넓고      1     1
# 5098                                바로 앞에 바다가 있어 경치도 좋고      1     1
# 2872        생각 없이 갔는 데 커피가 너무 맛있었고 같이 주문한 베리 음료도 맛있었어요!      1     1
# 6816                 음식 맛 또한 좋아서 정말 만족도가 높았어요 올라 추천합니다!      1     1
# 687                                     일단 카페가 넓어서 좋아요.      1     1
# 5651                            우도 땅콩이랑 코코넛은 인기가 많더라구요!      1     1
# 16                      인테리어나 굿즈들 색감을 너무 잘 뽑으셔서 분위기 미쳐요      1     1
# 5898                                           빵들이 특이해요      1     1
# 2548                                           분위기 짱이예요      1     1
# 2642                                등산하고 나니 산 속에 이런 공간이      1     1
# 2961                        툇마루 자리가 햇살도 좋고 바람이 부니 더 좋네요      1     1
# 5930                                           확실히 맛있어요      1     1
# 5522                                        빵 종류가 진짜 많고      1     1
# 8568        바깥에 자리가 3개 정도 있는 데 옆자리랑 가까워서 조용히 대화하긴 어렵고요.      0     0
# 2655                                             뷰가 예쁘고      1     1
# 4289                     애플 망고 우도 땅콩 구좌 당근 모두 즐길 수 있어요       1     1
# 7271                        기다린 만큼 맛은 있지만 일찍 와서 기다려야겠어요      1     0
# 7                                         알바생 분인지 모르겠지만      1     0
# 638                                              맛도 좋네요      1     1
# 1910                                            건물이 예쁘고      1     1
# 2897                                            자리도 많아요      1     1
# 1156                                                좋아요      1     1
# 6095                                            빵이 쫀득하고      1     1
# 4766                                            베이글 존 맛      1     1
# 4966                                    매장 엄청 깔끔하고 좋아요.      1     1
# 7056       평일 오후 5시 30분쯤이었는데 대기가 0명이어서 기분 좋게 매장에서 마셨어요.      1     1
# 2277                   뷰가 좋아서 갔는 데 커피랑 빵이 너무 맛있어서 만족했어요      1     1
# 763                                              맛이 있어요      1     1
# 1496                                 여러모로 추천하고 싶은 카페입니다      1     1
# 3835                                           바다 뷰 좋아요      1     1
# 1879                                               잠들 뻔      1     1
# 8488                                           커피는 맛있는뎅      1     1
# 4552                               소금 버터 베이글은 넘사입니당!!!!      1     1
# 3945                      분위기도 좋고 공항이랑 가까워서 시간 때우기 좋았어욥      1     1
# 6884  저는 다행히 30분 정도 기다리고 들어갈 수는 있었는데 한창 휴가철에 더 기다려야했...      0     0
# 5105                              호텔 가까이 이쁜 카페 빵도 맛있었어요      1     1
# 6750                   둘 다 귀여운 맛이었지만 특히 보리당고ice 너무 좋았어요      1     1
# 4673                             오랜만에 맛보는 진정한 베이글의 맛이네요      1     1
# 1687                                    일하시는 분도 늘 친절하세요      1     1
# 2538                                위치는 별로 여도 찾아올 만한 곳!      1     0
# 5665                                 제주 지역별 특색을 살린 메뉴들.      1     1
# 2099                                   뷰가 좋아서 전 두 번째 방문      1     1
# 5092                                           커피 맛 있어요      1     1
# 5623                          제 주 특성을 가장 잘 표현하는 빵집 같아요.      1     1
# 3374                 앞이 탁 트여 커피 마시면서 마음 편히 볼 수 있는 곳입니다.      1     1
# 4492                                   제주도 최애 맛집 중 하나에요      1     1
# 1113                                           커피가 맛나네요      1     1
# 4913                  베이글 너무 좋아하는 데 베이글 맛집 찾아서 너무 조하요!!      1     1
# 5829                          유명해서 들렀는데 크림이 안 달고 맛있습니다.      1     1
# 5918                                             맛있습니다!      1     1
# 417                                             위치는 좋음       1     1
# 4938     뭔가 심플하면서 북미풍의 느낌이 잘 살아 있는 인테리어와 맛있는 베이글과 센드위치!      1     1
# 1786                                      케일 사과 쥬스 맛있어요      1     1
# 7188     밖에서도 삼십 분? 기다리고 안에 가서도 삼십 분 기다렸네요 정말 오래 기다렸습니다      0     0
# 2776            조용하고 대화하기도 혼자 멍 때리며 편하게 커피 한 잔 하기에도 좋아요      1     1
# 3391                                         너무 너무 친절하고      1     1
# 2571                                             져아 융 뷰      1     1
# 4038                                   크림이랑 바질 오일도 맛있어요      1     1
# 8125                                     풍경이 아름다운 곳입니다.      1     1
# 121                        다음에는 친구 생일 케이크 주문하러 방문하겠습니다!      1     1
# 6662                                                비싸요      0     0
# 4456                                    제주 현지인 베이글 맛집!!      1     1
# 1138                                             뷰가 좋아요      1     1
# 4225                매장도 깨끗하고 직원분도 친절하시고 무엇보다 깔끔하니 맛있어요.      1     1
# 6541                                  우뭇향이 은은하게 나서 신기해요      1     1
# 5544                           빵 종류가 다양해서 행복한 고민이 많았습니다      1     1
# 4165                      사장님 너무 너무 너무 친절하시고 빙수 너무 맛있어요      1     1
# 1187                                        경치 뷰 아주 좋아요      1     1
# 1672                                        인테리어가 예쁩니다.      1     1
# 6188                                            매장은 좁지만      0     0
# 1391                                                 와우      1     1
# 1284                                 마운틴뷰 힐링 또 하고 왔습니다.      1     1
# 6108                                             크림 빵 굿      1     1
# 7566                                       사천 진 필수 코스네요      1     1
# 6029                           전에 비해 매장 넓어져서 빵 고르기도 편하고      1     1
# 1616       그리고 기차 테이블에 앉으면 기차가 음료를 배달해 주는 것이 너무 재미있었어요!      1     1
# 5268                                               뷰 맛집      1     1
# 5666                            동문시장 가야하는 이유가 하나 더 생겼네요      1     1
# 1635                                               깨끗하고      1     1
# 8554                                    너무 친절하게 설명해 주시고      1     1
# 1390                                   가을을 한눈에 볼 수 있는 곳      1     1
# 5975                                      더 살 껄 후회 중이에요      1     1
# 6734                                    식감 보들탱 글하고 맛있어요      1     1
# 8242                                   장인 정신이 고스란히 느껴진다      1     1
# 4785                                      시오 베이글 강추 합니당      1     1
# 7689    평소에 카페 잘 안 다니는 데 왜 사람들이 카페를 여기저기 찾아다니는지 알게해 준 곳      1     1
# 5152                                 바닷가 바라보며 먹는 커피 빵 굿      1     1
# 5062                                  제 아지트 삼고 싶은 곳입니다.      1     1
# 7286                      제 입맛에는 오래 기다려서 먹을 만큼 맛있지 않아요.      1     0
# 3739                                            빙수 맛있어요      1     1
# 336                                               바다뷰..      1     1
# 2312                                   바다가 바로 앞에 있는 카페.      1     1
# 1174                                         주차 공간은 넓은데      1     0
# 7941                                           뷰 맛집입니다.      1     1
# 3433                                             뷰가 좋아요      1     1
# 4134                  7살 딸들도 애플 망고 아이스크림과 주스를 맛있게 잘 먹네요      1     1
# 2942                                          한옥 풍경 좋아요      1     1
# 4373                                             아주 좋네요      1     1
# 8236                   커피 맛 진짜... 핸드드립은 이렇게 먹는 거구나. 감탄.      1     1
# 1938                   뷰가 너무 예쁜 데 밤에도 바다 뷰가 아예 없는 건 아니고      1     0
# 4817                                       베이글이 진짜 쫄깃하고      1     1
# 8201                                             공간이 넓고      1     1
# 4130            생 애플 망고 시즌 지나서 애플망고소르베빙수먹었는데 완전 맛나요!!!!      1     1
# 7385                                         분위기 너무 좋아요      1     1
# 4776                                           또 오겠습니다!      1     1
# 3926  제주 여행 마지막 날 공항 가기 전에 시간이 어정쩡해서 어디 갈까 고민하다가 갔는 ...      1     1
# 2731                                          감각적인 인테리어      1     1
# 6627                                   언제 먹어도 너무 맛있는 우무      1     1
# 5125                                        빵도 음료도 특별해요      1     1
# 599                            개인적으론 안 섞고 먹는 것이 맛있는 듯요!      1     1
# 1655                                              뷰가 좋고      1     1
# 574                                                 좋아요      1     1
# 6743                             우연히 방문한 곳인데 분위기도 너무 좋고      1     1
# 3782                     룸이 있어서 아기 데리고 여행 왔는데 너무 좋았습니다.      1     1
# 1437                                           분위기가 좋네요      1     1
# 8069                                               청소 좀      0     0
# 5237                                       주차하기 너무  힘들다      0     0
# 6985                                       주차공간은 별로 없어요      0     0
# 2436                                            케이크 맛집!      1     1
# 5685                   빵 안 좋아하시는 부모님도 조카들도 아주 맛있게 먹었어요.      1     1
# 7620                          뷰 맛집 사진 맛집 커피 베이커리 맛집입니다.      1     1
# 4298                                 아니 정말 망고 빙수 넘 맛있어요      1     1
# 82                                                 친절하고      1     1
# 1689                                   어른도 좋은 곳이라 자주 와요      1     1
# 4202                           애플 망고 빙수 우도 아이스크림 짱 맛있어요      1     1
# 1926                                  음료는 가격이 비싸지만 좋습니다      1     0
# 1626                         단풍 철이라서 전면에 보이는 단풍 뷰가 예쁘네요      1     1
# 5694                                     오메기떡 도넛 꼭 드세여!      1     1
# 7412                                      전면 창으로 뷰가 좋음.      1     1
# 5448                             우유 크림 빵 한라산 빵 진짜 맛있어요…      1     1
# 7947                                          카페 엄청 넓어요      1     1
# 2584                                         강추!!!!!!!!      1     1
# 4891                                          진짜 맛있어요!!      1     1
# 5630                               서울로 돌아가도 먹고 싶을 거 같아요      1     1
# 917                              신얌 해수욕장 풍경과 맛있는 커피 좋아요      1     1
# 6212                                        좋아하는 디저트네요.      1     1
# 4852                                                맛나요      1     1
# 8217                드립 커피는 안 마셔 봤지만 에스프레소 베이스 커피는 별로에요.      0     0
# 7239                         의자가 나무 의자라 엉덩이가 좀 있으면 아파요.      0     0
# 6274                             사과 크림 빵은 제 입맛엔 좀 아니에요.      0     0
# 6646                          넘 먹고 싶었는데 웨이팅 없이 빨리 구매했어요      1     1
# 5157                            바다 보면서 음료와 빵들 먹을 수 있어요.      1     1
# 85                                      시즌 메뉴인가 포롤롤로..?      1     1
# 8314                        바다도 넓은 창으로 볼 수 있어서 기분도 좋았구요      1     1
# 6634                                            너무 맛있어요      1     1
# 1607             가을에 운치 잇고 배경도 이뻐요 아주 멋있는 곳 시간이 행복했습니다.      1     1
# 4805                                           매장도 깔끔하고      1     1
# 4428                            빵이랑 크림치즈 종류도 많아서 조아욤 굿굿      1     1
# 6003                                         맛있게 잘 먹었어요      1     1
# 2257                            뷰도 예쁘고 앙 버터 바게트 진짜 맛있어요      1     1
# 3567           황리단길 가면 다들 먹어 보길래 사 봤는데 생각보다 맛있고 귀여웠습니다.      1     1
# 5558                                      크림이 풍부하고 부드럽고      1     1
# 2813                                 아아랑 말차 동동 라떼 마셨어요.      1     1
# 1923                                            주차하기 좋고      1     1
# 2688         아버지 모시고 월 정교 갔다가 앞에 카페를 갔는데 분위기가 너무 멋있었어요.      1     1
# 6363                                    남편이 너무너무 맛있대요!!      1     1
# 4302                애플 망고 빙수 1 인분 멜론 빙수 1 인분 매장에서 먹었어요!      1     1
# 2661                                        미술관처럼 멋 있어요      1     1
# 1573                                          음료도 맛 잇어요      1     1
# 5730                                     저는 딸기가 제일 맛있네용      1     1
# 5170                           시그니처 메뉴 중 하나를 먹었는데 맛있엇어요      1     1
# 3469                                                 친절      1     1
# 8384                                          브런치 좋았습니다      1     1
# 919                                    미니 초코파이로 샀는데 맛있고      1     1
# 7648                                              커피 굿!      1     1
# 851                                늘 오는 데 여기만 한 카페가 없어요      1     0
# 6                                                 사장님인지      1     0
# 3410                                      그래도 뷰는 참 이쁘네요      1     1
# 6923                                              뷰도 좋고      1     1
# 2728                                          커피 맛도 괜찮고      1     1
# 246                                              뷰가 좋아요      1     1
# 8148                                오션뷰가 있는 대형 카페 추천해요.      1     1
# 5987                            특히 떡 들어간 메뉴는 정말 미친 맛이에여      1     1
# 7321                       그치만 이 커피만 마시서 강릉까진 오지 못할 정도.      0     1
# 6249                                맛있다고 유명한 빵지순례 집이에요!      1     1
# 1822                                     분위기가 좋아서 자주 가요      1     1
# 5751     제주 관련된 특산품으로 특색 있는 빵 종류가 다양하고 많아서 선택하는 데 어려웠는데      1     0
# 3144                                  메뉴도 만족 분위기도 만족입니다      1     1
# 158                                            예쁘고 맛있어용      1     1
# 317                            포항 오면 다시 한 번 쯤 방문하고 싶네요.      1     1
# 4977                                            너무 맛있어요      1     1
# 4424            연어 샌드위치 넘 맛있는 데 베이글 자체만으로도 쫀득쫀득 너무 맛있네요      1     1
# 4025                                 다양한 디저트를 먹을 수 있는 곳      1     1
# 4859                                     후기가 좋은 이유가 있네요      1     1
# 7634                                         베이커리 맛집!!!      1     1
# 4906                              그냥 다 사고 싶은 걸 간신히 참았네요      1     0
# 3355                                            빵도 맛있어요      1     1
# 7284  그 이후에 엄청 유명해져서 이사까지 가게 되고 땡볕에 웨이팅해서 오랫만에 먹어 본 ...      1     1
# 8462  디저트 맛집이라고 해서 방문했는 데 포장으로 거의 다 팔리고 남는 것에 그 타르트랑...      1     1
# 4051                                       매장도 크고 깔끔해요.      1     1
# 2846              한옥 카페에서 시간 여행하는 기분을 느낄 수 있어서 너무 좋았어요.      1     1
# 3949                                       비행기 구경하기 좋아요      1     1
# 7727                      엄마 아빠 모시고 뷰 좋은 곳에서 힐링 하고 왔습니다      1     1
# 535                                               뷰가 좋고      1     1
# 3509                                   쿠키도 찍어 먹으니까 맛있어요      1     1
# 8118                                              빵 맛있고      1     1
# 3912                                          뷰가 진짜 좋아요      1     1
# 7758                                          화장실도 깨끗하고      1     1
# 5936                               아직 우도 땅콩만 먹었지만 맛있어용!      1     1
# 510                                            인테리어도 좋고      1     1
# 5335                             테이크아웃 주문하니 페트캔에 담아 줘요!      1     1
# 5                                           미국 바에 있는 느낌      1     1
# 5435     또 완전히 해동되기 전에 먹으면 크림이 아이스크림 같아서 또 다른 맛으로 맛있답니당      1     1
# 5480                                            빵이 쫀득해요      1     1
# 5015                                          커피도 맛있어 여      1     1
# 4504                                       처음 왔는데 넘 좋아요      1     1
# 1880                                           뷰도 너무 좋고      1     1
# 887                                              매장도 크고      1     1
# 286                     비싸기만 드릅게 비싸고 맛은 없는 그런 카페와는 달라요!      1     0
# 519                                 그냥 찍어도 사진 엄청 잘 나오네요      1     1
# 4496                                  베이글 종류 많고 넘 맛있습니다      1     1
# 3092                            카페 안 풍경이 예뻐서 사진 찍기도 좋아요      1     1
# 541                                              뷰가 좋아요      1     1
# 1787                                      기차 잼 있는 경험이에요      1     1
# 3168                                         디저트 종류도 많고      1     1
# 725                                빵 가격은 비싼 편이지만 맛은 있어요      1     0
# 7862                                                짱!!      1     1
# 1928                                             뷰는 좋은데      1     1
# 3790                            꼭 오고 싶었던 곳인데 너무 만족스러웠어요      1     1
# 7552                                                맛있당      1     1
# 2431                       초코 조각 케이크 맛있는 데 포장 안 되서 아쉬워요      1     0
# 679                                            바다뷰는 좋은데      1     1
# 163                                               감사합니다      1     1
# 6503                                            푸딩 맛있어요      1     1
# 1441                                       양송이 스프와 바게트!      1     1
# 2796                                   직원들도 정말 친절하고 예쁘고      1     1
# 551                                              자주 옵니다      1     1
# 1940                       그리고 얼마 전에 리뉴얼 돼서 빈 백도 깔끔하네요.      1     1
# 6214                                     마늘 조합이 진짜 미쳤어요      1     1
# 3600                         쥬스를 못 사서 아숩지만 에그타르트 잘 먹을게요      1     0
# 6387                                            너무 맛있어용      1     1
# 1494                             근처에 멋진 폭포가 있어 경치가 좋네요.      1     1
# 732                                     매번 케이크 구매하고 있어요      1     1

# %%
from sklearn.metrics import classification_report

print(classification_report(test_set['label'], test_set['pred']) )
# Out:
#               precision    recall  f1-score   support
#
#            0       0.51      0.85      0.64        33
#            1       0.99      0.94      0.96       467
#
#     accuracy                           0.94       500
#    macro avg       0.75      0.90      0.80       500
# weighted avg       0.96      0.94      0.94       500
